# %%
DATE = 'JUN11'
default_json  = '_json/default_params.json'
controller_mode = 'occupancy'
start = "2023-02-01 00:00"
end   = "2023-03-10 23:00"
N=80

# %%
from pathlib import Path
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json

RC_SIMULATOR = "ETHlib"
if RC_SIMULATOR not in sys.path:
    sys.path.insert(0, RC_SIMULATOR)

from _ import *
from _BR_ import *
from _zone_ import DebugZone as Zone
import supply_system
import emission_system
case = RCCase(
    year=2023,
    loc_json              = Path("_json/location_params.json"),
    geo_json              = Path("_json/geo_params.json"),
    default_json          = Path("_json/default_params.json"),
    epw_path              = Path("../src/_base/epw/ED-TMYx.2023.epw"),
    occupancy_profile_csv = Path("_data/default_occ.csv"),
    Zone=Zone,
    supply_system=supply_system,
    emission_system=emission_system,
)

case.occupancy_profile = (
    pd.read_csv(Path("_data/bldg_LoD.csv"), usecols=["Y"])
      .iloc[:8760]
      .reset_index(drop=True)
)

case.occupancy_profile.columns = ["People"]

case.electricity_profile = case.occupancy_profile.copy()

# %%
DEFAULT_PARAMS = json.loads(Path(default_json).read_text())
RUN_DIR = Path(f"_json/_run/{DATE}")
uq_json_path = RUN_DIR / "OAT.json"

meter_path = "_data/Metering_ISO.csv"
meter_daily = load_meter_heating(
    meter_path,
    "Main Heating",
    case.geometry["FLOOR_AREA"],
    "D",
)
meter_hourly = load_meter_heating(
    meter_path,
    "Main Heating",
    case.geometry["FLOOR_AREA"],
    "h",
)
# Out:
# Metering Timestamp: 2023-01-01 00:00:00 ~ 2023-12-31 23:00:00
# Metering Timestamp: 2023-01-01 00:00:00 ~ 2023-12-31 23:00:00

# %% [markdown]
# # RUN

# %%
from _ import show_progress
from scipy.stats import qmc
def make_lhs_samples_from_uq_json(uq_json_path, N=100, save_csv=True):
    
    uq_json_path = Path(uq_json_path)

    with open(uq_json_path, "r", encoding="utf-8") as f:
        uq_config = json.load(f)

    N = N
    seed = uq_config["seed"]
    params = uq_config["parameters"]

    param_names = list(params.keys())
    n_dim = len(param_names)

    sampler = qmc.LatinHypercube(d=n_dim, seed=seed)
    lhs_unit = sampler.random(n=N)

    samples = pd.DataFrame(index=range(N), columns=param_names, dtype=float)

    for i, name in enumerate(param_names):
        lower = params[name]["lower"]
        upper = params[name]["upper"]

        samples[name] = lower + lhs_unit[:, i] * (upper - lower)

    samples.index = [f"sample_{i+1:03d}" for i in range(N)]

    if save_csv:
        output_path = uq_json_path.parent / f"LHS_samples.csv"
        samples.to_csv(output_path)
        print(f"Saved LHS samples to: {output_path}")

    return samples

def run_lhs_samples(
    lhs_samples,
    controller_mode="occupancy",
):
    results = {}
    euis = {}

    for sample_id, row in show_progress(
        lhs_samples.iterrows(),
        total=len(lhs_samples),
        desc="Running samples",
        unit="sample",
    ):
        sampled_params = row.to_dict()

        res, eui, _ = run_model_case(
            case=case,
            sampled_params=sampled_params,
            controller_mode=controller_mode,
        )

        results[sample_id] = res
        euis[sample_id] = eui

    eui_df = pd.DataFrame(euis).T

    return results, eui_df

# %%
lhs_samples= make_lhs_samples_from_uq_json(
uq_json_path=uq_json_path,
N=N
)

lhs_results_occ, lhs_eui_df_occ = run_lhs_samples(
lhs_samples  = lhs_samples,
controller_mode = controller_mode,
)
# Out:
# Saved LHS samples to: _json/_run/JUN11/LHS_samples.csv
# Running samples:   0%|          | 0/80 [00:00<?, ?sample/s]

# %%
def calc_metrics(sim, obs):
    df = pd.concat(
        [sim.rename("sim"), obs.rename("obs")],
        axis=1,
    ).dropna()

    error = df["obs"] - df["sim"]
    obs_mean = df["obs"].mean()

    cvrmse = np.sqrt(np.mean(error ** 2)) / obs_mean * 100
    nmbe = error.sum() / (len(df) * obs_mean) * 100

    return cvrmse, nmbe


def compare_lhs_to_meter(
    lhs_results,
    meter_series,
    variable="HeatingEnergy",
    freq_label="hourly",
):
    rows = []

    for sample_id, res in lhs_results.items():
        cvrmse, nmbe = calc_metrics(res[variable], meter_series)
        rows.append((sample_id, freq_label, cvrmse, nmbe))

    return pd.DataFrame(
        rows,
        columns=["sample_id", "freq", "cvrmse", "nmbe"],
    ).set_index("sample_id")

# %%
KPI = "HeatingEnergy"
temp_res = "D"

meter_series = meter_hourly.resample(temp_res).sum()

lhs_results_res = {
    sample_id: res[[KPI]].resample(temp_res).sum()
    for sample_id, res in lhs_results_occ.items()
}

lhs_metrics_res = compare_lhs_to_meter(
    lhs_results=lhs_results_res,
    meter_series=meter_series,
    variable=KPI,
    freq_label=temp_res,
)

# %% [markdown]
# # Training dataset for `calibro`
# * temp_res = "H"   # hourly
# * temp_res = "D"   # daily
# * temp_res = "W"   # weekly
# * temp_res = "ME"  # month-end

# %%
def save_bayesian_calibration_files(
    lhs_samples,
    lhs_results,
    meter_series,
    variable="HeatingEnergy",
    freq="D",
    start=None,
    end=None,
    output_dir=Path(f"json/UQ/{DATE}_lhs"),
):
    output_dir = Path(output_dir)
    output_dir.mkdir(parents=True, exist_ok=True)

    TT = lhs_samples.copy()

    def prepare_series(series):
        series = series.copy()

        if start is not None or end is not None:
            series = series.loc[start:end]

        if freq is not None:
            series = series.resample(freq).sum()

        return series

    Y = pd.DataFrame({
        sample_id: prepare_series(res[variable])
        for sample_id, res in lhs_results.items()
    })

    obs = prepare_series(meter_series)
    obs.name = "obs"

    common_index = obs.index.intersection(Y.index)

    obs = obs.loc[common_index]
    Y = Y.loc[common_index]

    # Drop index columns when saving to CSV
    TT.to_csv(output_dir / "TT.csv", index=False)
    Y.to_csv(output_dir / "Y.csv", index=False)
    obs.to_csv(output_dir / "obs.csv", index=False)

    print(f"Saved Bayesian calibration files to: {output_dir}")
    print(f"Period: {obs.index.min()} to {obs.index.max()}")
    print(f"TT shape:  {TT.shape}")
    print(f"Y shape:   {Y.shape}")
    print(f"obs shape: {obs.shape}")

    return TT, Y, obs

KPI = "HeatingEnergy"
temp_res = "D"

output_dir = RUN_DIR / "BC"

TT, Y, obs = save_bayesian_calibration_files(
    lhs_samples=lhs_samples,
    lhs_results=lhs_results_occ,
    meter_series=meter_hourly,
    variable=KPI,
    freq=temp_res,
    start=start,
    end=end,
    output_dir=output_dir,
)
# Out:
# Saved Bayesian calibration files to: _json/_run/JUN11/BC
# Period: 2023-02-01 00:00:00 to 2023-03-10 00:00:00
# TT shape:  (80, 4)
# Y shape:   (38, 80)
# obs shape: (38,)

# %% [markdown]
# # Execution of `Calibro`

# %%
import papermill as pm

NOTEBOOK_IN = "1_CALIBRO.ipynb"

pm.execute_notebook(
    NOTEBOOK_IN,
    f"{DATE}.ipynb",
    parameters={
        "DATE": DATE,
        "START_DATE": start,
        "END_DATE": end,
    },
)
# Out:
# Passed unknown parameter: DATE
# Passed unknown parameter: START_DATE
# Passed unknown parameter: END_DATE
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/4 [00:00<?, ?cell/s]
# Loading required package: R6
# Loading required package: coda
# Loading required package: parallel
# Loading required package: MASS
# Loading required package: modeest
# ### NELDER-MEAD DOWNHILL SIMPLEX ALGORITHM ###
#
#  Version: amoeba
#  Start time: 2026-06-15 14:49:34.123685
#  Number of simulations: 5
#
#
# *** Simulation 1 / 5 (elapsed time: 0.00323 mins) ***
#
#  best y: 618.759946803821
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc.mu = 0.3922
# 	 %RHO@window_opening_ach%@sePar01.pc.mu = 0.5561
# 	 %ALPHA1@sePar01.pc.mu = 1
# 	 %SIGMA1@wn1.pc.mu = 1
# 	 %SIGMA1@wn2.pc.mu = 833900000
#
# *** Simulation 2 / 5 (elapsed time: 0.00454 mins) ***
#
#  best y: 618.759946803821
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc.mu = 0.3922
# 	 %RHO@window_opening_ach%@sePar01.pc.mu = 0.5561
# 	 %ALPHA1@sePar01.pc.mu = 1
# 	 %SIGMA1@wn1.pc.mu = 1
# 	 %SIGMA1@wn2.pc.mu = 833900000
#
# *** Simulation 3 / 5 (elapsed time: 0.00565 mins) ***
#
#  best y: 618.809884747137
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc.mu = 0.3951
# 	 %RHO@window_opening_ach%@sePar01.pc.mu = 0.5205
# 	 %ALPHA1@sePar01.pc.mu = 1
# 	 %SIGMA1@wn1.pc.mu = 1
# 	 %SIGMA1@wn2.pc.mu = 8.38e+08
#
# ### NELDER-MEAD DOWNHILL SIMPLEX ALGORITHM ###
#
#  Version: amoeba
#  Start time: 2026-06-15 14:49:34.509392
#  Number of simulations: 5
#
#
# *** Simulation 1 / 5 (elapsed time: 0.00101 mins) ***
#
#  best y: 490.199469618082
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc1 = 5.551e-17
# 	 %ALPHA1@sePar01.pc1 = 1
# 	 %SIGMA1@wn1.pc1 = 0.9997
# 	 %SIGMA1@wn2.pc1 = 128700000
#
# *** Simulation 2 / 5 (elapsed time: 0.0022 mins) ***
#
#  best y: 621.494020310445
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc1 = 0.1294
# 	 %ALPHA1@sePar01.pc1 = 1
# 	 %SIGMA1@wn1.pc1 = 1
# 	 %SIGMA1@wn2.pc1 = 112600000
#
# *** Simulation 3 / 5 (elapsed time: 0.00289 mins) ***
#
#  best y: 621.494020310445
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc1 = 0.1294
# 	 %ALPHA1@sePar01.pc1 = 1
# 	 %SIGMA1@wn1.pc1 = 1
# 	 %SIGMA1@wn2.pc1 = 112600000
#
# *** Simulation 4 / 5 (elapsed time: 0.00407 mins) ***
#
#  best y: 628.882364894258
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc1 = 0.04984
# 	 %ALPHA1@sePar01.pc1 = 1
# 	 %SIGMA1@wn1.pc1 = 1
# 	 %SIGMA1@wn2.pc1 = 124300000
#
# *** Simulation 5 / 5 (elapsed time: 0.00465 mins) ***
#
#  best y: 628.882364894258
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc1 = 0.04984
# 	 %ALPHA1@sePar01.pc1 = 1
# 	 %SIGMA1@wn1.pc1 = 1
# 	 %SIGMA1@wn2.pc1 = 124300000
#
# *** Simulation 6 / 5 (elapsed time: 0.00528 mins) ***
#
#  best y: 628.882364894258
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc1 = 0.04984
# 	 %ALPHA1@sePar01.pc1 = 1
# 	 %SIGMA1@wn1.pc1 = 1
# 	 %SIGMA1@wn2.pc1 = 124300000
#
# ### NELDER-MEAD DOWNHILL SIMPLEX ALGORITHM ###
#
#  Version: amoeba
#  Start time: 2026-06-15 14:49:34.874072
#  Number of simulations: 5
#
#
# *** Simulation 1 / 5 (elapsed time: 0.000958 mins) ***
#
#  best y: 242.544976303614
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc2 = 0.9901
# 	 %ALPHA1@sePar01.pc2 = 1
# 	 %SIGMA1@wn1.pc2 = 0.9939
# 	 %SIGMA1@wn2.pc2 = 6758000
#
# *** Simulation 2 / 5 (elapsed time: 0.00222 mins) ***
#
#  best y: 413.545137722621
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc2 = 0.09414
# 	 %ALPHA1@sePar01.pc2 = 0.9995
# 	 %SIGMA1@wn1.pc2 = 0.9998
# 	 %SIGMA1@wn2.pc2 = 6785000
#
# *** Simulation 3 / 5 (elapsed time: 0.00352 mins) ***
#
#  best y: 413.550234054465
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc2 = 0.08122
# 	 %ALPHA1@sePar01.pc2 = 0.9995
# 	 %SIGMA1@wn1.pc2 = 0.9998
# 	 %SIGMA1@wn2.pc2 = 6770000
#
# *** Simulation 4 / 5 (elapsed time: 0.00434 mins) ***
#
#  best y: 413.550234054465
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc2 = 0.08122
# 	 %ALPHA1@sePar01.pc2 = 0.9995
# 	 %SIGMA1@wn1.pc2 = 0.9998
# 	 %SIGMA1@wn2.pc2 = 6770000
#
# *** Simulation 5 / 5 (elapsed time: 0.00514 mins) ***
#
#  best y: 413.550234054465
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc2 = 0.08122
# 	 %ALPHA1@sePar01.pc2 = 0.9995
# 	 %SIGMA1@wn1.pc2 = 0.9998
# 	 %SIGMA1@wn2.pc2 = 6770000
#
# *** Simulation 6 / 5 (elapsed time: 0.00641 mins) ***
#
#  best y: 413.550234054465
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc2 = 0.08122
# 	 %ALPHA1@sePar01.pc2 = 0.9995
# 	 %SIGMA1@wn1.pc2 = 0.9998
# 	 %SIGMA1@wn2.pc2 = 6770000
#
# ### NELDER-MEAD DOWNHILL SIMPLEX ALGORITHM ###
#
#  Version: amoeba
#  Start time: 2026-06-15 14:49:35.304533
#  Number of simulations: 5
#
#
# *** Simulation 1 / 5 (elapsed time: 0.00197 mins) ***
#
#  best y: 275.140034404132
#  best z:
# 	 %RHO@window_opening_ach%@sePar01.pc3 = 0.1656
# 	 %RHO@infl_rate_m3ph_m2%@sePar01.pc3 = 0.4958
# 	 %ALPHA1@sePar01.pc3 = 0.9991
# 	 %SIGMA1@wn1.pc3 = 0.9967
# 	 %SIGMA1@wn2.pc3 = 36460
#
# *** Simulation 2 / 5 (elapsed time: 0.00341 mins) ***
#
#  best y: 275.140034404132
#  best z:
# 	 %RHO@window_opening_ach%@sePar01.pc3 = 0.1656
# 	 %RHO@infl_rate_m3ph_m2%@sePar01.pc3 = 0.4958
# 	 %ALPHA1@sePar01.pc3 = 0.9991
# 	 %SIGMA1@wn1.pc3 = 0.9967
# 	 %SIGMA1@wn2.pc3 = 36460
#
# *** Simulation 3 / 5 (elapsed time: 0.00457 mins) ***
#
#  best y: 275.140034404132
#  best z:
# 	 %RHO@window_opening_ach%@sePar01.pc3 = 0.1656
# 	 %RHO@infl_rate_m3ph_m2%@sePar01.pc3 = 0.4958
# 	 %ALPHA1@sePar01.pc3 = 0.9991
# 	 %SIGMA1@wn1.pc3 = 0.9967
# 	 %SIGMA1@wn2.pc3 = 36460
#
# ### NELDER-MEAD DOWNHILL SIMPLEX ALGORITHM ###
#
#  Version: amoeba
#  Start time: 2026-06-15 14:49:35.625975
#  Number of simulations: 5
#
#
# *** Simulation 1 / 5 (elapsed time: 0.00157 mins) ***
#
#  best y: 255.33778713018
#  best z:
# 	 %RHO@window_opening_ach%@sePar01.pc4 = 0.1043
# 	 %ALPHA1@sePar01.pc4 = 0.9996
# 	 %SIGMA1@wn1.pc4 = 0.995
# 	 %SIGMA1@wn2.pc4 = 15700
#
# *** Simulation 2 / 5 (elapsed time: 0.00213 mins) ***
#
#  best y: 255.33778713018
#  best z:
# 	 %RHO@window_opening_ach%@sePar01.pc4 = 0.1043
# 	 %ALPHA1@sePar01.pc4 = 0.9996
# 	 %SIGMA1@wn1.pc4 = 0.995
# 	 %SIGMA1@wn2.pc4 = 15700
#
# *** Simulation 3 / 5 (elapsed time: 0.00285 mins) ***
#
#  best y: 255.33778713018
#  best z:
# 	 %RHO@window_opening_ach%@sePar01.pc4 = 0.1043
# 	 %ALPHA1@sePar01.pc4 = 0.9996
# 	 %SIGMA1@wn1.pc4 = 0.995
# 	 %SIGMA1@wn2.pc4 = 15700
#
# ### ADAPTIVE METROPOLIS WITHIN GIBBS ALGORITHM ###
#
#  Start time: 2026-06-15 14:49:36.761987
#  Number of chains: 1
#  Number of simulations: <until converged>
#
# *** Simulation 5 / <until converged> (elapsed time: 0.0218 mins) ***
#
# Iterations = 50:1846
# Thinning interval = 4
# Number of chains = 1
# Sample size per chain = 450
#
# 1. Empirical mean and standard deviation for each variable,
#    plus standard error of the mean:
#
#                         Mean        SD  Naive SE Time-series SE        t
# t_set_heating      9.681e-01 6.352e-02 2.994e-03      1.043e-02 0.010771
# window_opening_ach 4.040e-01 2.825e-01 1.332e-02      2.421e-02 0.059910
# %SIGMA@wn2*.pc.mu% 2.806e+05 3.974e+04 1.873e+03      2.608e+03 0.009295
# %SIGMA@wn2*.pc1%   2.414e+04 4.777e+03 2.252e+02      4.458e+02 0.018469
# %SIGMA@wn2*.pc2%   1.996e+03 3.224e+02 1.520e+01      3.234e+01 0.016204
# infl_rate_m3ph_m2  4.831e-01 2.889e-01 1.362e-02      1.942e-02 0.040204
# %SIGMA@wn2*.pc3%   1.235e+01 1.754e+00 8.270e-02      1.837e-01 0.014877
# %SIGMA@wn2*.pc4%   4.542e+00 5.917e-01 2.789e-02      3.335e-02 0.007341
#                        eff      s
# t_set_heating      0.08247  37.11
# window_opening_ach 0.30273 136.23
# %SIGMA@wn2*.pc.mu% 0.51577 232.09
# %SIGMA@wn2*.pc1%   0.25516 114.82
# %SIGMA@wn2*.pc2%   0.22078  99.35
# infl_rate_m3ph_m2  0.49154 221.19
# %SIGMA@wn2*.pc3%   0.20267  91.20
# %SIGMA@wn2*.pc4%   0.69965 314.84
#
# 2. Quantiles for each variable:
#
#                         2.5%       25%       50%       75%     97.5%
# t_set_heating      7.156e-01 9.716e-01 9.850e-01 9.924e-01 9.990e-01
# window_opening_ach 1.633e-02 1.726e-01 3.409e-01 5.823e-01 9.617e-01
# %SIGMA@wn2*.pc.mu% 2.123e+05 2.498e+05 2.785e+05 3.078e+05 3.610e+05
# %SIGMA@wn2*.pc1%   1.631e+04 2.110e+04 2.384e+04 2.674e+04 3.458e+04
# %SIGMA@wn2*.pc2%   1.323e+03 1.777e+03 2.015e+03 2.195e+03 2.624e+03
# infl_rate_m3ph_m2  2.322e-02 2.163e-01 4.825e-01 7.465e-01 9.446e-01
# %SIGMA@wn2*.pc3%   9.152e+00 1.105e+01 1.222e+01 1.352e+01 1.591e+01
# %SIGMA@wn2*.pc4%   3.425e+00 4.138e+00 4.525e+00 4.953e+00 5.656e+00
#
# *** Simulation 10 / <until converged> (elapsed time: 0.0347 mins) ***
#
# Iterations = 100:3696
# Thinning interval = 4
# Number of chains = 1
# Sample size per chain = 900
#
# 1. Empirical mean and standard deviation for each variable,
#    plus standard error of the mean:
#
#                         Mean        SD  Naive SE Time-series SE        t    eff
# t_set_heating      9
n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\nIterations = 7100:262696\nThinning interval = 4 \nNumber of chains = 1 \nSample size per chain = 63900 \n\n1. Empirical mean and standard deviation for each variable,\n   plus standard error of the mean:\n\n                        Mean        SD  Naive SE Time-series SE         t\nt_set_heating      9.553e-01 8.682e-02 3.435e-04      2.749e-03 0.0028774\nwindow_opening_ach 4.077e-01 2.690e-01 1.064e-03      2.103e-03 0.0051582\n%SIGMA@wn2*.pc.mu% 2.793e+05 4.044e+04 1.600e+02      1.910e+02 0.0006838\n%SIGMA@wn2*.pc1%   2.408e+04 4.620e+03 1.828e+01      5.931e+01 0.0024631\n%SIGMA@wn2*.pc2%   1.955e+03 3.347e+02 1.324e+00      4.955e+00 0.0025341\ninfl_rate_m3ph_m2  5.174e-01 2.876e-01 1.138e-03      1.392e-03 0.0026894\n%SIGMA@wn2*.pc3%   1.234e+01 1.777e+00 7.030e-03      8.364e-03 0.0006780\n%SIGMA@wn2*.pc4%   4.542e+00 6.597e-01 2.610e-03      3.089e-03 0.0006802\n                       eff       s\nt_set_heating      0.01561   997.6\nwindow_opening_ach 0.25595 16355.1\n%SIGMA@wn2*.pc.mu% 0.70198 44856.3\n%SIGMA@wn2*.pc1%   0.09499  6069.7\n%SIGMA@wn2*.pc2%   0.07140  4562.5\ninfl_rate_m3ph_m2  0.66852 42718.6\n%SIGMA@wn2*.pc3%   0.70640 45139.1\n%SIGMA@wn2*.pc4%   0.71385 45614.9\n\n2. Quantiles for each variable:\n\n                        2.5%       25%       50%       75%     97.5%\nt_set_heating      6.457e-01 9.675e-01 9.865e-01 9.947e-01 9.995e-01\nwindow_opening_ach 2.426e-02 1.985e-01 3.527e-01 5.756e-01 9.710e-01\n%SIGMA@wn2*.pc.mu% 2.059e+05 2.510e+05 2.775e+05 3.053e+05 3.641e+05\n%SIGMA@wn2*.pc1%   1.634e+04 2.086e+04 2.361e+04 2.675e+04 3.456e+04\n%SIGMA@wn2*.pc2%   1.281e+03 1.737e+03 1.954e+03 2.173e+03 2.625e+03\ninfl_rate_m3ph_m2  2.764e-02 2.705e-01 5.296e-01 7.671e-01 9.774e-01\n%SIGMA@wn2*.pc3%   9.101e+00 1.109e+01 1.225e+01 1.348e+01 1.604e+01\n%SIGMA@wn2*.pc4%   3.344e+00 4.077e+00 4.507e+00 4.971e+00 5.913e+00\n\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '*** Simulation 715 / <until converged> (elapsed time: 2.37 mins) ***\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\nIterations = 7150:264546\nThinning interval = 4 \nNumber of chains = 1 \nSample size per chain = 64350 \n\n1. Empirical mean and standard deviation for each variable,\n   plus standard error of the mean:\n\n                        Mean        SD  Naive SE Time-series SE         t\nt_set_heating      9.549e-01 8.744e-02 3.447e-04      2.777e-03 0.0029084\nwindow_opening_ach 4.078e-01 2.689e-01 1.060e-03      2.095e-03 0.0051388\n%SIGMA@wn2*.pc.mu% 2.793e+05 4.042e+04 1.593e+02      1.902e+02 0.0006809\n%SIGMA@wn2*.pc1%   2.409e+04 4.626e+03 1.823e+01      5.986e+01 0.0024851\n%SIGMA@wn2*.pc2%   1.954e+03 3.351e+02 1.321e+00      4.999e+00 0.0025579\ninfl_rate_m3ph_m2  5.173e-01 2.876e-01 1.134e-03      1.387e-03 0.0026821\n%SIGMA@wn2*.pc3%   1.234e+01 1.777e+00 7.004e-03      8.331e-03 0.0006753\n%SIGMA@wn2*.pc4%   4.542e+00 6.594e-01 2.600e-03      3.078e-03 0.0006777\n                       eff       s\nt_set_heating      0.01540   991.2\nwindow_opening_ach 0.25584 16463.2\n%SIGMA@wn2*.pc.mu% 0.70216 45184.0\n%SIGMA@wn2*.pc1%   0.09280  5971.8\n%SIGMA@wn2*.pc2%   0.06984  4494.4\ninfl_rate_m3ph_m2  0.66795 42982.5\n%SIGMA@wn2*.pc3%   0.70680 45482.4\n%SIGMA@wn2*.pc4%   0.71343 45909.3\n\n2. Quantiles for each variable:\n\n                        2.5%       25%       50%       75%     97.5%\nt_set_heating      6.447e-01 9.673e-01 9.865e-01 9.947e-01 9.995e-01\nwindow_opening_ach 2.424e-02 1.987e-01 3.528e-01 5.756e-01 9.710e-01\n%SIGMA@wn2*.pc.mu% 2.060e+05 2.510e+05 2.775e+05 3.053e+05 3.640e+05\n%SIGMA@wn2*.pc1%   1.635e+04 2.086e+04 2.362e+04 2.677e+04 3.457e+04\n%SIGMA@wn2*.pc2%   1.279e+03 1.736e+03 1.953e+03 2.173e+03 2.625e+03\ninfl_rate_m3ph_m2  2.759e-02 2.702e-01 5.292e-01 7.670e-01 9.774e-01\n%SIGMA@wn2*.pc3%   9.100e+00 1.109e+01 1.225e+01 1.348e+01 1.604e+01\n%SIGMA@wn2*.pc4%   3.345e+00 4.078e+00 4.508e+00 4.971e+00 5.913e+00\n\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '*** Simulation 720 / <until converged> (elapsed time: 2.39 mins) ***\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\nIterations = 7200:266396\nThinning interval = 4 \nNumber of chains = 1 \nSample size per chain = 64800 \n\n1. Empirical mean and standard deviation for each variable,\n   plus standard error of the mean:\n\n                        Mean        SD  Naive SE Time-series SE         t\nt_set_heating      9.546e-01 8.785e-02 3.451e-04      2.768e-03 0.0029001\nwindow_opening_ach 4.081e-01 2.690e-01 1.057e-03      2.094e-03 0.0051310\n%SIGMA@wn2*.pc.mu% 2.793e+05 4.042e+04 1.588e+02      1.895e+02 0.0006783\n%SIGMA@wn2*.pc1%   2.410e+04 4.631e+03 1.819e+01      6.002e+01 0.0024909\n%SIGMA@wn2*.pc2%   1.954e+03 3.353e+02 1.317e+00      4.983e+00 0.0025505\ninfl_rate_m3ph_m2  5.174e-01 2.876e-01 1.130e-03      1.383e-03 0.0026729\n%SIGMA@wn2*.pc3%   1.234e+01 1.776e+00 6.975e-03      8.296e-03 0.0006725\n%SIGMA@wn2*.pc4%   4.542e+00 6.594e-01 2.591e-03      3.069e-03 0.0006757\n                       eff     s\nt_set_heating      0.01554  1007\nwindow_opening_ach 0.25463 16500\n%SIGMA@wn2*.pc.mu% 0.70231 45510\n%SIGMA@wn2*.pc1%   0.09186  5952\n%SIGMA@wn2*.pc2%   0.06988  4528\ninfl_rate_m3ph_m2  0.66736 43245\n%SIGMA@wn2*.pc3%   0.70692 45808\n%SIGMA@wn2*.pc4%   0.71263 46178\n\n2. Quantiles for each variable:\n\n                        2.5%       25%       50%       75%     97.5%\nt_set_heating      6.437e-01 9.671e-01 9.865e-01 9.947e-01 9.995e-01\nwindow_opening_ach 2.416e-02 1.988e-01 3.533e-01 5.763e-01 9.711e-01\n%SIGMA@wn2*.pc.mu% 2.061e+05 2.511e+05 2.775e+05 3.054e+05 3.640e+05\n%SIGMA@wn2*.pc1%   1.635e+04 2.087e+04 2.362e+04 2.678e+04 3.459e+04\n%SIGMA@wn2*.pc2%   1.278e+03 1.735e+03 1.953e+03 2.172e+03 2.625e+03\ninfl_rate_m3ph_m2  2.767e-02 2.703e-01 5.293e-01 7.671e-01 9.774e-01\n%SIGMA@wn2*.pc3%   9.102e+00 1.110e+01 1.225e+01 1.348e+01 1.604e+01\n%SIGMA@wn2*.pc4%   3.344e+00 4.078e+00 4.508e+00 4.971e+00 5.913e+00\n\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '$CALIBRATION_RESULTS\n           PARAMETER    ESTIMATE       LOWER      UPPER\n1      t_set_heating 23.07254404 21.83810830 23.0744492\n2 window_opening_ach  0.07868902  0.02624073  0.2123358\n3  infl_rate_m3ph_m2  4.18801754  3.64707975  4.3966044\n\n$CALIBRATED_MODEL_GOF\n            sim       cals\ndata1 0.0797525 0.08107992\n\n'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': "Warning messages:\n1: encountered a tie, and the difference between minimal and \n                   maximal value is > length('x') * 'tie.limit'\nthe distribution could be multimodal \n2: encountered a tie, and the difference between minimal and \n                   maximal value is > length('x') * 'tie.limit'\nthe distribution could be multimodal \n3: encountered a tie, and the difference between minimal and \n                   maximal value is > length('x') * 'tie.limit'\nthe distribution could be multimodal \n4: encountered a tie, and the difference between minimal and \n                   maximal value is > length('x') * 'tie.limit'\nthe distribution could be multimodal \n5: encountered a tie, and the difference between minimal and \n                   maximal value is > length('x') * 'tie.limit'\nthe distribution could be multimodal \n6: encountered a tie, and the difference between minimal and \n                   maximal value is > length('x') * 'tie.limit'\nthe distribution could be multimodal \n7: encountered a tie, and the difference between minimal and \n                   maximal value is > length('x') * 'tie.limit'\nthe distribution could be multimodal \n"},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': "Warning messages:\n1: encountered a tie, and the difference between minimal and \n                   maximal value is > length('x') * 'tie.limit'\nthe distribution could be multimodal \n2: encountered a tie, and the difference between minimal and \n                   maximal value is > length('x') * 'tie.limit'\nthe distribution could be multimodal \n3: encountered a tie, and the difference between minimal and \n                   maximal value is > length('x') * 'tie.limit'\nthe distribution could be multimodal \n4: encountered a tie, and the difference between minimal and \n                   maximal value is > length('x') * 'tie.limit'\nthe distribution could be multimodal \n5: encountered a tie, and the difference between minimal and \n                   maximal value is > length('x') * 'tie.limit'\nthe distribution could be multimodal \n6: encountered a tie, and the difference between minimal and \n                   maximal value is > length('x') * 'tie.limit'\nthe distribution could be multimodal \n7: encountered a tie, and the difference between minimal and \n                   maximal value is > length('x') * 'tie.limit'\nthe distribution could be multimodal \n"},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\n\nprocessing file: /opt/homebrew/lib/R/4.3/site-library/calibro/calibro_report.Rnw\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '1/44             \n2/44 [setup]     \n3/44             \n4/44 [exeSumm]   \n5/44             \n6/44 [content]   \n7/44             \n8/44 [genVar]    \n9/44             \n10/44 [dsVar]     \n11/44 [dsText]    \n12/44             \n13/44 [ds1]       \n14/44 [ds2]       \n15/44 [ds3]       \n16/44 [ds4]       \n17/44 [ds5]       \n18/44 [ds6]       \n19/44 [ds7]       \n20/44 [ds8]       \n21/44 [ds9]       \n22/44 [ds10]      \n23/44             \n24/44 [saVar]     \n25/44 [saText]    \n26/44             \n27/44 [ret_tables]\n28/44             \n29/44 [train]     \n30/44             \n31/44 [calVar]    \n32/44 [cal]       \n33/44 [thetaplot] \n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '34/44 [ds1fit]    \n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '35/44 [ds2fit]    \n36/44 [ds3fit]    \n37/44 [ds4fit]    \n38/44 [ds5fit]    \n39/44 [ds6fit]    \n40/44 [ds7fit]    \n41/44 [ds8fit]    \n42/44 [ds9fit]    \n43/44 [ds10fit]   \n44/44             \n'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': 'output file: calibro_report.tex\n\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '[1] "calibro_report.pdf"\n✓ Calibro finished successfully.\n\n🎉 Experiment complete. Results saved to: /Users/rui.bo/Desktop/BASE/1_phd/Y3/RC_br/_json/_run/JUN11/calibro\n'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': "Warning: LaTeX Warning: `!h' float specifier changed to `!ht'.\nWarning: LaTeX Warning: `!h' float specifier changed to `!ht'.\nWarning messages:\n1: encountered a tie, and the difference between minimal and \n                   maximal value is > length('x') * 'tie.limit'\nthe distribution could be multimodal \n2: encountered a tie, and the difference between minimal and \n                   maximal value is > length('x') * 'tie.limit'\nthe distribution could be multimodal \n3: encountered a tie, and the difference between minimal and \n                   maximal value is > length('x') * 'tie.limit'\nthe distribution could be multimodal \n4: encountered a tie, and the difference between minimal and \n                   maximal value is > length('x') * 'tie.limit'\nthe distribution could be multimodal \n5: encountered a tie, and the difference between minimal and \n                   maximal value is > length('x') * 'tie.limit'\nthe distribution could be multimodal \n6: encountered a tie, and the difference between minimal and \n                   maximal value is > length('x') * 'tie.limit'\nthe distribution could be multimodal \n7: encountered a tie, and the difference between minimal and \n                   maximal value is > length('x') * 'tie.limit'\nthe distribution could be multimodal \n"}],
#    'source': 'r_code = f"""\nsetwd("{output_dir}")\n\nlibrary(calibro)\n\nCE <- calEnv$new(name = \'{CALIBRO_NAME}\')\n\nCE$add.ds(\n    name = \'data1\',\n    Y.star = \'{data_dir}/obs.csv\',\n    TT     = \'{data_dir}/TT.csv\',\n    Y      = \'{data_dir}/Y.csv\'\n)\n\nCE$rd = \'pca\'\nCE$sa = \'sobolSmthSpl\'\nCE$ret = list(mthd = \'ng.screening\')\nCE$mdls = \'gpr.ng.sePar01_whitePar01\'\nCE$train = list(type = \'training\', alg = \'amoeba\')\nCE$cals = \'cal.gpr.ng\'\nCE$cal.mcmc = list(alg = \'amg\')\n\nCE$cal.res()\n\nM <- CE$cal.mcmc\nZ <- M$Z\n# z_map <- as.data.frame(t(M$bestz))\n\nif (inherits(Z, "mcmc.list")) {{\nZ <- do.call(rbind, lapply(Z, as.matrix))\n}} else {{\nZ <- as.matrix(Z)\n}}\n\n\nwrite.csv(Z, "posterior_draws_Z.csv", row.names = FALSE)\n# write.csv(z_map, "z_map.csv", row.names = FALSE)\ntheta <- CE$cal.res(mode = "theta")\nwrite.csv(theta, "theta_physical_summary.csv", row.names = FALSE)\n\nCE$genReport(\ntype = "pdf",\nout = c("dss", "cal")\n)\n"""\nr_script_path = code_dir / "run_calibro.R"\n\nr_code = r_code\n\nwith open(r_script_path, "w") as f:\n    f.write(r_code)\n\nprint("[INFO] R script generated:", r_script_path)\n\n\n# ================================================================\n# 6. Run Rscript\n# ================================================================\nprint("\\n[INFO] Running Calibro Rscript...")\ncmd = [RSCRIPT_BIN, str(r_script_path)]\nresult = subprocess.run(cmd)\nif result.returncode == 0:\n    print("✓ Calibro finished successfully.")\nelse:\n    print("❌ Calibro failed.")\n\n\nprint(f"\\n🎉 Experiment complete. Results saved to: {output_dir}")',
#    'id': '7d95cea0'},
#   {'cell_type': 'code',
#    'execution_count': None,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2026-06-15T13:52:06.758586',
#      'end_time': '2026-06-15T13:52:06.765239',
#      'duration': 0.006653,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': '',
#    'id': '47ca4d71'}],
#  'metadata': {'kernelspec': {'display_name': 'eplus_env',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.10.4',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'orig_nbformat_minor': 2,
#   'papermill': {'default_parameters': {},
#    'parameters': {'DATE': 'JUN11',
#     'START_DATE': '2023-02-01 00:00',
#     'END_DATE': '2023-03-10 23:00'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '1_CALIBRO.ipynb',
#    'output_path': 'JUN11.ipynb',
#    'start_time': '2026-06-15T13:49:18.080683',
#    'end_time': '2026-06-15T13:52:06.887025',
#    'duration': 168.806342,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %%
import papermill as pm

NOTEBOOK_IN = "1_PLOT_map.ipynb"

pm.execute_notebook(
    NOTEBOOK_IN,
    f"{DATE}.ipynb",
    parameters={
        "DATE": DATE,
        "START_DATE": start,
        "END_DATE": end,
    },
)
# Out:
# Passed unknown parameter: DATE
# Passed unknown parameter: START_DATE
# Passed unknown parameter: END_DATE
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/1 [00:00<?, ?cell/s]
# {'cells': [{'id': 'bc45cb69',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2026-06-15T13:52:07.485809',
#      'end_time': '2026-06-15T13:52:07.503003',
#      'duration': 0.017194,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2026-06-15T13:52:07.491088Z',
#      'iopub.execute_input': '2026-06-15T13:52:07.491709Z',
#      'iopub.status.idle': '2026-06-15T13:52:07.501387Z',
#      'shell.execute_reply': '2026-06-15T13:52:07.500674Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nDATE = "JUN11"\nSTART_DATE = "2023-02-01 00:00"\nEND_DATE = "2023-03-10 23:00"\n',
#    'outputs': []}],
#  'metadata': {'kernelspec': {'display_name': 'eplus_env',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.10.4',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'orig_nbformat_minor': 2,
#   'papermill': {'default_parameters': {},
#    'parameters': {'DATE': 'JUN11',
#     'START_DATE': '2023-02-01 00:00',
#     'END_DATE': '2023-03-10 23:00'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '1_PLOT_map.ipynb',
#    'output_path': 'JUN11.ipynb',
#    'start_time': '2026-06-15T13:52:06.932089',
#    'end_time': '2026-06-15T13:52:07.622313',
#    'duration': 0.690224,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %% [markdown]
# # Posterior SIM

# %%
posterior_TT = f'_json/_run/{DATE}/calibro/posterior_rand10_from_topfrac.csv'
# If posterior_TT is a string (file path)
posterior_TT = pd.read_csv(posterior_TT)

# %%
def make_ecm_specs(case):
    default_win = case.default_params["window_opening_ach"]

    return {
        "Baseline": {},

        "ECM-1_setpoint_19C": {
            "t_set_heating": 19.5,
        },

        "ECM-2_reschedule_8_8_8": {
            "heating_schedule_mode": "8_8_8",
        },

        "ECM-3_setpoint_19C_reschedule_8_8_8": {
            "t_set_heating": 19.5,
            "heating_schedule_mode": "8_8_8",
        },

        "ECM-4_setpoint_19C_default_infiltration": {
            "t_set_heating": 19.5,
            "window_opening_ach": default_win,
        },

        "ECM-5_reschedule_8_8_8_default_infiltration": {
            "heating_schedule_mode": "8_8_8",
            "window_opening_ach": default_win,
        },
    }

# %%
ecm_specs = make_ecm_specs(case)
def run_posterior_ecm_samples(
    posterior_TT,
    extra_params=None,
    controller_mode=controller_mode,
):
    results = {}
    euis = {}

    if extra_params is None:
        extra_params = {}

    for sample_id, row in show_progress(
        posterior_TT.iterrows(),
        total=len(posterior_TT),
        desc="Running posterior samples",
        unit="sample",
    ):
        sampled_params = row.to_dict()
        sampled_params.update(extra_params)

        res, eui, _ = run_model_case(
            case=case,
            sampled_params=sampled_params,
            controller_mode=controller_mode,
        )

        results[sample_id] = res
        euis[sample_id] = eui

    eui_df = pd.DataFrame(euis).T

    return results, eui_df

def run_ecm_suite(
    posterior_TT,
    ecm_specs,
    controller_mode=controller_mode,
):
    all_results = {}
    all_euis = {}

    for ecm_name, extra_params in ecm_specs.items():
        results, eui_df = run_posterior_ecm_samples(
            posterior_TT=posterior_TT,
            extra_params=extra_params,
            controller_mode=controller_mode,
        )

        all_results[ecm_name] = results
        all_euis[ecm_name] = eui_df

    return all_results, all_euis
all_results, all_euis = run_ecm_suite(
    posterior_TT=posterior_TT,
    ecm_specs=ecm_specs,
)
# Out:
# Running posterior samples:   0%|          | 0/10 [00:00<?, ?sample/s]
# Running posterior samples:   0%|          | 0/10 [00:00<?, ?sample/s]
# Running posterior samples:   0%|          | 0/10 [00:00<?, ?sample/s]
# Running posterior samples:   0%|          | 0/10 [00:00<?, ?sample/s]
# Running posterior samples:   0%|          | 0/10 [00:00<?, ?sample/s]
# Running posterior samples:   0%|          | 0/10 [00:00<?, ?sample/s]

# %% [markdown]
# # Post-analysis

# %%
posterior_Y = make_posterior_Y_from_results(
    posterior_results=all_results["Baseline"],
    variable="HeatingEnergy",
    freq="D",
    start_date=start,
    end_date=end,
)

# %%
sim_summary = make_sim_summary(posterior_Y)

coverage = plot_heating_coverage(
    sim_summary=sim_summary,
    meter_series=meter_daily,
    start_date=start,
    end_date=end,
    y_label=r"Daily heating energy use (kWh m$^{-2}$ d$^{-1}$)",
    title="Daily heating-energy prediction across posterior samples"
)
# Out:
# Viewing period: 2023-02-01 00:00:00 to 2023-03-10 23:00:00
# Number of matched timesteps: 38
# Coverage by q05-q95: 13.2%
# Coverage by IQR: 5.3%

# %%
posterior_metric_rows = []

meter_eval = meter_daily.copy()
meter_eval.index = pd.to_datetime(meter_eval.index)
meter_eval = meter_eval.loc[start:end]

for sim_id in posterior_Y.columns[:10]:

    sim_eval = posterior_Y[sim_id].copy()
    sim_eval.index = pd.to_datetime(sim_eval.index)
    sim_eval = sim_eval.loc[start:end]

    cvrmse, nmbe = calc_metrics(
        sim=sim_eval,
        obs=meter_eval,
    )

    posterior_metric_rows.append(
        {
            "sim_id": sim_id,
            "period_start": start,
            "period_end": end,
            "freq": "daily",
            "cvrmse": cvrmse,
            "nmbe": nmbe,
        }
    )

posterior_metric_df = (
    pd.DataFrame(posterior_metric_rows)
      .set_index("sim_id")
)

posterior_metric_summary = posterior_metric_df[
    ["cvrmse", "nmbe"]
].agg(["mean", "median", "std", "min", "max"])

posterior_metric_df, posterior_metric_summary
# Out:
# (            period_start        period_end   freq     cvrmse       nmbe
#  sim_id
#  0       2023-02-01 00:00  2023-03-10 23:00  daily  33.006745 -11.689496
#  1       2023-02-01 00:00  2023-03-10 23:00  daily  34.611651 -14.848778
#  2       2023-02-01 00:00  2023-03-10 23:00  daily  36.599271 -18.189914
#  3       2023-02-01 00:00  2023-03-10 23:00  daily  32.229560 -10.542390
#  4       2023-02-01 00:00  2023-03-10 23:00  daily  35.328107 -16.200085
#  5       2023-02-01 00:00  2023-03-10 23:00  daily  30.260378  -5.544031
#  6       2023-02-01 00:00  2023-03-10 23:00  daily  32.281023 -10.728420
#  7       2023-02-01 00:00  2023-03-10 23:00  daily  30.542116  -5.988005
#  8       2023-02-01 00:00  2023-03-10 23:00  daily  32.710611 -11.065591
#  9       2023-02-01 00:00  2023-03-10 23:00  daily  30.004093  -4.354327,
#             cvrmse       nmbe
#  mean    32.757356 -10.915104
#  median  32.495817 -10.897006
#  std      2.213593   4.634320
#  min     30.004093 -18.189914
#  max     36.599271  -4.354327)

# %%
ecm_savings = compute_ecm_savings(
    all_results=all_results,
    baseline_name="Baseline",
    variable="HeatingEnergy",
    period_start=start,
    period_end=end,
    freq="D",
)

# %%
plot_ecm_savings_pair(
    savings_df=ecm_savings,
    kpi_label="Heating energy",
)
