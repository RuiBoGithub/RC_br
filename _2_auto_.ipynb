# %%
DATE = 'JUN11'
default_json  = '_json/default_params.json'
controller_mode = 'occupancy'
start = "2023-02-01 00:00"
end   = "2023-03-10 23:00"

# %%
from pathlib import Path
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json

RC_SIMULATOR = "ETHlib"
if RC_SIMULATOR not in sys.path:
    sys.path.insert(0, RC_SIMULATOR)

from _ import *
from _BR_ import *
from _zone_ import DebugZone as Zone
import supply_system
import emission_system
case = RCCase(
    year=2023,
    loc_json              = Path("_json/location_params.json"),
    geo_json              = Path("_json/geo_params.json"),
    default_json          = Path("_json/default_params.json"),
    epw_path              = Path("../src/_base/epw/ED-TMYx.2023.epw"),
    occupancy_profile_csv = Path("ETHlib/auxiliary/schedules_el_OFFICE.csv"),
    Zone=Zone,
    supply_system=supply_system,
    emission_system=emission_system,
)
case.occupancy_profile = (
    pd.read_csv(Path("_data/bldg_LoD.csv"), usecols=["D"])
      .rename(columns={"D": "People"})
      .iloc[:8760]
      .reset_index(drop=True)
)

# %%
DEFAULT_PARAMS = json.loads(Path(default_json).read_text())
RUN_DIR = Path(f"_json/_run/{DATE}")
uq_json_path = RUN_DIR / "OAT.json"

meter_path = "_data/Metering_ISO.csv"
meter_daily = load_meter_heating(
    meter_path,
    "Main Heating",
    case.geometry["FLOOR_AREA"],
    "D",
)
meter_hourly = load_meter_heating(
    meter_path,
    "Main Heating",
    case.geometry["FLOOR_AREA"],
    "h",
)
# Out:
# Metering Timestamp: 2023-01-01 00:00:00 ~ 2023-12-31 23:00:00
# Metering Timestamp: 2023-01-01 00:00:00 ~ 2023-12-31 23:00:00

# %% [markdown]
# # RUN

# %%
from _ import show_progress
from scipy.stats import qmc
def make_lhs_samples_from_uq_json(uq_json_path, N=100, save_csv=True):
    
    uq_json_path = Path(uq_json_path)

    with open(uq_json_path, "r", encoding="utf-8") as f:
        uq_config = json.load(f)

    N = N
    seed = uq_config["seed"]
    params = uq_config["parameters"]

    param_names = list(params.keys())
    n_dim = len(param_names)

    sampler = qmc.LatinHypercube(d=n_dim, seed=seed)
    lhs_unit = sampler.random(n=N)

    samples = pd.DataFrame(index=range(N), columns=param_names, dtype=float)

    for i, name in enumerate(param_names):
        lower = params[name]["lower"]
        upper = params[name]["upper"]

        samples[name] = lower + lhs_unit[:, i] * (upper - lower)

    samples.index = [f"sample_{i+1:03d}" for i in range(N)]

    if save_csv:
        output_path = uq_json_path.parent / f"LHS_samples.csv"
        samples.to_csv(output_path)
        print(f"Saved LHS samples to: {output_path}")

    return samples

def run_lhs_samples(
    lhs_samples,
    controller_mode="occupancy",
):
    results = {}
    euis = {}

    for sample_id, row in show_progress(
        lhs_samples.iterrows(),
        total=len(lhs_samples),
        desc="Running samples",
        unit="sample",
    ):
        sampled_params = row.to_dict()

        res, eui, _ = run_model_case(
            case=case,
            sampled_params=sampled_params,
            controller_mode=controller_mode,
        )

        results[sample_id] = res
        euis[sample_id] = eui

    eui_df = pd.DataFrame(euis).T

    return results, eui_df

# %%
lhs_samples= make_lhs_samples_from_uq_json(
uq_json_path=uq_json_path,
N=40
)

lhs_results_occ, lhs_eui_df_occ = run_lhs_samples(
lhs_samples  = lhs_samples,
controller_mode = controller_mode,
)
# Out:
# Saved LHS samples to: _json/_run/JUN11/LHS_samples.csv
# Running samples:   0%|          | 0/40 [00:00<?, ?sample/s]

# %%
def calc_metrics(sim, obs):
    df = pd.concat(
        [sim.rename("sim"), obs.rename("obs")],
        axis=1,
    ).dropna()

    error = df["obs"] - df["sim"]
    obs_mean = df["obs"].mean()

    cvrmse = np.sqrt(np.mean(error ** 2)) / obs_mean * 100
    nmbe = error.sum() / (len(df) * obs_mean) * 100

    return cvrmse, nmbe


def compare_lhs_to_meter(
    lhs_results,
    meter_series,
    variable="HeatingEnergy",
    freq_label="hourly",
):
    rows = []

    for sample_id, res in lhs_results.items():
        cvrmse, nmbe = calc_metrics(res[variable], meter_series)
        rows.append((sample_id, freq_label, cvrmse, nmbe))

    return pd.DataFrame(
        rows,
        columns=["sample_id", "freq", "cvrmse", "nmbe"],
    ).set_index("sample_id")

# %%
KPI = "HeatingEnergy"
temp_res = "D"

meter_series = meter_hourly.resample(temp_res).sum()

lhs_results_res = {
    sample_id: res[[KPI]].resample(temp_res).sum()
    for sample_id, res in lhs_results_occ.items()
}

lhs_metrics_res = compare_lhs_to_meter(
    lhs_results=lhs_results_res,
    meter_series=meter_series,
    variable=KPI,
    freq_label=temp_res,
)

# %% [markdown]
# # Training dataset for `calibro`
# * temp_res = "H"   # hourly
# * temp_res = "D"   # daily
# * temp_res = "W"   # weekly
# * temp_res = "ME"  # month-end

# %%
def save_bayesian_calibration_files(
    lhs_samples,
    lhs_results,
    meter_series,
    variable="HeatingEnergy",
    freq="D",
    start=None,
    end=None,
    output_dir=Path(f"json/UQ/{DATE}_lhs"),
):
    output_dir = Path(output_dir)
    output_dir.mkdir(parents=True, exist_ok=True)

    TT = lhs_samples.copy()

    def prepare_series(series):
        series = series.copy()

        if start is not None or end is not None:
            series = series.loc[start:end]

        if freq is not None:
            series = series.resample(freq).sum()

        return series

    Y = pd.DataFrame({
        sample_id: prepare_series(res[variable])
        for sample_id, res in lhs_results.items()
    })

    obs = prepare_series(meter_series)
    obs.name = "obs"

    common_index = obs.index.intersection(Y.index)

    obs = obs.loc[common_index]
    Y = Y.loc[common_index]

    # Drop index columns when saving to CSV
    TT.to_csv(output_dir / "TT.csv", index=False)
    Y.to_csv(output_dir / "Y.csv", index=False)
    obs.to_csv(output_dir / "obs.csv", index=False)

    print(f"Saved Bayesian calibration files to: {output_dir}")
    print(f"Period: {obs.index.min()} to {obs.index.max()}")
    print(f"TT shape:  {TT.shape}")
    print(f"Y shape:   {Y.shape}")
    print(f"obs shape: {obs.shape}")

    return TT, Y, obs

KPI = "HeatingEnergy"
temp_res = "D"

output_dir = RUN_DIR / "BC"

TT, Y, obs = save_bayesian_calibration_files(
    lhs_samples=lhs_samples,
    lhs_results=lhs_results_occ,
    meter_series=meter_hourly,
    variable=KPI,
    freq=temp_res,
    start=start,
    end=end,
    output_dir=output_dir,
)
# Out:
# Saved Bayesian calibration files to: _json/_run/JUN11/BC
# Period: 2023-02-01 00:00:00 to 2023-03-10 00:00:00
# TT shape:  (40, 4)
# Y shape:   (38, 40)
# obs shape: (38,)

# %% [markdown]
# # Execution of `Calibro`

# %%
import papermill as pm

NOTEBOOK_IN = "1_CALIBRO.ipynb"

pm.execute_notebook(
    NOTEBOOK_IN,
    f"{DATE}.ipynb",
    parameters={
        "DATE": DATE,
        "START_DATE": start,
        "END_DATE": end,
    },
)
# Out:
# Passed unknown parameter: DATE
# Passed unknown parameter: START_DATE
# Passed unknown parameter: END_DATE
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/4 [00:00<?, ?cell/s]
# Loading required package: R6
# Loading required package: coda
# Loading required package: parallel
# Loading required package: MASS
# Loading required package: modeest
# ### NELDER-MEAD DOWNHILL SIMPLEX ALGORITHM ###
#
#  Version: amoeba
#  Start time: 2026-06-14 22:02:48.91809
#  Number of simulations: 5
#
#
# *** Simulation 1 / 5 (elapsed time: 0.00117 mins) ***
#
#  best y: 243.803891033431
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc.mu = 1
# 	 %RHO@window_opening_ach%@sePar01.pc.mu = 1
# 	 %ALPHA1@sePar01.pc.mu = 1
# 	 %SIGMA1@wn1.pc.mu = 0.9998
# 	 %SIGMA1@wn2.pc.mu = 88410000
#
# *** Simulation 2 / 5 (elapsed time: 0.00196 mins) ***
#
#  best y: 266.555905949008
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc.mu = 0.3182
# 	 %RHO@window_opening_ach%@sePar01.pc.mu = 0.007931
# 	 %ALPHA1@sePar01.pc.mu = 0.9999
# 	 %SIGMA1@wn1.pc.mu = 0.9999
# 	 %SIGMA1@wn2.pc.mu = 89120000
#
# *** Simulation 3 / 5 (elapsed time: 0.00245 mins) ***
#
#  best y: 271.118950876529
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc.mu = 0.5128
# 	 %RHO@window_opening_ach%@sePar01.pc.mu = 0.6622
# 	 %ALPHA1@sePar01.pc.mu = 0.9999
# 	 %SIGMA1@wn1.pc.mu = 0.9999
# 	 %SIGMA1@wn2.pc.mu = 86990000
#
# *** Simulation 4 / 5 (elapsed time: 0.00281 mins) ***
#
#  best y: 271.118950876529
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc.mu = 0.5128
# 	 %RHO@window_opening_ach%@sePar01.pc.mu = 0.6622
# 	 %ALPHA1@sePar01.pc.mu = 0.9999
# 	 %SIGMA1@wn1.pc.mu = 0.9999
# 	 %SIGMA1@wn2.pc.mu = 86990000
#
# *** Simulation 5 / 5 (elapsed time: 0.00314 mins) ***
#
#  best y: 271.118950876529
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc.mu = 0.5128
# 	 %RHO@window_opening_ach%@sePar01.pc.mu = 0.6622
# 	 %ALPHA1@sePar01.pc.mu = 0.9999
# 	 %SIGMA1@wn1.pc.mu = 0.9999
# 	 %SIGMA1@wn2.pc.mu = 86990000
#
# *** Simulation 6 / 5 (elapsed time: 0.00344 mins) ***
#
#  best y: 271.905046128599
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc.mu = 0.3803
# 	 %RHO@window_opening_ach%@sePar01.pc.mu = 0.5018
# 	 %ALPHA1@sePar01.pc.mu = 0.9999
# 	 %SIGMA1@wn1.pc.mu = 0.9999
# 	 %SIGMA1@wn2.pc.mu = 88070000
#
# ### NELDER-MEAD DOWNHILL SIMPLEX ALGORITHM ###
#
#  Version: amoeba
#  Start time: 2026-06-14 22:02:49.171205
#  Number of simulations: 5
#
#
# *** Simulation 1 / 5 (elapsed time: 0.000476 mins) ***
#
#  best y: 266.556131497009
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc1 = 0.1207
# 	 %ALPHA1@sePar01.pc1 = 0.9999
# 	 %SIGMA1@wn1.pc1 = 0.9999
# 	 %SIGMA1@wn2.pc1 = 13580000
#
# *** Simulation 2 / 5 (elapsed time: 0.000749 mins) ***
#
#  best y: 266.556131497009
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc1 = 0.1207
# 	 %ALPHA1@sePar01.pc1 = 0.9999
# 	 %SIGMA1@wn1.pc1 = 0.9999
# 	 %SIGMA1@wn2.pc1 = 13580000
#
# *** Simulation 3 / 5 (elapsed time: 0.00101 mins) ***
#
#  best y: 266.556131497009
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc1 = 0.1207
# 	 %ALPHA1@sePar01.pc1 = 0.9999
# 	 %SIGMA1@wn1.pc1 = 0.9999
# 	 %SIGMA1@wn2.pc1 = 13580000
#
# ### NELDER-MEAD DOWNHILL SIMPLEX ALGORITHM ###
#
#  Version: amoeba
#  Start time: 2026-06-14 22:02:49.271307
#  Number of simulations: 5
#
#
# *** Simulation 1 / 5 (elapsed time: 0.000414 mins) ***
#
#  best y: 143.163468075349
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc2 = 0.1929
# 	 %ALPHA1@sePar01.pc2 = 0.9981
# 	 %SIGMA1@wn1.pc2 = 0.9996
# 	 %SIGMA1@wn2.pc2 = 926700
#
# *** Simulation 2 / 5 (elapsed time: 0.000644 mins) ***
#
#  best y: 143.163468075349
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc2 = 0.1929
# 	 %ALPHA1@sePar01.pc2 = 0.9981
# 	 %SIGMA1@wn1.pc2 = 0.9996
# 	 %SIGMA1@wn2.pc2 = 926700
#
# *** Simulation 3 / 5 (elapsed time: 0.00101 mins) ***
#
#  best y: 161.042139005673
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc2 = 0.1105
# 	 %ALPHA1@sePar01.pc2 = 0.9984
# 	 %SIGMA1@wn1.pc2 = 0.9996
# 	 %SIGMA1@wn2.pc2 = 746900
#
# *** Simulation 4 / 5 (elapsed time: 0.00125 mins) ***
#
#  best y: 161.042139005673
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc2 = 0.1105
# 	 %ALPHA1@sePar01.pc2 = 0.9984
# 	 %SIGMA1@wn1.pc2 = 0.9996
# 	 %SIGMA1@wn2.pc2 = 746900
#
# *** Simulation 5 / 5 (elapsed time: 0.00148 mins) ***
#
#  best y: 161.042139005673
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc2 = 0.1105
# 	 %ALPHA1@sePar01.pc2 = 0.9984
# 	 %SIGMA1@wn1.pc2 = 0.9996
# 	 %SIGMA1@wn2.pc2 = 746900
#
# *** Simulation 6 / 5 (elapsed time: 0.00179 mins) ***
#
#  best y: 161.045672495397
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc2 = 0.104
# 	 %ALPHA1@sePar01.pc2 = 0.9984
# 	 %SIGMA1@wn1.pc2 = 0.9996
# 	 %SIGMA1@wn2.pc2 = 744300
#
# ### NELDER-MEAD DOWNHILL SIMPLEX ALGORITHM ###
#
#  Version: amoeba
#  Start time: 2026-06-14 22:02:49.420866
#  Number of simulations: 5
#
#
# *** Simulation 1 / 5 (elapsed time: 0.000435 mins) ***
#
#  best y: 103.825677855465
#  best z:
# 	 %RHO@window_opening_ach%@sePar01.pc3 = 0.1289
# 	 %ALPHA1@sePar01.pc3 = 0.9983
# 	 %SIGMA1@wn1.pc3 = 0.9926
# 	 %SIGMA1@wn2.pc3 = 2757
#
# *** Simulation 2 / 5 (elapsed time: 8e-04 mins) ***
#
#  best y: 103.828681389213
#  best z:
# 	 %RHO@window_opening_ach%@sePar01.pc3 = 0.1488
# 	 %ALPHA1@sePar01.pc3 = 0.9984
# 	 %SIGMA1@wn1.pc3 = 0.9926
# 	 %SIGMA1@wn2.pc3 = 2759
#
# *** Simulation 3 / 5 (elapsed time: 0.00102 mins) ***
#
#  best y: 103.828681389213
#  best z:
# 	 %RHO@window_opening_ach%@sePar01.pc3 = 0.1488
# 	 %ALPHA1@sePar01.pc3 = 0.9984
# 	 %SIGMA1@wn1.pc3 = 0.9926
# 	 %SIGMA1@wn2.pc3 = 2759
#
# ### ADAPTIVE METROPOLIS WITHIN GIBBS ALGORITHM ###
#
#  Start time: 2026-06-14 22:02:50.183428
#  Number of chains: 1
#  Number of simulations: <until converged>
#
# *** Simulation 5 / <until converged> (elapsed time: 0.00967 mins) ***
#
# Iterations = 50:1846
# Thinning interval = 4
# Number of chains = 1
# Sample size per chain = 450
#
# 1. Empirical mean and standard deviation for each variable,
#    plus standard error of the mean:
#
#                         Mean        SD  Naive SE Time-series SE        t    eff
# t_set_heating      9.244e-01 8.650e-02 4.078e-03      9.418e-03 0.010189 0.1875
# window_opening_ach 4.839e-01 2.472e-01 1.165e-02      1.942e-02 0.040143 0.3599
# %SIGMA@wn2*.pc.mu% 1.165e+05 1.576e+04 7.428e+02      1.018e+03 0.008736 0.5328
# %SIGMA@wn2*.pc1%   1.124e+04 2.000e+03 9.427e+01      1.247e+02 0.011087 0.5718
# %SIGMA@wn2*.pc2%   8.255e+02 1.379e+02 6.499e+00      1.038e+01 0.012572 0.3921
# %SIGMA@wn2*.pc3%   3.718e+00 5.165e-01 2.435e-02      2.837e-02 0.007630 0.7366
#                         s
# t_set_heating       84.36
# window_opening_ach 161.96
# %SIGMA@wn2*.pc.mu% 239.78
# %SIGMA@wn2*.pc1%   257.33
# %SIGMA@wn2*.pc2%   176.44
# %SIGMA@wn2*.pc3%   331.46
#
# 2. Quantiles for each variable:
#
#                         2.5%       25%       50%       75%     97.5%
# t_set_heating      6.744e-01 8.971e-01 9.570e-01 9.870e-01 9.989e-01
# window_opening_ach 5.463e-02 2.885e-01 4.852e-01 6.623e-01 9.405e-01
# %SIGMA@wn2*.pc.mu% 8.567e+04 1.067e+05 1.164e+05 1.251e+05 1.484e+05
# %SIGMA@wn2*.pc1%   8.012e+03 9.794e+03 1.110e+04 1.239e+04 1.527e+04
# %SIGMA@wn2*.pc2%   5.635e+02 7.363e+02 8.207e+02 9.092e+02 1.120e+03
# %SIGMA@wn2*.pc3%   2.807e+00 3.364e+00 3.676e+00 4.052e+00 4.770e+00
#
# *** Simulation 10 / <until converged> (elapsed time: 0.0141 mins) ***
#
# Iterations = 100:3696
# Thinning interval = 4
# Number of chains = 1
# Sample size per chain = 900
#
# 1. Empirical mean and standard deviation for each variable,
#    plus standard error of the mean:
#
#                         Mean        SD  Naive SE Time-series SE        t    eff
# t_set_heating      9
# %SIGMA@wn2*.pc3%   2.721e+00 3.288e+00 3.627e+00 3.981e+00 4.734e+00
#
# $CALIBRATION_RESULTS
#            PARAMETER   ESTIMATE       LOWER      UPPER
# 1      t_set_heating 23.0828786 22.29189189 23.0891229
# 2 window_opening_ach  0.1259833  0.02837692  0.1990446
#
# $CALIBRATED_MODEL_GOF
#              sim       cals
# data1 0.08148599 0.08333347
# Warning messages:
# 1: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 2: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# Warning messages:
# 1: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 2: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
#
#
# processing file: /opt/homebrew/lib/R/4.3/site-library/calibro/calibro_report.Rnw
# 1/44
# 2/44 [setup]
# 3/44
# 4/44 [exeSumm]
# 5/44
# 6/44 [content]
# 7/44
# 8/44 [genVar]
# 9/44
# 10/44 [dsVar]
# 11/44 [dsText]
# 12/44
# 13/44 [ds1]
# 14/44 [ds2]
# 15/44 [ds3]
# 16/44 [ds4]
# 17/44 [ds5]
# 18/44 [ds6]
# 19/44 [ds7]
# 20/44 [ds8]
# 21/44 [ds9]
# 22/44 [ds10]
# 23/44
# 24/44 [saVar]
# 25/44 [saText]
# 26/44
# 27/44 [ret_tables]
# 28/44
# 29/44 [train]
# 30/44
# 31/44 [calVar]
# 32/44 [cal]
# 33/44 [thetaplot]
# 34/44 [ds1fit]
# 35/44 [ds2fit]
# 36/44 [ds3fit]
# 37/44 [ds4fit]
# 38/44 [ds5fit]
# 39/44 [ds6fit]
# 40/44 [ds7fit]
# 41/44 [ds8fit]
# 42/44 [ds9fit]
# 43/44 [ds10fit]
# 44/44
# output file: calibro_report.tex
# [1] "calibro_report.pdf"
# Warning: LaTeX Warning: `!h' float specifier changed to `!ht'.
# Warning: LaTeX Warning: `!h' float specifier changed to `!ht'.
# Warning messages:
# 1: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 2: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# {'cells': [{'id': 'bb9d38ea',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2026-06-14T21:02:33.373237',
#      'end_time': '2026-06-14T21:02:33.391111',
#      'duration': 0.017874,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2026-06-14T21:02:33.380149Z',
#      'iopub.execute_input': '2026-06-14T21:02:33.380858Z',
#      'iopub.status.idle': '2026-06-14T21:02:33.389598Z',
#      'shell.execute_reply': '2026-06-14T21:02:33.388895Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nDATE = "JUN11"\nSTART_DATE = "2023-02-01 00:00"\nEND_DATE = "2023-03-10 23:00"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'execution_count': 2,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2026-06-14T21:02:33.394621',
#      'end_time': '2026-06-14T21:02:33.402526',
#      'duration': 0.007905,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2026-06-14T21:02:33.397548Z',
#      'iopub.execute_input': '2026-06-14T21:02:33.397950Z',
#      'iopub.status.idle': '2026-06-14T21:02:33.401512Z',
#      'shell.execute_reply': '2026-06-14T21:02:33.401115Z'}},
#    'outputs': [],
#    'source': 'from pathlib import Path\nimport subprocess\ndata_dir = Path(f"_json/_run/{DATE}/BC").resolve()\noutput_dir = Path(f"_json/_run/{DATE}/calibro").resolve()\noutput_dir.mkdir(parents=True, exist_ok=True)\ncode_dir = Path(f"_json/_run/{DATE}/_code")\ncode_dir.mkdir(parents=True, exist_ok=True)\nCALIBRO_NAME = "simplest"\nRSCRIPT_BIN = "Rscript"',
#    'id': 'c1ec4e19'},
#   {'cell_type': 'code',
#    'execution_count': 3,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2026-06-14T21:02:33.403652',
#      'end_time': '2026-06-14T21:02:55.853617',
#      'duration': 22.449965,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2026-06-14T21:02:33.405226Z',
#      'iopub.execute_input': '2026-06-14T21:02:33.405404Z',
#      'iopub.status.idle': '2026-06-14T21:02:55.852941Z',
#      'shell.execute_reply': '2026-06-14T21:02:55.852659Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': '[INFO] R script generated: _json/_run/JUN11/_code/run_calibro.R\n\n[INFO] Running Calibro Rscript...\n'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': 'Loading required package: R6\nLoading required package: coda\nLoading required package: parallel\nLoading required package: MASS\nLoading required package: modeest\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\n### NELDER-MEAD DOWNHILL SIMPLEX ALGORITHM ###\n\n Version: amoeba\n Start time: 2026-06-14 22:02:48.91809 \n Number of simulations: 5 \n\n\n*** Simulation 1 / 5 (elapsed time: 0.00117 mins) ***\n\n best y: 243.803891033431\n best z:\n\t %RHO@t_set_heating%@sePar01.pc.mu = 1 \n\t %RHO@window_opening_ach%@sePar01.pc.mu = 1 \n\t %ALPHA1@sePar01.pc.mu = 1 \n\t %SIGMA1@wn1.pc.mu = 0.9998 \n\t %SIGMA1@wn2.pc.mu = 88410000 \n\n*** Simulation 2 / 5 (elapsed time: 0.00196 mins) ***\n\n best y: 266.555905949008\n best z:\n\t %RHO@t_set_heating%@sePar01.pc.mu = 0.3182 \n\t %RHO@window_opening_ach%@sePar01.pc.mu = 0.007931 \n\t %ALPHA1@sePar01.pc.mu = 0.9999 \n\t %SIGMA1@wn1.pc.mu = 0.9999 \n\t %SIGMA1@wn2.pc.mu = 89120000 \n\n*** Simulation 3 / 5 (elapsed time: 0.00245 mins) ***\n\n best y: 271.118950876529\n best z:\n\t %RHO@t_set_heating%@sePar01.pc.mu = 0.5128 \n\t %RHO@window_opening_ach%@sePar01.pc.mu = 0.6622 \n\t %ALPHA1@sePar01.pc.mu = 0.9999 \n\t %SIGMA1@wn1.pc.mu = 0.9999 \n\t %SIGMA1@wn2.pc.mu = 86990000 \n\n*** Simulation 4 / 5 (elapsed time: 0.00281 mins) ***\n\n best y: 271.118950876529\n best z:\n\t %RHO@t_set_heating%@sePar01.pc.mu = 0.5128 \n\t %RHO@window_opening_ach%@sePar01.pc.mu = 0.6622 \n\t %ALPHA1@sePar01.pc.mu = 0.9999 \n\t %SIGMA1@wn1.pc.mu = 0.9999 \n\t %SIGMA1@wn2.pc.mu = 86990000 \n\n*** Simulation 5 / 5 (elapsed time: 0.00314 mins) ***\n\n best y: 271.118950876529\n best z:\n\t %RHO@t_set_heating%@sePar01.pc.mu = 0.5128 \n\t %RHO@window_opening_ach%@sePar01.pc.mu = 0.6622 \n\t %ALPHA1@sePar01.pc.mu = 0.9999 \n\t %SIGMA1@wn1.pc.mu = 0.9999 \n\t %SIGMA1@wn2.pc.mu = 86990000 \n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\n*** Simulation 6 / 5 (elapsed time: 0.00344 mins) ***\n\n best y: 271.905046128599\n best z:\n\t %RHO@t_set_heating%@sePar01.pc.mu = 0.3803 \n\t %RHO@window_opening_ach%@sePar01.pc.mu = 0.5018 \n\t %ALPHA1@sePar01.pc.mu = 0.9999 \n\t %SIGMA1@wn1.pc.mu = 0.9999 \n\t %SIGMA1@wn2.pc.mu = 88070000 \n\n### NELDER-MEAD DOWNHILL SIMPLEX ALGORITHM ###\n\n Version: amoeba\n Start time: 2026-06-14 22:02:49.171205 \n Number of simulations: 5 \n\n\n*** Simulation 1 / 5 (elapsed time: 0.000476 mins) ***\n\n best y: 266.556131497009\n best z:\n\t %RHO@t_set_heating%@sePar01.pc1 = 0.1207 \n\t %ALPHA1@sePar01.pc1 = 0.9999 \n\t %SIGMA1@wn1.pc1 = 0.9999 \n\t %SIGMA1@wn2.pc1 = 13580000 \n\n*** Simulation 2 / 5 (elapsed time: 0.000749 mins) ***\n\n best y: 266.556131497009\n best z:\n\t %RHO@t_set_heating%@sePar01.pc1 = 0.1207 \n\t %ALPHA1@sePar01.pc1 = 0.9999 \n\t %SIGMA1@wn1.pc1 = 0.9999 \n\t %SIGMA1@wn2.pc1 = 13580000 \n\n*** Simulation 3 / 5 (elapsed time: 0.00101 mins) ***\n\n best y: 266.556131497009\n best z:\n\t %RHO@t_set_heating%@sePar01.pc1 = 0.1207 \n\t %ALPHA1@sePar01.pc1 = 0.9999 \n\t %SIGMA1@wn1.pc1 = 0.9999 \n\t %SIGMA1@wn2.pc1 = 13580000 \n\n### NELDER-MEAD DOWNHILL SIMPLEX ALGORITHM ###\n\n Version: amoeba\n Start time: 2026-06-14 22:02:49.271307 \n Number of simulations: 5 \n\n\n*** Simulation 1 / 5 (elapsed time: 0.000414 mins) ***\n\n best y: 143.163468075349\n best z:\n\t %RHO@t_set_heating%@sePar01.pc2 = 0.1929 \n\t %ALPHA1@sePar01.pc2 = 0.9981 \n\t %SIGMA1@wn1.pc2 = 0.9996 \n\t %SIGMA1@wn2.pc2 = 926700 \n\n*** Simulation 2 / 5 (elapsed time: 0.000644 mins) ***\n\n best y: 143.163468075349\n best z:\n\t %RHO@t_set_heating%@sePar01.pc2 = 0.1929 \n\t %ALPHA1@sePar01.pc2 = 0.9981 \n\t %SIGMA1@wn1.pc2 = 0.9996 \n\t %SIGMA1@wn2.pc2 = 926700 \n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\n*** Simulation 3 / 5 (elapsed time: 0.00101 mins) ***\n\n best y: 161.042139005673\n best z:\n\t %RHO@t_set_heating%@sePar01.pc2 = 0.1105 \n\t %ALPHA1@sePar01.pc2 = 0.9984 \n\t %SIGMA1@wn1.pc2 = 0.9996 \n\t %SIGMA1@wn2.pc2 = 746900 \n\n*** Simulation 4 / 5 (elapsed time: 0.00125 mins) ***\n\n best y: 161.042139005673\n best z:\n\t %RHO@t_set_heating%@sePar01.pc2 = 0.1105 \n\t %ALPHA1@sePar01.pc2 = 0.9984 \n\t %SIGMA1@wn1.pc2 = 0.9996 \n\t %SIGMA1@wn2.pc2 = 746900 \n\n*** Simulation 5 / 5 (elapsed time: 0.00148 mins) ***\n\n best y: 161.042139005673\n best z:\n\t %RHO@t_set_heating%@sePar01.pc2 = 0.1105 \n\t %ALPHA1@sePar01.pc2 = 0.9984 \n\t %SIGMA1@wn1.pc2 = 0.9996 \n\t %SIGMA1@wn2.pc2 = 746900 \n\n*** Simulation 6 / 5 (elapsed time: 0.00179 mins) ***\n\n best y: 161.045672495397\n best z:\n\t %RHO@t_set_heating%@sePar01.pc2 = 0.104 \n\t %ALPHA1@sePar01.pc2 = 0.9984 \n\t %SIGMA1@wn1.pc2 = 0.9996 \n\t %SIGMA1@wn2.pc2 = 744300 \n\n### NELDER-MEAD DOWNHILL SIMPLEX ALGORITHM ###\n\n Version: amoeba\n Start time: 2026-06-14 22:02:49.420866 \n Number of simulations: 5 \n\n\n*** Simulation 1 / 5 (elapsed time: 0.000435 mins) ***\n\n best y: 103.825677855465\n best z:\n\t %RHO@window_opening_ach%@sePar01.pc3 = 0.1289 \n\t %ALPHA1@sePar01.pc3 = 0.9983 \n\t %SIGMA1@wn1.pc3 = 0.9926 \n\t %SIGMA1@wn2.pc3 = 2757 \n\n*** Simulation 2 / 5 (elapsed time: 8e-04 mins) ***\n\n best y: 103.828681389213\n best z:\n\t %RHO@window_opening_ach%@sePar01.pc3 = 0.1488 \n\t %ALPHA1@sePar01.pc3 = 0.9984 \n\t %SIGMA1@wn1.pc3 = 0.9926 \n\t %SIGMA1@wn2.pc3 = 2759 \n\n*** Simulation 3 / 5 (elapsed time: 0.00102 mins) ***\n\n best y: 103.828681389213\n best z:\n\t %RHO@window_opening_ach%@sePar01.pc3 = 0.1488 \n\t %ALPHA1@sePar01.pc3 = 0.9984 \n\t %SIGMA1@wn1.pc3 = 0.9926 \n\t %SIGMA1@wn2.pc3 = 2759 \n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\n### ADAPTIVE METROPOLIS WITHIN GIBBS ALGORITHM ###\n\n Start time: 2026-06-14 22:02:50.183428 \n Number of chains: 1 \n Number of simulations: <until converged> \n\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '*** Simulation 5 / <until converged> (elapsed time: 0.00967 mins) ***\n\nIterations = 50:1846\nThinning interval = 4 \nNumber of chains = 1 \nSample size per chain = 450 \n\n1. Empirical mean and standard deviation for each variable,\n   plus standard error of the mean:\n\n                        Mean        SD  Naive SE Time-series SE        t    eff\nt_set_heating      9.244e-01 8.650e-02 4.078e-03      9.418e-03 0.010189 0.1875\nwindow_opening_ach 4.839e-01 2.472e-01 1.165e-02      1.942e-02 0.040143 0.3599\n%SIGMA@wn2*.pc.mu% 1.165e+05 1.576e+04 7.428e+02      1.018e+03 0.008736 0.5328\n%SIGMA@wn2*.pc1%   1.124e+04 2.000e+03 9.427e+01      1.247e+02 0.011087 0.5718\n%SIGMA@wn2*.pc2%   8.255e+02 1.379e+02 6.499e+00      1.038e+01 0.012572 0.3921\n%SIGMA@wn2*.pc3%   3.718e+00 5.165e-01 2.435e-02      2.837e-02 0.007630 0.7366\n                        s\nt_set_heating       84.36\nwindow_opening_ach 161.96\n%SIGMA@wn2*.pc.mu% 239.78\n%SIGMA@wn2*.pc1%   257.33\n%SIGMA@wn2*.pc2%   176.44\n%SIGMA@wn2*.pc3%   331.46\n\n2. Quantiles for each variable:\n\n                        2.5%       25%       50%       75%     97.5%\nt_set_heating      6.744e-01 8.971e-01 9.570e-01 9.870e-01 9.989e-01\nwindow_opening_ach 5.463e-02 2.885e-01 4.852e-01 6.623e-01 9.405e-01\n%SIGMA@wn2*.pc.mu% 8.567e+04 1.067e+05 1.164e+05 1.251e+05 1.484e+05\n%SIGMA@wn2*.pc1%   8.012e+03 9.794e+03 1.110e+04 1.239e+04 1.527e+04\n%SIGMA@wn2*.pc2%   5.635e+02 7.363e+02 8.207e+02 9.092e+02 1.120e+03\n%SIGMA@wn2*.pc3%   2.807e+00 3.364e+00 3.676e+00 4.052e+00 4.770e+00\n\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '*** Simulation 10 / <until converged> (elapsed time: 0.0141 mins) ***\n\nIterations = 100:3696\nThinning interval = 4 \nNumber of chains = 1 \nSample size per chain = 900 \n\n1. Empirical mean and standard deviation for each variable,\n   plus standard error of the mean:\n\n                        Mean        SD  Naive SE Time-series SE        t    eff\nt_set_heating      9.388e-01 7.385e-02 2.462e-03      6.024e-03 0.006417 0.1670\nwindow_opening_ach 4.454e-01 2.482e-01 8.272e-03      1.192e-02 0.026752 0.4818\n%SIGMA@wn2*.pc.mu% 1.167e+05 1.668e+04 5.561e+02      6.825e+02 0.005849 0.6639\n%SIGMA@wn2*.pc1%   1.113e+04 2.010e+03 6.700e+01      8.294e+01 0.007453 0.6525\n%SIGMA@wn2*.pc2%   8.459e+02 1.362e+02 4.539e+00      6.375e+00 0.007536 0.5069\n%SIGMA@wn2*.pc3%   3.662e+00 5.221e-01 1.740e-02      2.400e-02 0.006555 0.5257\n                       s\nt_set_heating      150.3\nwindow_opening_ach 433.6\n%SIGMA@wn2*.pc.mu% 597.5\n%SIGMA@wn2*.pc1%   587.3\n%SIGMA@wn2*.pc2%   456.2\n%SIGMA@wn2*.pc3%   473.1\n\n2. Quantiles for each variable:\n\n                        2.5%       25%       50%       75%     97.5%\nt_set_heating      7.155e-01 9.161e-01 9.670e-01 9.879e-01 9.990e-01\nwindow_opening_ach 4.014e-02 2.459e-01 4.362e-01 6.043e-01 9.438e-01\n%SIGMA@wn2*.pc.mu% 8.570e+04 1.058e+05 1.164e+05 1.262e+05 1.548e+05\n%SIGMA@wn2*.pc1%   7.856e+03 9.696e+03 1.094e+04 1.229e+04 1.547e+04\n%SIGMA@wn2*.pc2%   5.875e+02 7.579e+02 8.506e+02 9.304e+02 1.125e+03\n%SIGMA@wn2*.pc3%   2.744e+00 3.300e+00 3.641e+00 4.022e+00 4.721e+00\n\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '*** Simulation 15 / <until converged> (elapsed time: 0.0184 mins) ***\n\nIterations = 150:5546\nThinning interval = 4 \nNumber of chains = 1 \nSample size per chain = 1350 \n\n1. Empirical mean and standard deviation for each variable,\n   plus standard error of the mean:\n\n                        Mean        SD  Naive SE Time-series SE        t    eff\nt_set_heating      9.394e-01 7.045e-02 1.918e-03      4.116e-03 0.004381 0.2171\nwindow_opening_ach 4.430e-01 2.532e-01 6.893e-03      8.978e-03 0.020267 0.5894\n%SIGMA@wn2*.pc.mu% 1.164e+05 1.665e+04 4.531e+02      5.269e+02 0.004525 0.7396\n%SIGMA@wn2*.pc1%   1.120e+04 2.077e+03 5.652e+01      7.038e+01 0.006285 0.6451\n%SIGMA@wn2*.pc2%   8.416e+02 1.331e+02 3.623e+00      4.835e+00 0.005745 0.5615\n%SIGMA@wn2*.pc3%   3.673e+00 5.261e-01 1.432e-02      1.808e-02 0.004921 0.6274\n                       s\nt_set_heating      293.1\nwindow_opening_ach 795.6\n%SIGMA@wn2*.pc.mu% 998.5\n%SIGMA@wn2*.pc1%   870.9\n%SIGMA@wn2*.pc2%   758.0\n%SIGMA@wn2*.pc3%   847.0\n\n2. Quantiles for each variable:\n\n                        2.5%       25%       50%       75%     97.5%\nt_set_heating      7.427e-01 9.146e-01 9.671e-01 9.882e-01 9.992e-01\nwindow_opening_ach 3.032e-02 2.423e-01 4.378e-01 6.152e-01 9.490e-01\n%SIGMA@wn2*.pc.mu% 8.570e+04 1.052e+05 1.161e+05 1.265e+05 1.516e+05\n%SIGMA@wn2*.pc1%   7.803e+03 9.717e+03 1.098e+04 1.249e+04 1.573e+04\n%SIGMA@wn2*.pc2%   5.919e+02 7.536e+02 8.377e+02 9.267e+02 1.114e+03\n%SIGMA@wn2*.pc3%   2.744e+00 3.316e+00 3.660e+00 4.022e+00 4.711e+00\n\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '*** Simulation 20 / <until converged> (elapsed time: 0.0229 mins) ***\n\nIterations = 200:7396\nThinning interval = 4 \nNumber of chains = 1 \nSample size per chain = 1800 \n\n1. Empirical mean and standard deviation for each variable,\n   plus standard error of the mean:\n\n                        Mean        SD  Naive SE Time-series SE        t    eff\nt_set_heating      9.397e-01 6.915e-02 1.630e-03      3.700e-03 0.003937 0.1940\nwindow_opening_ach 4.378e-01 2.530e-01 5.962e-03      7.478e-03 0.017080 0.6358\n%SIGMA@wn2*.pc.mu% 1.162e+05 1.688e+04 3.979e+02      4.450e+02 0.003828 0.7998\n%SIGMA@wn2*.pc1%   1.122e+04 2.057e+03 4.848e+01      6.191e+01 0.005518 0.6133\n%SIGMA@wn2*.pc2%   8.418e+02 1.342e+02 3.162e+00      4.199e+00 0.004988 0.5671\n%SIGMA@wn2*.pc3%   3.657e+00 5.192e-01 1.224e-02      1.594e-02 0.004359 0.5894\n                        s\nt_set_heating       349.3\nwindow_opening_ach 1144.4\n%SIGMA@wn2*.pc.mu% 1439.6\n%SIGMA@wn2*.pc1%   1103.9\n%SIGMA@wn2*.pc2%   1020.7\n%SIGMA@wn2*.pc3%   1060.9\n\n2. Quantiles for each variable:\n\n                        2.5%       25%       50%       75%     97.5%\nt_set_heating      7.435e-01 9.157e-01 9.667e-01 9.873e-01 9.989e-01\nwindow_opening_ach 2.618e-02 2.387e-01 4.324e-01 6.095e-01 9.458e-01\n%SIGMA@wn2*.pc.mu% 8.554e+04 1.044e+05 1.159e+05 1.267e+05 1.528e+05\n%SIGMA@wn2*.pc1%   7.711e+03 9.770e+03 1.104e+04 1.250e+04 1.568e+04\n%SIGMA@wn2*.pc2%   5.932e+02 7.505e+02 8.378e+02 9.285e+02 1.113e+03\n%SIGMA@wn2*.pc3%   2.744e+00 3.288e+00 3.631e+00 3.995e+00 4.700e+00\n\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '*** Simulation 25 / <until converged> (elapsed time: 0.0273 mins) ***\n\nIterations = 250:9246\nThinning interval = 4 \nNumber of chains = 1 \nSample size per chain = 2250 \n\n1. Empirical mean and standard deviation for each variable,\n   plus standard error of the mean:\n\n                        Mean        SD  Naive SE Time-series SE        t    eff\nt_set_heating      9.408e-01 6.905e-02 1.456e-03      3.390e-03 0.003603 0.1845\nwindow_opening_ach 4.408e-01 2.516e-01 5.305e-03      6.541e-03 0.014838 0.6578\n%SIGMA@wn2*.pc.mu% 1.160e+05 1.684e+04 3.551e+02      3.936e+02 0.003394 0.8140\n%SIGMA@wn2*.pc1%   1.119e+04 2.033e+03 4.287e+01      5.679e+01 0.005075 0.5699\n%SIGMA@wn2*.pc2%   8.421e+02 1.335e+02 2.814e+00      3.668e+00 0.004356 0.5884\n%SIGMA@wn2*.pc3%   3.656e+00 5.110e-01 1.077e-02      1.300e-02 0.003556 0.6864\n                      s\nt_set_heating       415\nwindow_opening_ach 1480\n%SIGMA@wn2*.pc.mu% 1831\n%SIGMA@wn2*.pc1%   1282\n%SIGMA@wn2*.pc2%   1324\n%SIGMA@wn2*.pc3%   1544\n\n2. Quantiles for each variable:\n\n                        2.5%       25%       50%       75%     97.5%\nt_set_heating      7.435e-01 9.180e-01 9.674e-01 9.879e-01 9.989e-01\nwindow_opening_ach 2.621e-02 2.430e-01 4.362e-01 6.130e-01 9.452e-01\n%SIGMA@wn2*.pc.mu% 8.548e+04 1.042e+05 1.152e+05 1.268e+05 1.513e+05\n%SIGMA@wn2*.pc1%   7.661e+03 9.764e+03 1.101e+04 1.249e+04 1.561e+04\n%SIGMA@wn2*.pc2%   5.884e+02 7.512e+02 8.413e+02 9.284e+02 1.109e+03\n%SIGMA@wn2*.pc3%   2.736e+00 3.293e+00 3.641e+00 3.996e+00 4.678e+00\n\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '*** Simulation 30 / <until converged> (elapsed time: 0.0317 mins) ***\n\nIterations = 300:11096\nThinning interval = 4 \nNumber of chains = 1 \nSample size per chain = 2700 \n\n1. Empirical mean and standard deviation for each variable,\n   plus standard error of the mean:\n\n                        Mean        SD  Naive SE Time-series SE        t    eff\nt_set_heating      9.437e-01 6.461e-02 1.243e-03      2.729e-03 0.002891 0.2076\nwindow_opening_ach 4.394e-01 2.492e-01 4.795e-03      5.730e-03 0.013041 0.7003\n%SIGMA@wn2*.pc.mu% 1.163e+05 1.700e+04 3.272e+02      3.310e+02 0.002845 0.9769\n%SIGMA@wn2*.pc1%   1.116e+04 2.017e+03 3.882e+01      4.892e+01 0.004383 0.6297\n%SIGMA@wn2*.pc2%   8.438e+02 1.334e+02 2.567e+00      3.313e+00 0.003926 0.6005\n%SIGMA@wn2*.pc3%   3.654e+00 5.088e-01 9.792e-03      1.187e-02 0.003247 0.6808\n                        s\nt_set_heating       560.6\nwindow_opening_ach 1890.8\n%SIGMA@wn2*.pc.mu% 2637.6\n%SIGMA@wn2*.pc1%   1700.3\n%SIGMA@wn2*.pc2%   1621.3\n%SIGMA@wn2*.pc3%   1838.0\n\n2. Quantiles for each variable:\n\n                        2.5%       25%       50%       75%     97.5%\nt_set_heating      7.629e-01 9.234e-01 9.680e-01 9.879e-01 9.985e-01\nwindow_opening_ach 2.799e-02 2.437e-01 4.359e-01 6.129e-01 9.380e-01\n%SIGMA@wn2*.pc.mu% 8.555e+04 1.044e+05 1.154e+05 1.272e+05 1.528e+05\n%SIGMA@wn2*.pc1%   7.625e+03 9.739e+03 1.099e+04 1.246e+04 1.555e+04\n%SIGMA@wn2*.pc2%   5.933e+02 7.539e+02 8.414e+02 9.295e+02 1.111e+03\n%SIGMA@wn2*.pc3%   2.739e+00 3.293e+00 3.635e+00 3.984e+00 4.682e+00\n\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '*** Simulation 35 / <until converged> (elapsed time: 0.0362 mins) ***\n\nIterations = 350:12946\nThinning interval = 4 \nNumber of chains = 1 \nSample size per chain = 3150 \n\n1. Empirical mean and standard deviation for each variable,\n   plus standard error of the mean:\n\n                        Mean        SD  Naive SE Time-series SE        t    eff\nt_set_heating      9.443e-01 6.393e-02 1.139e-03      2.470e-03 0.002615 0.2127\nwindow_opening_ach 4.411e-01 2.500e-01 4.454e-03      5.435e-03 0.012320 0.6715\n%SIGMA@wn2*.pc.mu% 1.165e+05 1.708e+04 3.044e+02      3.600e+02 0.003089 0.7150\n%SIGMA@wn2*.pc1%   1.117e+04 2.001e+03 3.566e+01      4.486e+01 0.004015 0.6319\n%SIGMA@wn2*.pc2%   8.456e+02 1.336e+02 2.381e+00      3.354e+00 0.003966 0.5041\n%SIGMA@wn2*.pc3%   3.652e+00 5.083e-01 9.056e-03      1.063e-02 0.002911 0.7257\n                        s\nt_set_heating       670.1\nwindow_opening_ach 2115.3\n%SIGMA@wn2*.pc.mu% 2252.1\n%SIGMA@wn2*.pc1%   1990.4\n%SIGMA@wn2*.pc2%   1588.1\n%SIGMA@wn2*.pc3%   2285.9\n\n2. Quantiles for each variable:\n\n                        2.5%       25%       50%       75%     97.5%\nt_set_heating      7.663e-01 9.242e-01 9.687e-01 9.880e-01 9.987e-01\nwindow_opening_ach 2.864e-02 2.456e-01 4.348e-01 6.146e-01 9.439e-01\n%SIGMA@wn2*.pc.mu% 8.520e+04 1.045e+05 1.159e+05 1.276e+05 1.525e+05\n%SIGMA@wn2*.pc1%   7.689e+03 9.770e+03 1.100e+04 1.244e+04 1.556e+04\n%SIGMA@wn2*.pc2%   5.960e+02 7.545e+02 8.418e+02 9.312e+02 1.114e+03\n%SIGMA@wn2*.pc3%   2.738e+00 3.291e+00 3.632e+00 3.983e+00 4.690e+00\n\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '*** Simulation 40 / <until converged> (elapsed time: 0.0406 mins) ***\n\nIterations = 400:14796\nThinning interval = 4 \nNumber of chains = 1 \nSample size per chain = 3600 \n\n1. Empirical mean and standard deviation for each variable,\n   plus standard error of the mean:\n\n                        Mean        SD  Naive SE Time-series SE        t    eff\nt_set_heating      9.443e-01 6.421e-02 1.070e-03      2.310e-03 0.002446 0.2147\nwindow_opening_ach 4.412e-01 2.494e-01 4.157e-03      4.976e-03 0.011280 0.6978\n%SIGMA@wn2*.pc.mu% 1.164e+05 1.713e+04 2.856e+02      3.382e+02 0.002905 0.7129\n%SIGMA@wn2*.pc1%   1.118e+04 1.975e+03 3.292e+01      4.232e+01 0.003786 0.6050\n%SIGMA@wn2*.pc2%   8.455e+02 1.327e+02 2.212e+00      3.185e+00 0.003767 0.4824\n%SIGMA@wn2*.pc3%   3.642e+00 5.094e-01 8.489e-03      1.042e-02 0.002862 0.6634\n                        s\nt_set_heating       772.7\nwindow_opening_ach 2512.2\n%SIGMA@wn2*.pc.mu% 2566.4\n%SIGMA@wn2*.pc1%   2178.0\n%SIGMA@wn2*.pc2%   1736.5\n%SIGMA@wn2*.pc3%   2388.4\n\n2. Quantiles for each variable:\n\n                        2.5%       25%       50%       75%     97.5%\nt_set_heating      7.642e-01 9.242e-01 9.687e-01 9.884e-01 9.990e-01\nwindow_opening_ach 2.740e-02 2.460e-01 4.372e-01 6.155e-01 9.382e-01\n%SIGMA@wn2*.pc.mu% 8.491e+04 1.044e+05 1.157e+05 1.276e+05 1.523e+05\n%SIGMA@wn2*.pc1%   7.711e+03 9.780e+03 1.102e+04 1.245e+04 1.549e+04\n%SIGMA@wn2*.pc2%   5.960e+02 7.547e+02 8.409e+02 9.313e+02 1.113e+03\n%SIGMA@wn2*.pc3%   2.722e+00 3.282e+00 3.623e+00 3.977e+00 4.679e+00\n\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '*** Simulation 45 / <until converged> (elapsed time: 0.0457 mins) ***\n\nIterations = 450:16646\nThinning interval = 4 \nNumber of chains = 1 \nSample size per chain = 4050 \n\n1. Empirical mean and standard deviation for each variable,\n   plus standard error of the mean:\n\n                        Mean        SD  Naive SE Time-series SE        t    eff\nt_set_heating      9.442e-01 6.441e-02 1.012e-03      2.172e-03 0.002301 0.2171\nwindow_opening_ach 4.408e-01 2.496e-01 3.923e-03      4.794e-03 0.010875 0.6695\n%SIGMA@wn2*.pc.mu% 1.165e+05 1.713e+04 2.692e+02      3.212e+02 0.002758 0.7024\n%SIGMA@wn2*.pc1%   1.120e+04 1.976e+03 3.104e+01      4.057e+01 0.003622 0.5855\n%SIGMA@wn2*.pc2%   8.467e+02 1.339e+02 2.105e+00      2.928e+00 0.003459 0.5166\n%SIGMA@wn2*.pc3%   3.643e+00 5.126e-01 8.055e-03      9.438e-03 0.002591 0.7285\n                        s\nt_set_heating       879.1\nwindow_opening_ach 2711.6\n%SIGMA@wn2*.pc.mu% 2844.7\n%SIGMA@wn2*.pc1%   2371.4\n%SIGMA@wn2*.pc2%   2092.2\n%SIGMA@wn2*.pc3%   2950.3\n\n2. Quantiles for each variable:\n\n                        2.5%       25%       50%       75%     97.5%\nt_set_heating      7.640e-01 9.244e-01 9.686e-01 9.882e-01 9.989e-01\nwindow_opening_ach 2.714e-02 2.437e-01 4.361e-01 6.179e-01 9.381e-01\n%SIGMA@wn2*.pc.mu% 8.519e+04 1.045e+05 1.160e+05 1.275e+05 1.522e+05\n%SIGMA@wn2*.pc1%   7.742e+03 9.795e+03 1.104e+04 1.247e+04 1.554e+04\n%SIGMA@wn2*.pc2%   5.947e+02 7.549e+02 8.413e+02 9.329e+02 1.116e+03\n%SIGMA@wn2*.pc3%   2.723e+00 3.280e+00 3.623e+00 3.978e+00 4.698e+00\n\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '*** Simulation 50 / <until converged> (elapsed time: 0.0501 mins) ***\n\nIterations = 500:18496\nThinning interval = 4 \nNumber of chains = 1 \nSample size per chain = 4500 \n\n1. Empirical mean and standard deviation for each variable,\n   plus standard error of the mean:\n\n                        Mean        SD  Naive SE Time-series SE        t    eff\nt_set_heating      9.442e-01 6.375e-02 9.503e-04      2.012e-03 0.002131 0.2230\nwindow_opening_ach 4.424e-01 2.494e-01 3.718e-03      4.582e-03 0.010356 0.6584\n%SIGMA@wn2*.pc.mu% 1.165e+05 1.704e+04 2.541e+02      3.017e+02 0.002590 0.7090\n%SIGMA@wn2*.pc1%   1.119e+04 1.961e+03 2.923e+01      3.762e+01 0.003361 0.6037\n%SIGMA@wn2*.pc2%   8.472e+02 1.341e+02 1.999e+00      2.782e+00 0.003284 0.5163\n%SIGMA@wn2*.pc3%   3.645e+00 5.140e-01 7.662e-03      9.136e-03 0.002506 0.7034\n                      s\nt_set_heating      1003\nwindow_opening_ach 2963\n%SIGMA@wn2*.pc.mu% 3191\n%SIGMA@wn2*.pc1%   2717\n%SIGMA@wn2*.pc2%   2323\n%SIGMA@wn2*.pc3%   3165\n\n2. Quantiles for each variable:\n\n                        2.5%       25%       50%       75%     97.5%\nt_set_heating      7.668e-01 9.236e-01 9.685e-01 9.879e-01 9.989e-01\nwindow_opening_ach 2.618e-02 2.437e-01 4.393e-01 6.197e-01 9.389e-01\n%SIGMA@wn2*.pc.mu% 8.522e+04 1.046e+05 1.160e+05 1.275e+05 1.520e+05\n%SIGMA@wn2*.pc1%   7.758e+03 9.801e+03 1.103e+04 1.245e+04 1.546e+04\n%SIGMA@wn2*.pc2%   5.962e+02 7.548e+02 8.413e+02 9.338e+02 1.116e+03\n%SIGMA@wn2*.pc3%   2.724e+00 3.284e+00 3.625e+00 3.981e+00 4.714e+00\n\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '*** Simulation 55 / <until converged> (elapsed time: 0.0546 mins) ***\n\nIterations = 550:20346\nThinning interval = 4 \nNumber of chains = 1 \nSample size per chain = 4950 \n\n1. Empirical mean and standard deviation for each variable,\n   plus standard error of the mean:\n\n                        Mean        SD  Naive SE Time-series SE        t    eff\nt_set_heating      9.447e-01 6.308e-02 8.966e-04      1.858e-03 0.001967 0.2328\nwindow_opening_ach 4.401e-01 2.494e-01 3.545e-03      4.392e-03 0.009980 0.6516\n%SIGMA@wn2*.pc.mu% 1.165e+05 1.703e+04 2.420e+02      2.870e+02 0.002464 0.7112\n%SIGMA@wn2*.pc1%   1.120e+04 1.942e+03 2.760e+01      3.516e+01 0.003140 0.6164\n%SIGMA@wn2*.pc2%   8.479e+02 1.338e+02 1.901e+00      2.490e+00 0.002936 0.5833\n%SIGMA@wn2*.pc3%   3.649e+00 5.150e-01 7.320e-03      8.801e-03 0.002412 0.6918\n                      s\nt_set_heating      1153\nwindow_opening_ach 3226\n%SIGMA@wn2*.pc.mu% 3520\n%SIGMA@wn2*.pc1%   3051\n%SIGMA@wn2*.pc2%   2887\n%SIGMA@wn2*.pc3%   3424\n\n2. Quantiles for each variable:\n\n                        2.5%       25%       50%       75%     97.5%\nt_set_heating      7.699e-01 9.246e-01 9.688e-01 9.880e-01 9.989e-01\nwindow_opening_ach 2.715e-02 2.429e-01 4.355e-01 6.186e-01 9.378e-01\n%SIGMA@wn2*.pc.mu% 8.523e+04 1.045e+05 1.159e+05 1.274e+05 1.522e+05\n%SIGMA@wn2*.pc1%   7.795e+03 9.817e+03 1.104e+04 1.241e+04 1.541e+04\n%SIGMA@wn2*.pc2%   5.987e+02 7.560e+02 8.420e+02 9.337e+02 1.118e+03\n%SIGMA@wn2*.pc3%   2.721e+00 3.288e+00 3.627e+00 3.981e+00 4.734e+00\n\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '$CALIBRATION_RESULTS\n           PARAMETER   ESTIMATE       LOWER      UPPER\n1      t_set_heating 23.0828786 22.29189189 23.0891229\n2 window_opening_ach  0.1259833  0.02837692  0.1990446\n\n$CALIBRATED_MODEL_GOF\n             sim       cals\ndata1 0.08148599 0.08333347\n\n'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': "Warning messages:\n1: encountered a tie, and the difference between minimal and \n                   maximal value is > length('x') * 'tie.limit'\nthe distribution could be multimodal \n2: encountered a tie, and the difference between minimal and \n                   maximal value is > length('x') * 'tie.limit'\nthe distribution could be multimodal \nWarning messages:\n1: encountered a tie, and the difference between minimal and \n                   maximal value is > length('x') * 'tie.limit'\nthe distribution could be multimodal \n2: encountered a tie, and the difference between minimal and \n                   maximal value is > length('x') * 'tie.limit'\nthe distribution could be multimodal \n"},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\n\nprocessing file: /opt/homebrew/lib/R/4.3/site-library/calibro/calibro_report.Rnw\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '1/44             \n2/44 [setup]     \n3/44             \n4/44 [exeSumm]   \n5/44             \n6/44 [content]   \n7/44             \n8/44 [genVar]    \n9/44             \n10/44 [dsVar]     \n11/44 [dsText]    \n12/44             \n13/44 [ds1]       \n14/44 [ds2]       \n15/44 [ds3]       \n16/44 [ds4]       \n17/44 [ds5]       \n18/44 [ds6]       \n19/44 [ds7]       \n20/44 [ds8]       \n21/44 [ds9]       \n22/44 [ds10]      \n23/44             \n24/44 [saVar]     \n25/44 [saText]    \n26/44             \n27/44 [ret_tables]\n28/44             \n29/44 [train]     \n30/44             \n31/44 [calVar]    \n32/44 [cal]       \n33/44 [thetaplot] \n34/44 [ds1fit]    \n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '35/44 [ds2fit]    \n36/44 [ds3fit]    \n37/44 [ds4fit]    \n38/44 [ds5fit]    \n39/44 [ds6fit]    \n40/44 [ds7fit]    \n41/44 [ds8fit]    \n42/44 [ds9fit]    \n43/44 [ds10fit]   \n44/44             \n'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': 'output file: calibro_report.tex\n\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '[1] "calibro_report.pdf"\n✓ Calibro finished successfully.\n\n🎉 Experiment complete. Results saved to: /Users/rui.bo/Desktop/BASE/1_phd/Y3/RC_br/_json/_run/JUN11/calibro\n'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': "Warning: LaTeX Warning: `!h' float specifier changed to `!ht'.\nWarning: LaTeX Warning: `!h' float specifier changed to `!ht'.\nWarning messages:\n1: encountered a tie, and the difference between minimal and \n                   maximal value is > length('x') * 'tie.limit'\nthe distribution could be multimodal \n2: encountered a tie, and the difference between minimal and \n                   maximal value is > length('x') * 'tie.limit'\nthe distribution could be multimodal \n"}],
#    'source': 'r_code = f"""\nsetwd("{output_dir}")\n\nlibrary(calibro)\n\nCE <- calEnv$new(name = \'{CALIBRO_NAME}\')\n\nCE$add.ds(\n    name = \'data1\',\n    Y.star = \'{data_dir}/obs.csv\',\n    TT     = \'{data_dir}/TT.csv\',\n    Y      = \'{data_dir}/Y.csv\'\n)\n\nCE$rd = \'pca\'\nCE$sa = \'sobolSmthSpl\'\nCE$ret = list(mthd = \'ng.screening\')\nCE$mdls = \'gpr.ng.sePar01_whitePar01\'\nCE$train = list(type = \'training\', alg = \'amoeba\')\nCE$cals = \'cal.gpr.ng\'\nCE$cal.mcmc = list(alg = \'amg\')\n\nCE$cal.res()\n\nM <- CE$cal.mcmc\nZ <- M$Z\n# z_map <- as.data.frame(t(M$bestz))\n\nif (inherits(Z, "mcmc.list")) {{\nZ <- do.call(rbind, lapply(Z, as.matrix))\n}} else {{\nZ <- as.matrix(Z)\n}}\n\n\nwrite.csv(Z, "posterior_draws_Z.csv", row.names = FALSE)\n# write.csv(z_map, "z_map.csv", row.names = FALSE)\ntheta <- CE$cal.res(mode = "theta")\nwrite.csv(theta, "theta_physical_summary.csv", row.names = FALSE)\n\nCE$genReport(\ntype = "pdf",\nout = c("dss", "cal")\n)\n"""\nr_script_path = code_dir / "run_calibro.R"\n\nr_code = r_code\n\nwith open(r_script_path, "w") as f:\n    f.write(r_code)\n\nprint("[INFO] R script generated:", r_script_path)\n\n\n# ================================================================\n# 6. Run Rscript\n# ================================================================\nprint("\\n[INFO] Running Calibro Rscript...")\ncmd = [RSCRIPT_BIN, str(r_script_path)]\nresult = subprocess.run(cmd)\nif result.returncode == 0:\n    print("✓ Calibro finished successfully.")\nelse:\n    print("❌ Calibro failed.")\n\n\nprint(f"\\n🎉 Experiment complete. Results saved to: {output_dir}")',
#    'id': 'e030c8e0'},
#   {'cell_type': 'code',
#    'execution_count': None,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2026-06-14T21:02:55.855372',
#      'end_time': '2026-06-14T21:02:55.856793',
#      'duration': 0.001421,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': '',
#    'id': '8002ed15'}],
#  'metadata': {'kernelspec': {'display_name': 'eplus_env',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.10.4',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'orig_nbformat_minor': 2,
#   'papermill': {'default_parameters': {},
#    'parameters': {'DATE': 'JUN11',
#     'START_DATE': '2023-02-01 00:00',
#     'END_DATE': '2023-03-10 23:00'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '1_CALIBRO.ipynb',
#    'output_path': 'JUN11.ipynb',
#    'start_time': '2026-06-14T21:02:32.889785',
#    'end_time': '2026-06-14T21:02:55.973838',
#    'duration': 23.084053,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %%
import papermill as pm

NOTEBOOK_IN = "1_PLOT_map.ipynb"

pm.execute_notebook(
    NOTEBOOK_IN,
    f"{DATE}.ipynb",
    parameters={
        "DATE": DATE,
        "START_DATE": start,
        "END_DATE": end,
    },
)
# Out:
# Passed unknown parameter: DATE
# Passed unknown parameter: START_DATE
# Passed unknown parameter: END_DATE
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/1 [00:00<?, ?cell/s]
# {'cells': [{'id': 'fb17f68e',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2026-06-14T21:02:56.477687',
#      'end_time': '2026-06-14T21:02:56.496317',
#      'duration': 0.01863,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2026-06-14T21:02:56.483403Z',
#      'iopub.execute_input': '2026-06-14T21:02:56.484143Z',
#      'iopub.status.idle': '2026-06-14T21:02:56.494708Z',
#      'shell.execute_reply': '2026-06-14T21:02:56.493564Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nDATE = "JUN11"\nSTART_DATE = "2023-02-01 00:00"\nEND_DATE = "2023-03-10 23:00"\n',
#    'outputs': []}],
#  'metadata': {'kernelspec': {'display_name': 'eplus_env',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.10.4',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'orig_nbformat_minor': 2,
#   'papermill': {'default_parameters': {},
#    'parameters': {'DATE': 'JUN11',
#     'START_DATE': '2023-02-01 00:00',
#     'END_DATE': '2023-03-10 23:00'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '1_PLOT_map.ipynb',
#    'output_path': 'JUN11.ipynb',
#    'start_time': '2026-06-14T21:02:55.992380',
#    'end_time': '2026-06-14T21:02:56.615707',
#    'duration': 0.623327,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %% [markdown]
# # APPENDIX: Code STYLE

# %% [markdown]
# Use a configuration-driven functional pandas style.
#
# Package preference:
# - Use pathlib.Path for paths.
# - Use pandas for tabular data, time-indexed data, resampling, alignment, and CSV output.
# - Use numpy only for numerical formulas.
# - Avoid classes unless state must be preserved across many methods.
# - Avoid creating many intermediate global objects when a function can apply the transformation internally.
#
# Function style:
# - Keep functions small and task-specific.
# - Pass domain choices as arguments: KPI, frequency, period, output directory.
# - Let functions accept base-resolution data, then slice, resample, align, and save internally.
# - Avoid hard-coded daily/hourly/heating names inside the function body.
# - Avoid default arguments that depend on changing global variables where possible.
#
# DataFrame construction style:
# - For fixed summary rows, collect tuples and create one DataFrame with explicit columns.
# - For simulation matrices, create a dictionary of aligned Series and pass it once to pd.DataFrame.
# - Do not append rows directly to a DataFrame inside a loop.
# - Always align simulated and observed data explicitly before metrics or export.
#
# Calling style:
# - Define configuration variables once at the call site.
# - Use keyword arguments for main workflow functions.
# - Do not pre-create daily-specific objects unless they are reused elsewhere.

# %% [markdown]
# # Posterior SIM

# %%
posterior_TT = f'_json/_run/{DATE}/calibro/posterior_rand10_from_topfrac.csv'
# If posterior_TT is a string (file path)
posterior_TT = pd.read_csv(posterior_TT)

# %%
def run_posterior_ecm_samples(
    posterior_TT,
    extra_params=None,
    controller_mode="original",
):
    results = {}
    euis = {}

    if extra_params is None:
        extra_params = {}

    for sample_id, row in show_progress(
        posterior_TT.iterrows(),
        total=len(posterior_TT),
        desc="Running posterior samples",
        unit="sample",
    ):
        sampled_params = row.to_dict()
        sampled_params.update(extra_params)

        res, eui, _ = run_model_case(
            case=case,
            sampled_params=sampled_params,
            controller_mode=controller_mode,
        )

        results[sample_id] = res
        euis[sample_id] = eui

    eui_df = pd.DataFrame(euis).T

    return results, eui_df

# baseline_results, baseline_eui = run_posterior_ecm_samples(
#     posterior_TT=posterior_TT,
#     extra_params=None,
#     controller_mode=controller_mode,
# )

# %%
def make_ecm_specs(case):
    default_win = case.default_params["window_opening_ach"]

    return {
        "Baseline": {},

        "ECM-1_setpoint_19C": {
            "t_set_heating": 19.5,
        },

        "ECM-2_reschedule_8_8_8": {
            "heating_schedule_mode": "8_8_8",
        },

        "ECM-3_setpoint_19C_default_infiltration": {
            "t_set_heating": 19.5,
            "window_opening_ach": default_win,
        },

        "ECM-4_reschedule_8_8_8_default_infiltration": {
            "heating_schedule_mode": "8_8_8",
            "window_opening_ach": default_win,
        },
    }

def run_ecm_suite(
    posterior_TT,
    ecm_specs,
    controller_mode="original",
):
    all_results = {}
    all_euis = {}

    for ecm_name, extra_params in ecm_specs.items():
        results, eui_df = run_posterior_ecm_samples(
            posterior_TT=posterior_TT,
            extra_params=extra_params,
            controller_mode=controller_mode,
        )

        all_results[ecm_name] = results
        all_euis[ecm_name] = eui_df

    return all_results, all_euis

# %%
ecm_specs = make_ecm_specs(case)

all_results, all_euis = run_ecm_suite(
    posterior_TT=posterior_TT,
    ecm_specs=ecm_specs,
)
# Out:
# Running posterior samples:   0%|          | 0/10 [00:00<?, ?sample/s]
# Running posterior samples:   0%|          | 0/10 [00:00<?, ?sample/s]
# Running posterior samples:   0%|          | 0/10 [00:00<?, ?sample/s]
# Running posterior samples:   0%|          | 0/10 [00:00<?, ?sample/s]
# Running posterior samples:   0%|          | 0/10 [00:00<?, ?sample/s]

# %%
def compute_ecm_savings(
    all_euis,
    baseline_name="Baseline",
    energy_col="HeatingEnergy",
):
    baseline = all_euis[baseline_name][energy_col]
    rows = []

    for ecm_name, eui_df in all_euis.items():
        if ecm_name == baseline_name:
            continue

        df = pd.concat(
            [
                baseline.rename("baseline"),
                eui_df[energy_col].rename("ecm_energy"),
            ],
            axis=1,
            join="inner",
        )

        saving_abs = df["baseline"] - df["ecm_energy"]

        rows.append(
            pd.DataFrame(
                {
                    "ecm": ecm_name,
                    "sample_id": df.index,
                    "saving_abs": saving_abs,
                    "saving_rel": saving_abs / df["baseline"] * 100.0,
                }
            )
        )

    return pd.concat(rows, ignore_index=True)

# %%
def plot_ecm_savings_pair(
    savings_df,
    kpi_label="Heating energy",
    abs_unit="kWh m$^{-2}$",
    figsize=(12, 8),
    rot=30,
):
    plot_specs = {
        "saving_abs": (
            f"Absolute {kpi_label.lower()} saving ({abs_unit})",
            f"Absolute {kpi_label.lower()} savings across posterior samples",
        ),
        "saving_rel": (
            f"Relative {kpi_label.lower()} saving (%)",
            f"Relative {kpi_label.lower()} savings across posterior samples",
        ),
    }

    for value_col, (y_label, title) in plot_specs.items():
        fig, ax = plt.subplots(figsize=figsize)

        savings_df.boxplot(
            column=value_col,
            by="ecm",
            ax=ax,
            rot=rot,
        )

        ax.axhline(0, linestyle="--", linewidth=1)
        ax.set_ylabel(y_label)
        ax.set_xlabel("")
        ax.set_title(title)
        ax.grid(True, axis="y", alpha=0.3)

        plt.suptitle("")
        plt.tight_layout()
        plt.show()

# %%
heating_savings = compute_ecm_savings(
    all_euis=all_euis,
    baseline_name="Baseline",
    energy_col="HeatingEnergy",
)

plot_ecm_savings_pair(
    savings_df=heating_savings,
    kpi_label="Heating energy",
)
