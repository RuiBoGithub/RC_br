# %%
# Parameters
DATE = "JUN11__ETHlib_default_occ"
START_DATE = "2023-02-01 00:00"
END_DATE = "2023-03-10 23:00"

# %%
from pathlib import Path
import subprocess
data_dir = Path(f"_json/_run/{DATE}/BC").resolve()
output_dir = Path(f"_json/_run/{DATE}/calibro").resolve()
output_dir.mkdir(parents=True, exist_ok=True)
code_dir = Path(f"_json/_run/{DATE}/_code")
code_dir.mkdir(parents=True, exist_ok=True)
CALIBRO_NAME = "simplest"
RSCRIPT_BIN = "Rscript"

# %%
r_code = f"""
setwd("{output_dir}")

library(calibro)

CE <- calEnv$new(name = '{CALIBRO_NAME}')

CE$add.ds(
    name = 'data1',
    Y.star = '{data_dir}/obs.csv',
    TT     = '{data_dir}/TT.csv',
    Y      = '{data_dir}/Y.csv'
)

CE$rd = 'pca'
CE$sa = 'sobolSmthSpl'
CE$ret = list(mthd = 'ng.screening')
CE$mdls = 'gpr.ng.sePar01_whitePar01'
CE$train = list(type = 'training', alg = 'amoeba')
CE$cals = 'cal.gpr.ng'
CE$cal.mcmc = list(alg = 'amg')

CE$cal.res()

M <- CE$cal.mcmc
Z <- M$Z
# z_map <- as.data.frame(t(M$bestz))

if (inherits(Z, "mcmc.list")) {{
Z <- do.call(rbind, lapply(Z, as.matrix))
}} else {{
Z <- as.matrix(Z)
}}


write.csv(Z, "posterior_draws_Z.csv", row.names = FALSE)
# write.csv(z_map, "z_map.csv", row.names = FALSE)
theta <- CE$cal.res(mode = "theta")
write.csv(theta, "theta_physical_summary.csv", row.names = FALSE)

CE$genReport(
type = "pdf",
out = c("dss", "cal")
)
"""
r_script_path = code_dir / "run_calibro.R"

r_code = r_code

with open(r_script_path, "w") as f:
    f.write(r_code)

print("[INFO] R script generated:", r_script_path)


# ================================================================
# 6. Run Rscript
# ================================================================
print("\n[INFO] Running Calibro Rscript...")
cmd = [RSCRIPT_BIN, str(r_script_path)]
result = subprocess.run(cmd)
if result.returncode == 0:
    print("✓ Calibro finished successfully.")
else:
    print("❌ Calibro failed.")


print(f"\n🎉 Experiment complete. Results saved to: {output_dir}")
# Out:
# [INFO] R script generated: _json/_run/JUN11__ETHlib_default_occ/_code/run_calibro.R
#
# [INFO] Running Calibro Rscript...
# Loading required package: R6
# Loading required package: coda
# Loading required package: parallel
# Loading required package: MASS
# Loading required package: modeest
# ### NELDER-MEAD DOWNHILL SIMPLEX ALGORITHM ###
#
#  Version: amoeba
#  Start time: 2026-06-16 14:14:31.814506
#  Number of simulations: 5
#
#
# *** Simulation 1 / 5 (elapsed time: 0.00193 mins) ***
#
#  best y: 532.471347507054
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc.mu = 0.1553
# 	 %RHO@infl_rate_m3ph_m2%@sePar01.pc.mu = 1
# 	 %RHO@window_opening_ach%@sePar01.pc.mu = 1
# 	 %ALPHA1@sePar01.pc.mu = 1
# 	 %SIGMA1@wn1.pc.mu = 0.9999
# 	 %SIGMA1@wn2.pc.mu = 70820000
# *** Simulation 2 / 5 (elapsed time: 0.00354 mins) ***
#
#  best y: 545.278390509714
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc.mu = 0.004838
# 	 %RHO@infl_rate_m3ph_m2%@sePar01.pc.mu = 0.9998
# 	 %RHO@window_opening_ach%@sePar01.pc.mu = 0.6235
# 	 %ALPHA1@sePar01.pc.mu = 1
# 	 %SIGMA1@wn1.pc.mu = 0.9999
# 	 %SIGMA1@wn2.pc.mu = 76970000
#
# *** Simulation 3 / 5 (elapsed time: 0.00464 mins) ***
#
#  best y: 545.278390509714
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc.mu = 0.004838
# 	 %RHO@infl_rate_m3ph_m2%@sePar01.pc.mu = 0.9998
# 	 %RHO@window_opening_ach%@sePar01.pc.mu = 0.6235
# 	 %ALPHA1@sePar01.pc.mu = 1
# 	 %SIGMA1@wn1.pc.mu = 0.9999
# 	 %SIGMA1@wn2.pc.mu = 76970000
#
# *** Simulation 4 / 5 (elapsed time: 0.00563 mins) ***
#
#  best y: 545.278390509714
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc.mu = 0.004838
# 	 %RHO@infl_rate_m3ph_m2%@sePar01.pc.mu = 0.9998
# 	 %RHO@window_opening_ach%@sePar01.pc.mu = 0.6235
# 	 %ALPHA1@sePar01.pc.mu = 1
# 	 %SIGMA1@wn1.pc.mu = 0.9999
# 	 %SIGMA1@wn2.pc.mu = 76970000
# *** Simulation 5 / 5 (elapsed time: 0.00714 mins) ***
#
#  best y: 545.278390509714
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc.mu = 0.004838
# 	 %RHO@infl_rate_m3ph_m2%@sePar01.pc.mu = 0.9998
# 	 %RHO@window_opening_ach%@sePar01.pc.mu = 0.6235
# 	 %ALPHA1@sePar01.pc.mu = 1
# 	 %SIGMA1@wn1.pc.mu = 0.9999
# 	 %SIGMA1@wn2.pc.mu = 76970000
#
# *** Simulation 6 / 5 (elapsed time: 0.00813 mins) ***
#
#  best y: 545.278390509714
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc.mu = 0.004838
# 	 %RHO@infl_rate_m3ph_m2%@sePar01.pc.mu = 0.9998
# 	 %RHO@window_opening_ach%@sePar01.pc.mu = 0.6235
# 	 %ALPHA1@sePar01.pc.mu = 1
# 	 %SIGMA1@wn1.pc.mu = 0.9999
# 	 %SIGMA1@wn2.pc.mu = 76970000
#
# ### NELDER-MEAD DOWNHILL SIMPLEX ALGORITHM ###
#
#  Version: amoeba
#  Start time: 2026-06-16 14:14:32.355466
#  Number of simulations: 5
# *** Simulation 1 / 5 (elapsed time: 0.00216 mins) ***
#
#  best y: 814.595584248977
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc1 = 0.5799
# 	 %RHO@infl_rate_m3ph_m2%@sePar01.pc1 = 0.7177
# 	 %RHO@window_opening_ach%@sePar01.pc1 = 0.6459
# 	 %RHO@atrium_ach%@sePar01.pc1 = 0.7918
# 	 %ALPHA1@sePar01.pc1 = 1
# 	 %SIGMA1@wn1.pc1 = 1
# 	 %SIGMA1@wn2.pc1 = 10690000
#
# *** Simulation 2 / 5 (elapsed time: 0.00525 mins) ***
#
#  best y: 814.595584248977
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc1 = 0.5799
# 	 %RHO@infl_rate_m3ph_m2%@sePar01.pc1 = 0.7177
# 	 %RHO@window_opening_ach%@sePar01.pc1 = 0.6459
# 	 %RHO@atrium_ach%@sePar01.pc1 = 0.7918
# 	 %ALPHA1@sePar01.pc1 = 1
# 	 %SIGMA1@wn1.pc1 = 1
# 	 %SIGMA1@wn2.pc1 = 10690000
# *** Simulation 3 / 5 (elapsed time: 0.0069 mins) ***
#
#  best y: 814.595584248977
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc1 = 0.5799
# 	 %RHO@infl_rate_m3ph_m2%@sePar01.pc1 = 0.7177
# 	 %RHO@window_opening_ach%@sePar01.pc1 = 0.6459
# 	 %RHO@atrium_ach%@sePar01.pc1 = 0.7918
# 	 %ALPHA1@sePar01.pc1 = 1
# 	 %SIGMA1@wn1.pc1 = 1
# 	 %SIGMA1@wn2.pc1 = 10690000
#
# ### NELDER-MEAD DOWNHILL SIMPLEX ALGORITHM ###
#
#  Version: amoeba
#  Start time: 2026-06-16 14:14:32.816722
#  Number of simulations: 5
#
#
# *** Simulation 1 / 5 (elapsed time: 0.0014 mins) ***
#
#  best y: 432.852355894594
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc2 = 0.043
# 	 %ALPHA1@sePar01.pc2 = 0.9995
# 	 %SIGMA1@wn1.pc2 = 0.9999
# 	 %SIGMA1@wn2.pc2 = 1904000
#
# *** Simulation 2 / 5 (elapsed time: 0.00246 mins) ***
#
#  best y: 432.852355894594
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc2 = 0.043
# 	 %ALPHA1@sePar01.pc2 = 0.9995
# 	 %SIGMA1@wn1.pc2 = 0.9999
# 	 %SIGMA1@wn2.pc2 = 1904000
# *** Simulation 3 / 5 (elapsed time: 0.00303 mins) ***
#
#  best y: 432.852355894594
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc2 = 0.043
# 	 %ALPHA1@sePar01.pc2 = 0.9995
# 	 %SIGMA1@wn1.pc2 = 0.9999
# 	 %SIGMA1@wn2.pc2 = 1904000
#
# ### NELDER-MEAD DOWNHILL SIMPLEX ALGORITHM ###
#
#  Version: amoeba
#  Start time: 2026-06-16 14:14:33.042022
#  Number of simulations: 5
#
#
# *** Simulation 1 / 5 (elapsed time: 0.00126 mins) ***
#
#  best y: 350.586100855982
#  best z:
# 	 %RHO@infl_rate_m3ph_m2%@sePar01.pc3 = 0.4714
# 	 %RHO@window_opening_ach%@sePar01.pc3 = 0.6161
# 	 %RHO@atrium_ach%@sePar01.pc3 = 0.7466
# 	 %ALPHA1@sePar01.pc3 = 0.9991
# 	 %SIGMA1@wn1.pc3 = 0.9993
# 	 %SIGMA1@wn2.pc3 = 28300
# *** Simulation 2 / 5 (elapsed time: 0.00285 mins) ***
#
#  best y: 350.586100855982
#  best z:
# 	 %RHO@infl_rate_m3ph_m2%@sePar01.pc3 = 0.4714
# 	 %RHO@window_opening_ach%@sePar01.pc3 = 0.6161
# 	 %RHO@atrium_ach%@sePar01.pc3 = 0.7466
# 	 %ALPHA1@sePar01.pc3 = 0.9991
# 	 %SIGMA1@wn1.pc3 = 0.9993
# 	 %SIGMA1@wn2.pc3 = 28300
#
# *** Simulation 3 / 5 (elapsed time: 0.00561 mins) ***
#
#  best y: 350.723230893094
#  best z:
# 	 %RHO@infl_rate_m3ph_m2%@sePar01.pc3 = 0.5114
# 	 %RHO@window_opening_ach%@sePar01.pc3 = 0.6161
# 	 %RHO@atrium_ach%@sePar01.pc3 = 0.7532
# 	 %ALPHA1@sePar01.pc3 = 0.9991
# 	 %SIGMA1@wn1.pc3 = 0.9993
# 	 %SIGMA1@wn2.pc3 = 28010
# *** Simulation 4 / 5 (elapsed time: 0.00745 mins) ***
#
#  best y: 350.723230893094
#  best z:
# 	 %RHO@infl_rate_m3ph_m2%@sePar01.pc3 = 0.5114
# 	 %RHO@window_opening_ach%@sePar01.pc3 = 0.6161
# 	 %RHO@atrium_ach%@sePar01.pc3 = 0.7532
# 	 %ALPHA1@sePar01.pc3 = 0.9991
# 	 %SIGMA1@wn1.pc3 = 0.9993
# 	 %SIGMA1@wn2.pc3 = 28010
#
# *** Simulation 5 / 5 (elapsed time: 0.00853 mins) ***
#
#  best y: 350.723230893094
#  best z:
# 	 %RHO@infl_rate_m3ph_m2%@sePar01.pc3 = 0.5114
# 	 %RHO@window_opening_ach%@sePar01.pc3 = 0.6161
# 	 %RHO@atrium_ach%@sePar01.pc3 = 0.7532
# 	 %ALPHA1@sePar01.pc3 = 0.9991
# 	 %SIGMA1@wn1.pc3 = 0.9993
# 	 %SIGMA1@wn2.pc3 = 28010
# ### ADAPTIVE METROPOLIS WITHIN GIBBS ALGORITHM ###
#
#  Start time: 2026-06-16 14:14:34.534256
#  Number of chains: 1
#  Number of simulations: <until converged>
# *** Simulation 5 / <until converged> (elapsed time: 0.0175 mins) ***
#
# Iterations = 50:1846
# Thinning interval = 4
# Number of chains = 1
# Sample size per chain = 450
#
# 1. Empirical mean and standard deviation for each variable,
#    plus standard error of the mean:
#
#                         Mean        SD  Naive SE Time-series SE        t    eff
# t_set_heating      9.721e-01 2.181e-02 1.028e-03      1.577e-03 0.001623 0.4248
# infl_rate_m3ph_m2  7.350e-01 1.662e-01 7.836e-03      1.053e-02 0.014327 0.5537
# window_opening_ach 6.439e-01 2.338e-01 1.102e-02      2.294e-02 0.035625 0.2308
# %SIGMA@wn2*.pc.mu% 2.889e+05 4.124e+04 1.944e+03      3.007e+03 0.010408 0.4179
# atrium_ach         6.263e-01 2.283e-01 1.076e-02      1.571e-02 0.025076 0.4695
# %SIGMA@wn2*.pc1%   6.121e+03 8.854e+02 4.174e+01      4.727e+01 0.007722 0.7797
# %SIGMA@wn2*.pc2%   7.641e+03 1.072e+03 5.054e+01      4.579e+01 0.005993 1.2181
# %SIGMA@wn2*.pc3%   9.761e+01 1.473e+01 6.944e-01      9.820e-01 0.010061 0.4999
#                        s
# t_set_heating      191.2
# infl_rate_m3ph_m2  249.2
# window_opening_ach 103.9
# %SIGMA@wn2*.pc.mu% 188.1
# atrium_ach         211.3
# %SIGMA@wn2*.pc1%   350.9
# %SIGMA@wn2*.pc2%   548.1
# %SIGMA@wn2*.pc3%   225.0
#
# 2. Quantiles for each variable:
#
#                         2.5%       25%       50%       75%     97.5%
# t_set_heating      9.160e-01 9.600e-01 9.765e-01 9.884e-01 9.994e-01
# infl_rate_m3ph_m2  3.373e-01 6.298e-01 7.540e-01 8.643e-01 9.756e-01
# window_opening_ach 9.373e-02 4.938e-01 6.733e-01 8.365e-01 9.705e-01
# %SIGMA@wn2*.pc.mu% 2.173e+05 2.589e+05 2.852e+05 3.175e+05 3.748e+05
# atrium_ach         1.582e-01 4.667e-01 6.539e-01 8.083e-01 9.762e-01
# %SIGMA@wn2*.pc1%   4.551e+03 5.518e+03 6.071e+03 6.679e+03 7.932e+03
# %SIGMA@wn2*.pc2%   5.659e+03 6.942e+03 7.637e+03 8.285e+03 9.903e+03
# %SIGMA@wn2*.pc3%   7.091e+01 8.717e+01 9.685e+01 1.075e+02 1.301e+02
# *** Simulation 10 / <until converged> (elapsed time: 0.0286 mins) ***
#
# Iterations = 100:3696
# Thinning interval = 4
# Number of chains = 1
# Sample size per chain = 900
#
# 1. Empirical mean and standard deviation for each variable,
#    plus standard error of the mean:
#
#                         Mean        SD  Naive SE Time-series SE        t    eff
# t_set_heating      9.731e-01 2.187e-02 7.290e-04      1.140e-03 0.001172 0.4085
# infl_rate_m3ph_m2  7.417e-01 1.652e-01 5.507e-03      7.034e-03 0.009485 0.6128
# window_opening_ach 6.515e-01 2.262e-01 7.541e-03      1.027e-02 0.015759 0.5394
# %SIGMA@wn2*.pc.mu% 2.902e+05 4.160e+04 1.387e+03      1.757e+03 0.006054 0.6230
# atrium_ach         6.157e-01 2.336e-01 7.786e-03      1.015e-02 0.016484 0.5884
# %SIGMA@wn2*.pc1%   6.080e+03 8.980e+02 2.993e+01      3.509e+01 0.005770 0.7278
# %SIGMA@wn2*.pc2%   7.585e+03 1.105e+03 3.685e+01      4.468e+01 0.005890 0.6801
# %SIGMA@wn2*.pc3%   9.831e+01 1.518e+01 5.060e-01      5.765e-01 0.005864 0.7706
#                        s
# t_set_heating      367.7
# infl_rate_m3ph_m2  551.5
# window_opening_ach 485.5
# %SIGMA@wn2*.pc.mu% 560.7
# atrium_ach         529.6
# %SIGMA@wn2*.pc1%   655.0
# %SIGMA@wn2*.pc2%   612.1
# %SIGMA@wn2*.pc3%   693.5
#
# 2. Quantiles for each variable:
#
#                         2.5%       25%       50%       75%     97.5%
# t_set_heating      9.146e-01 9.624e-01 9.774e-01 9.896e-01 9.990e-01
# infl_rate_m3ph_m2  3.465e-01 6.373e-01 7.690e-01 8.652e-01 9.762e-01
# window_opening_ach 1.362e-01 4.943e-01 6.833e-01 8.335e-01 9.778e-01
# %SIGMA@wn2*.pc.mu% 2.161e+05 2.610e+05 2.866e+05 3.188e+05 3.758e+05
# atrium_ach         1.167e-01 4.663e-01 6.496e-01 7.918e-01 9.774e-01
# %SIGMA@wn2*.pc1%   4.485e+03 5.463e+03 6.071e+03 6.645e+03 8.062e+03
# %SIGMA@wn2*.pc2%   5.652e+03 6.811e+03 7.525e+03 8.268e+03 9.866e+03
# %SIGMA@wn2*.pc3%   6.988e+01 8.757e+01 9.721e+01 1.087e+02 1.297e+02
# *** Simulation 15 / <until converged> (elapsed time: 0.0395 mins) ***
#
# Iterations = 150:5546
# Thinning interval = 4
# Number of chains = 1
# Sample size per chain = 1350
#
# 1. Empirical mean and standard deviation for each variable,
#    plus standard error of the mean:
#
#                         Mean        SD  Naive SE Time-series SE         t
# t_set_heating      9.747e-01 2.121e-02 5.774e-04      8.462e-04 0.0008681
# infl_rate_m3ph_m2  7.478e-01 1.644e-01 4.475e-03      6.073e-03 0.0081217
# window_opening_ach 6.566e-01 2.244e-01 6.108e-03      8.084e-03 0.0123117
# %SIGMA@wn2*.pc.mu% 2.876e+05 4.171e+04 1.135e+03      1.377e+03 0.0047894
# atrium_ach         6.163e-01 2.363e-01 6.431e-03      7.880e-03 0.0127863
# %SIGMA@wn2*.pc1%   6.064e+03 8.811e+02 2.398e+01      2.774e+01 0.0045751
# %SIGMA@wn2*.pc2%   7.580e+03 1.115e+03 3.035e+01      3.773e+01 0.0049782
# %SIGMA@wn2*.pc3%   9.866e+01 1.512e+01 4.115e-01      4.553e-01 0.0046150
#                       eff      s
# t_set_heating      0.4656  628.5
# infl_rate_m3ph_m2  0.5428  732.8
# window_opening_ach 0.5709  770.7
# %SIGMA@wn2*.pc.mu% 0.6795  917.3
# atrium_ach         0.6661  899.2
# %SIGMA@wn2*.pc1%   0.7473 1008.8
# %SIGMA@wn2*.pc2%   0.6467  873.1
# %SIGMA@wn2*.pc3%   0.8168 1102.6
#
# 2. Quantiles for each variable:
#
#                         2.5%       25%       50%       75%     97.5%
# t_set_heating      9.201e-01 9.643e-01 9.797e-01 9.906e-01 9.993e-01
# infl_rate_m3ph_m2  3.477e-01 6.454e-01 7.695e-01 8.758e-01 9.828e-01
# window_opening_ach 1.727e-01 4.951e-01 6.842e-01 8.412e-01 9.813e-01
# %SIGMA@wn2*.pc.mu% 2.145e+05 2.587e+05 2.839e+05 3.156e+05 3.718e+05
# atrium_ach         1.155e-01 4.530e-01 6.516e-01 7.961e-01 9.819e-01
# %SIGMA@wn2*.pc1%   4.497e+03 5.463e+03 6.040e+03 6.583e+03 8.027e+03
# %SIGMA@wn2*.pc2%   5.657e+03 6.804e+03 7.511e+03 8.264e+03 9.959e+03
# %SIGMA@wn2*.pc3%   7.062e+01 8.826e+01 9.763e+01 1.088e+02 1.287e+02
# *** Simulation 20 / <until converged> (elapsed time: 0.0507 mins) ***
#
# Iterations = 200:7396
# Thinning interval = 4
# Number of chains = 1
# Sample size per chain = 1800
#
# 1. Empirical mean and standard deviation for each variable,
#    plus standard error of the mean:
#
#                         Mean        SD  Naive SE Time-series SE         t
# t_set_heating      9.757e-01 2.074e-02 4.889e-04      7.217e-04 0.0007397
# infl_rate_m3ph_m2  7.382e-01 1.679e-01 3.958e-03      5.384e-03 0.0072933
# window_opening_ach 6.626e-01 2.213e-01 5.216e-03      6.802e-03 0.0102644
# %SIGMA@wn2*.pc.mu% 2.874e+05 4.131e+04 9.737e+02      1.175e+03 0.0040877
# atrium_ach         6.230e-01 2.326e-01 5.481e-03      6.745e-03 0.0108267
# %SIGMA@wn2*.pc1%   6.051e+03 8.905e+02 2.099e+01      2.453e+01 0.0040541
# %SIGMA@wn2*.pc2%   7.576e+03 1.102e+03 2.597e+01      3.114e+01 0.0041105
# %SIGMA@wn2*.pc3%   9.880e+01 1.537e+01 3.624e-01      4.009e-01 0.0040576
#                       eff      s
# t_set_heating      0.4589  826.0
# infl_rate_m3ph_m2  0.5404  972.7
# window_opening_ach 0.5882 1058.7
# %SIGMA@wn2*.pc.mu% 0.6871 1236.8
# atrium_ach         0.6605 1188.9
# %SIGMA@wn2*.pc1%   0.7321 1317.7
# %SIGMA@wn2*.pc2%   0.6953 1251.5
# %SIGMA@wn2*.pc3%   0.8171 1470.7
#
# 2. Quantiles for each variable:
#
#                         2.5%       25%       50%       75%     97.5%
# t_set_heating      9.240e-01 9.651e-01 9.810e-01 9.914e-01 9.993e-01
# infl_rate_m3ph_m2  3.351e-01 6.334e-01 7.627e-01 8.693e-01 9.833e-01
# window_opening_ach 1.729e-01 5.098e-01 6.891e-01 8.463e-01 9.813e-01
# %SIGMA@wn2*.pc.mu% 2.139e+05 2.586e+05 2.847e+05 3.149e+05 3.699e+05
# atrium_ach         1.149e-01 4.769e-01 6.528e-01 7.997e-01 9.801e-01
# %SIGMA@wn2*.pc1%   4.450e+03 5.448e+03 6.011e+03 6.593e+03 8.060e+03
# %SIGMA@wn2*.pc2%   5.667e+03 6.797e+03 7.515e+03 8.271e+03 9.892e+03
# %SIGMA@wn2*.pc3%   7.089e+01 8.812e+01 9.727e+01 1.088e+02 1.304e+02
# *** Simulation 25 / <until converged> (elapsed time: 0.0617 mins) ***
#
# Iterations = 250:9246
# Thinning interval = 4
# Number of chains = 1
# Sample size per chain = 2250
#
# 1. Empirical mean and standard deviation for each variable,
#    plus standard error of the mean:
#
#                         Mean        SD  Naive SE Time-series SE         t
# t_set_heating      9.757e-01 2.097e-02 4.422e-04      6.602e-04 0.0006766
# infl_rate_m3ph_m2  7.355e-01 1.683e-01 3.549e-03      4.901e-03 0.0066628
# window_opening_ach 6.589e-01 2.214e-01 4.668e-03      6.257e-03 0.0094959
# %SIGMA@wn2*.pc.mu% 2.857e+05 4.031e+04 8.499e+02      1.024e+03 0.0035838
# atrium_ach         6.257e-01 2.305e-01 4.859e-03      6.269e-03 0.0100191
# %SIGMA@wn2*.pc1%   6.049e+03 8.826e+02 1.861e+01      2.188e+01 0.0036176
# %SIGMA@wn2*.pc2%   7.587e+03 1.108e+03 2.336e+01      2.771e+01 0.0036528
# %SIGMA@wn2*.pc3%   9.848e+01 1.510e+01 3.183e-01      3.737e-01 0.0037945
#                       eff    s
# t_set_heating      0.4486 1009
# infl_rate_m3ph_m2  0.5244 1180
# window_opening_ach 0.5566 1252
# %SIGMA@wn2*.pc.mu% 0.6892 1551
# atrium_ach         0.6008 1352
# %SIGMA@wn2*.pc1%   0.7231 1627
# %SIGMA@wn2*.pc2%   0.7108 1599
# %SIGMA@wn2*.pc3%   0.7254 1632
#
# 2. Quantiles for each variable:
#
#                         2.5%       25%       50%       75%     97.5%
# t_set_heating      9.224e-01 9.653e-01 9.811e-01 9.916e-01 9.993e-01
# infl_rate_m3ph_m2  3.347e-01 6.322e-01 7.613e-01 8.652e-01 9.808e-01
# window_opening_ach 1.659e-01 5.054e-01 6.871e-01 8.395e-01 9.816e-01
# %SIGMA@wn2*.pc.mu% 2.129e+05 2.572e+05 2.832e+05 3.132e+05 3.674e+05
# atrium_ach         1.119e-01 4.795e-01 6.576e-01 7.997e-01 9.793e-01
# %SIGMA@wn2*.pc1%   4.464e+03 5.448e+03 6.011e+03 6.589e+03 7.995e+03
# %SIGMA@wn2*.pc2%   5.655e+03 6.799e+03 7.525e+03 8.283e+03 9.937e+03
# %SIGMA@wn2*.pc3%   7.096e+01 8.804e+01 9.692e+01 1.078e+02 1.285e+02
# *** Simulation 30 / <until converged> (elapsed time: 0.0732 mins) ***
#
# Iterations = 300:11096
# Thinning interval = 4
# Number of chains = 1
# Sample size per chain = 2700
#
# 1. Empirical mean and standard deviation for each variable,
#    plus standard error of the mean:
#
#                         Mean        SD  Naive SE Time-series SE         t
# t_set_heating      9.757e-01 2.079e-02 4.000e-04      5.979e-04 0.0006128
# infl_rate_m3ph_m2  7.366e-01 1.694e-01 3.259e-03      4.591e-03 0.0062319
# window_opening_ach 6.598e-01 2.244e-01 4.318e-03      5.778e-03 0.0087577
# %SIGMA@wn2*.pc.mu% 2.856e+05 4.042e+04 7.779e+02      9.444e+02 0.0033073
# atrium_ach         6.243e-01 2.316e-01 4.456e-03      5.774e-03 0.0092495
# %SIGMA@wn2*.pc1%   6.056e+03 8.901e+02 1.713e+01      2.015e+01 0.0033275
# %SIGMA@wn2*.pc2%   7.583e+03 1.103e+03 2.122e+01      2.530e+01 0.0033364
# %SIGMA@wn2*.pc3%   9.863e+01 1.506e+01 2.899e-01      3.821e-01 0.0038742
#                       eff    s
# t_set_heating      0.4476 1208
# infl_rate_m3ph_m2  0.5041 1361
# window_opening_ach 0.5585 1508
# %SIGMA@wn2*.pc.mu% 0.6784 1832
# atrium_ach         0.5956 1608
# %SIGMA@wn2*.pc1%   0.7225 1951
# %SIGMA@wn2*.pc2%   0.7036 1900
# %SIGMA@wn2*.pc3%   0.5756 1554
#
# 2. Quantiles for each variable:
#
#                         2.5%       25%       50%       75%     97.5%
# t_set_heating      9.227e-01 9.654e-01 9.810e-01 9.915e-01 9.992e-01
# infl_rate_m3ph_m2  3.253e-01 6.362e-01 7.618e-01 8.657e-01 9.839e-01
# window_opening_ach 1.623e-01 5.039e-01 6.866e-01 8.453e-01 9.843e-01
# %SIGMA@wn2*.pc.mu% 2.131e+05 2.572e+05 2.828e+05 3.128e+05 3.707e+05
# atrium_ach         1.084e-01 4.745e-01 6.551e-01 8.039e-01 9.792e-01
# %SIGMA@wn2*.pc1%   4.427e+03 5.454e+03 6.026e+03 6.608e+03 7.987e+03
# %SIGMA@wn2*.pc2%   5.652e+03 6.784e+03 7.528e+03 8.285e+03 9.897e+03
# %SIGMA@wn2*.pc3%   7.178e+01 8.812e+01 9.710e+01 1.078e+02 1.293e+02
# $CALIBRATION_RESULTS
#            PARAMETER   ESTIMATE       LOWER      UPPER
# 1      t_set_heating 23.9430361 23.57189957 23.9634205
# 2  infl_rate_m3ph_m2  4.4396584  3.86068980  4.7968843
# 3 window_opening_ach  0.1885561  0.05223933  0.1992389
# 4         atrium_ach  2.1722454  1.73993435  2.3960606
#
# $CALIBRATED_MODEL_GOF
#            sim      cals
# data1 0.115151 0.1258967
# Warning messages:
# 1: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 2: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 3: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 4: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 5: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# Warning messages:
# 1: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 2: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 3: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 4: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 5: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# processing file: /opt/homebrew/lib/R/4.3/site-library/calibro/calibro_report.Rnw
# 1/44
# 2/44 [setup]
# 3/44
# 4/44 [exeSumm]
# 5/44
# 6/44 [content]
# 7/44
# 8/44 [genVar]
# 9/44
# 10/44 [dsVar]
# 11/44 [dsText]
# 12/44
# 13/44 [ds1]
# 14/44 [ds2]
# 15/44 [ds3]
# 16/44 [ds4]
# 17/44 [ds5]
# 18/44 [ds6]
# 19/44 [ds7]
# 20/44 [ds8]
# 21/44 [ds9]
# 22/44 [ds10]
# 23/44
# 24/44 [saVar]
# 25/44 [saText]
# 26/44
# 27/44 [ret_tables]
# 28/44
# 29/44 [train]
# 30/44
# 31/44 [calVar]
# 32/44 [cal]
# 33/44 [thetaplot]
# 34/44 [ds1fit]
# 35/44 [ds2fit]
# 36/44 [ds3fit]
# 37/44 [ds4fit]
# 38/44 [ds5fit]
# 39/44 [ds6fit]
# 40/44 [ds7fit]
# 41/44 [ds8fit]
# 42/44 [ds9fit]
# 43/44 [ds10fit]
# 44/44
# output file: calibro_report.tex
# [1] "calibro_report.pdf"
# ✓ Calibro finished successfully.
#
# 🎉 Experiment complete. Results saved to: /Users/rui.bo/Desktop/BASE/1_phd/Y3/RC_br/_json/_run/JUN11__ETHlib_default_occ/calibro
# Warning: LaTeX Warning: `!h' float specifier changed to `!ht'.
# Warning: LaTeX Warning: `!h' float specifier changed to `!ht'.
# Warning messages:
# 1: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 2: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 3: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 4: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 5: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
