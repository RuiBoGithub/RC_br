# %%
# Parameters
DATE = "JUN11__ETHlib_bldg_LoD_Y"
START_DATE = "2023-01-20 00:00"
END_DATE = "2023-03-17 23:00"

# %%
from pathlib import Path
import subprocess
data_dir = Path(f"_json/_run/{DATE}/BC").resolve()
output_dir = Path(f"_json/_run/{DATE}/calibro").resolve()
output_dir.mkdir(parents=True, exist_ok=True)
code_dir = Path(f"_json/_run/{DATE}/_code")
code_dir.mkdir(parents=True, exist_ok=True)
CALIBRO_NAME = "simplest"
RSCRIPT_BIN = "Rscript"

# %%
r_code = f"""
setwd("{output_dir}")

library(calibro)

CE <- calEnv$new(name = '{CALIBRO_NAME}')

CE$add.ds(
    name = 'data1',
    Y.star = '{data_dir}/obs.csv',
    TT     = '{data_dir}/TT.csv',
    Y      = '{data_dir}/Y.csv'
)

CE$rd = 'pca'
CE$sa = 'sobolSmthSpl'
CE$ret = list(mthd = 'ng.screening')
CE$mdls = 'gpr.ng.sePar01_whitePar01'
CE$train = list(type = 'training', alg = 'amoeba')
CE$cals = 'cal.gpr.ng'
CE$cal.mcmc = list(alg = 'amg')

CE$cal.res()

M <- CE$cal.mcmc
Z <- M$Z
# z_map <- as.data.frame(t(M$bestz))

if (inherits(Z, "mcmc.list")) {{
Z <- do.call(rbind, lapply(Z, as.matrix))
}} else {{
Z <- as.matrix(Z)
}}


write.csv(Z, "posterior_draws_Z.csv", row.names = FALSE)
# write.csv(z_map, "z_map.csv", row.names = FALSE)
theta <- CE$cal.res(mode = "theta")
write.csv(theta, "theta_physical_summary.csv", row.names = FALSE)

CE$genReport(
type = "pdf",
out = c("dss", "cal")
)
"""
r_script_path = code_dir / "run_calibro.R"

r_code = r_code

with open(r_script_path, "w") as f:
    f.write(r_code)

print("[INFO] R script generated:", r_script_path)


# ================================================================
# 6. Run Rscript
# ================================================================
print("\n[INFO] Running Calibro Rscript...")
cmd = [RSCRIPT_BIN, str(r_script_path)]
result = subprocess.run(cmd)
if result.returncode == 0:
    print("✓ Calibro finished successfully.")
else:
    print("❌ Calibro failed.")


print(f"\n🎉 Experiment complete. Results saved to: {output_dir}")
# Out:
# [INFO] R script generated: _json/_run/JUN11__ETHlib_bldg_LoD_Y/_code/run_calibro.R
#
# [INFO] Running Calibro Rscript...
# Loading required package: R6
# Loading required package: coda
# Loading required package: parallel
# Loading required package: MASS
# Loading required package: modeest
# ### NELDER-MEAD DOWNHILL SIMPLEX ALGORITHM ###
#
#  Version: amoeba
#  Start time: 2026-06-16 16:53:56.939117
#  Number of simulations: 5
#
#
# *** Simulation 1 / 5 (elapsed time: 0.00303 mins) ***
#
#  best y: 557.646101408149
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc.mu = 1.46e-09
# 	 %RHO@infl_rate_m3ph_m2%@sePar01.pc.mu = 0.5888
# 	 %RHO@window_opening_ach%@sePar01.pc.mu = 0.5663
# 	 %ALPHA1@sePar01.pc.mu = 0.9999
# 	 %SIGMA1@wn1.pc.mu = 1
# 	 %SIGMA1@wn2.pc.mu = 293200000
# *** Simulation 2 / 5 (elapsed time: 0.00401 mins) ***
#
#  best y: 557.646101408149
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc.mu = 1.46e-09
# 	 %RHO@infl_rate_m3ph_m2%@sePar01.pc.mu = 0.5888
# 	 %RHO@window_opening_ach%@sePar01.pc.mu = 0.5663
# 	 %ALPHA1@sePar01.pc.mu = 0.9999
# 	 %SIGMA1@wn1.pc.mu = 1
# 	 %SIGMA1@wn2.pc.mu = 293200000
#
# *** Simulation 3 / 5 (elapsed time: 0.00533 mins) ***
#
#  best y: 557.646101408149
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc.mu = 1.46e-09
# 	 %RHO@infl_rate_m3ph_m2%@sePar01.pc.mu = 0.5888
# 	 %RHO@window_opening_ach%@sePar01.pc.mu = 0.5663
# 	 %ALPHA1@sePar01.pc.mu = 0.9999
# 	 %SIGMA1@wn1.pc.mu = 1
# 	 %SIGMA1@wn2.pc.mu = 293200000
#
# ### NELDER-MEAD DOWNHILL SIMPLEX ALGORITHM ###
#
#  Version: amoeba
#  Start time: 2026-06-16 16:53:57.310092
#  Number of simulations: 5
# *** Simulation 1 / 5 (elapsed time: 0.00134 mins) ***
#
#  best y: 570.756377043264
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc1 = 0.06268
# 	 %ALPHA1@sePar01.pc1 = 0.9999
# 	 %SIGMA1@wn1.pc1 = 1
# 	 %SIGMA1@wn2.pc1 = 40810000
#
# *** Simulation 2 / 5 (elapsed time: 0.00238 mins) ***
#
#  best y: 570.756377043264
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc1 = 0.06268
# 	 %ALPHA1@sePar01.pc1 = 0.9999
# 	 %SIGMA1@wn1.pc1 = 1
# 	 %SIGMA1@wn2.pc1 = 40810000
#
# *** Simulation 3 / 5 (elapsed time: 0.00361 mins) ***
#
#  best y: 570.756377043264
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc1 = 0.06268
# 	 %ALPHA1@sePar01.pc1 = 0.9999
# 	 %SIGMA1@wn1.pc1 = 1
# 	 %SIGMA1@wn2.pc1 = 40810000
#
# ### NELDER-MEAD DOWNHILL SIMPLEX ALGORITHM ###
#
#  Version: amoeba
#  Start time: 2026-06-16 16:53:57.573026
#  Number of simulations: 5
# *** Simulation 1 / 5 (elapsed time: 0.00111 mins) ***
#
#  best y: 411.604368205987
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc2 = 0.09439
# 	 %ALPHA1@sePar01.pc2 = 0.9995
# 	 %SIGMA1@wn1.pc2 = 0.9997
# 	 %SIGMA1@wn2.pc2 = 5254000
#
# *** Simulation 2 / 5 (elapsed time: 0.0025 mins) ***
#
#  best y: 411.604368205987
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc2 = 0.09439
# 	 %ALPHA1@sePar01.pc2 = 0.9995
# 	 %SIGMA1@wn1.pc2 = 0.9997
# 	 %SIGMA1@wn2.pc2 = 5254000
#
# *** Simulation 3 / 5 (elapsed time: 0.00355 mins) ***
#
#  best y: 411.604368205987
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc2 = 0.09439
# 	 %ALPHA1@sePar01.pc2 = 0.9995
# 	 %SIGMA1@wn1.pc2 = 0.9997
# 	 %SIGMA1@wn2.pc2 = 5254000
#
# ### NELDER-MEAD DOWNHILL SIMPLEX ALGORITHM ###
#
#  Version: amoeba
#  Start time: 2026-06-16 16:53:57.832345
#  Number of simulations: 5
# *** Simulation 1 / 5 (elapsed time: 0.00142 mins) ***
#
#  best y: 273.699704706118
#  best z:
# 	 %RHO@infl_rate_m3ph_m2%@sePar01.pc3 = 0.2501
# 	 %RHO@window_opening_ach%@sePar01.pc3 = 0.3176
# 	 %ALPHA1@sePar01.pc3 = 0.9991
# 	 %SIGMA1@wn1.pc3 = 0.9966
# 	 %SIGMA1@wn2.pc3 = 37910
#
# *** Simulation 2 / 5 (elapsed time: 0.00328 mins) ***
#
#  best y: 274.256772598435
#  best z:
# 	 %RHO@infl_rate_m3ph_m2%@sePar01.pc3 = 0.4409
# 	 %RHO@window_opening_ach%@sePar01.pc3 = 0.4123
# 	 %ALPHA1@sePar01.pc3 = 0.9991
# 	 %SIGMA1@wn1.pc3 = 0.9967
# 	 %SIGMA1@wn2.pc3 = 38080
#
# *** Simulation 3 / 5 (elapsed time: 0.0044 mins) ***
#
#  best y: 274.256772598435
#  best z:
# 	 %RHO@infl_rate_m3ph_m2%@sePar01.pc3 = 0.4409
# 	 %RHO@window_opening_ach%@sePar01.pc3 = 0.4123
# 	 %ALPHA1@sePar01.pc3 = 0.9991
# 	 %SIGMA1@wn1.pc3 = 0.9967
# 	 %SIGMA1@wn2.pc3 = 38080
# *** Simulation 4 / 5 (elapsed time: 0.00636 mins) ***
#
#  best y: 275.625835165189
#  best z:
# 	 %RHO@infl_rate_m3ph_m2%@sePar01.pc3 = 0.3536
# 	 %RHO@window_opening_ach%@sePar01.pc3 = 0.4228
# 	 %ALPHA1@sePar01.pc3 = 0.9991
# 	 %SIGMA1@wn1.pc3 = 0.9967
# 	 %SIGMA1@wn2.pc3 = 39350
#
# *** Simulation 5 / 5 (elapsed time: 0.0087 mins) ***
#
#  best y: 275.627259506496
#  best z:
# 	 %RHO@infl_rate_m3ph_m2%@sePar01.pc3 = 0.363
# 	 %RHO@window_opening_ach%@sePar01.pc3 = 0.4309
# 	 %ALPHA1@sePar01.pc3 = 0.9991
# 	 %SIGMA1@wn1.pc3 = 0.9966
# 	 %SIGMA1@wn2.pc3 = 39460
# *** Simulation 6 / 5 (elapsed time: 0.0106 mins) ***
#
#  best y: 275.627259506496
#  best z:
# 	 %RHO@infl_rate_m3ph_m2%@sePar01.pc3 = 0.363
# 	 %RHO@window_opening_ach%@sePar01.pc3 = 0.4309
# 	 %ALPHA1@sePar01.pc3 = 0.9991
# 	 %SIGMA1@wn1.pc3 = 0.9966
# 	 %SIGMA1@wn2.pc3 = 39460
#
# ### NELDER-MEAD DOWNHILL SIMPLEX ALGORITHM ###
#
#  Version: amoeba
#  Start time: 2026-06-16 16:53:58.516691
#  Number of simulations: 5
#
#
# *** Simulation 1 / 5 (elapsed time: 0.00106 mins) ***
#
#  best y: 247.769578330941
#  best z:
# 	 %RHO@window_opening_ach%@sePar01.pc4 = 0.1193
# 	 %ALPHA1@sePar01.pc4 = 0.9998
# 	 %SIGMA1@wn1.pc4 = 0.9942
# 	 %SIGMA1@wn2.pc4 = 12730
#
# *** Simulation 2 / 5 (elapsed time: 0.00181 mins) ***
#
#  best y: 247.769578330941
#  best z:
# 	 %RHO@window_opening_ach%@sePar01.pc4 = 0.1193
# 	 %ALPHA1@sePar01.pc4 = 0.9998
# 	 %SIGMA1@wn1.pc4 = 0.9942
# 	 %SIGMA1@wn2.pc4 = 12730
#
# *** Simulation 3 / 5 (elapsed time: 0.00243 mins) ***
#
#  best y: 247.769578330941
#  best z:
# 	 %RHO@window_opening_ach%@sePar01.pc4 = 0.1193
# 	 %ALPHA1@sePar01.pc4 = 0.9998
# 	 %SIGMA1@wn1.pc4 = 0.9942
# 	 %SIGMA1@wn2.pc4 = 12730
# ### ADAPTIVE METROPOLIS WITHIN GIBBS ALGORITHM ###
#
#  Start time: 2026-06-16 16:53:59.643185
#  Number of chains: 1
#  Number of simulations: <until converged>
# *** Simulation 5 / <until converged> (elapsed time: 0.0237 mins) ***
#
# Iterations = 50:1846
# Thinning interval = 4
# Number of chains = 1
# Sample size per chain = 450
#
# 1. Empirical mean and standard deviation for each variable,
#    plus standard error of the mean:
#
#                         Mean        SD  Naive SE Time-series SE        t    eff
# t_set_heating      6.325e-01 4.629e-02 2.182e-03      3.117e-03 0.004928 0.4900
# infl_rate_m3ph_m2  5.299e-01 2.809e-01 1.324e-02      2.307e-02 0.043538 0.3294
# window_opening_ach 6.454e-01 2.355e-01 1.110e-02      1.709e-02 0.026473 0.4222
# %SIGMA@wn2*.pc.mu% 1.712e+05 2.147e+04 1.012e+03      1.527e+03 0.008922 0.4393
# %SIGMA@wn2*.pc1%   2.273e+04 3.050e+03 1.438e+02      2.269e+02 0.009985 0.4015
# %SIGMA@wn2*.pc2%   3.018e+03 3.981e+02 1.877e+01      3.010e+01 0.009974 0.3888
# %SIGMA@wn2*.pc3%   2.442e+01 3.122e+00 1.472e-01      3.883e-01 0.015901 0.1436
# %SIGMA@wn2*.pc4%   7.399e+00 8.992e-01 4.239e-02      5.603e-02 0.007572 0.5724
#                         s
# t_set_heating      220.48
# infl_rate_m3ph_m2  148.23
# window_opening_ach 189.98
# %SIGMA@wn2*.pc.mu% 197.68
# %SIGMA@wn2*.pc1%   180.68
# %SIGMA@wn2*.pc2%   174.96
# %SIGMA@wn2*.pc3%    64.64
# %SIGMA@wn2*.pc4%   257.59
#
# 2. Quantiles for each variable:
#
#                         2.5%       25%       50%       75%     97.5%
# t_set_heating      5.394e-01 5.989e-01 6.324e-01 6.647e-01 7.216e-01
# infl_rate_m3ph_m2  4.123e-02 2.900e-01 5.457e-01 7.737e-01 9.689e-01
# window_opening_ach 1.315e-01 4.824e-01 6.955e-01 8.296e-01 9.820e-01
# %SIGMA@wn2*.pc.mu% 1.320e+05 1.561e+05 1.705e+05 1.851e+05 2.130e+05
# %SIGMA@wn2*.pc1%   1.748e+04 2.071e+04 2.247e+04 2.489e+04 2.919e+04
# %SIGMA@wn2*.pc2%   2.255e+03 2.754e+03 2.991e+03 3.277e+03 3.828e+03
# %SIGMA@wn2*.pc3%   1.932e+01 2.211e+01 2.413e+01 2.630e+01 3.104e+01
# %SIGMA@wn2*.pc4%   5.784e+00 6.771e+00 7.316e+00 8.005e+00 9.205e+00
# *** Simulation 10 / <until converged> (elapsed time: 0.0377 mins) ***
#
# Iterations = 100:3696
# Thinning interval = 4
# Number of chains = 1
# Sample size per chain = 900
#
# 1. Empirical mean and standard deviation for each variable,
#    plus standard error of the mean:
#
#                         Mean        SD  Naive SE Time-series SE        t    eff
# t_set_heating      6.311e-01 4.709e-02 1.570e-03      1.910e-03 0.003027 0.6754
# infl_rate_m3ph_m2  5.449e-01 2.663e-01 8.875e-03      1.348e-02 0.024734 0.4336
# window_opening_ach 6.525e-01 2.305e-01 7.683e-03      9.784e-03 0.014995 0.6167
# %SIGMA@wn2*.pc.mu% 1.725e+05 2.182e+04 7.275e+02      9.262e+02 0.005370 0.6169
# %SIGMA@wn2*.pc1%   2.293e+04 2.829e+03 9.431e+01      1.192e+02 0.005197 0.6260
# %SIGMA@wn2*.pc2%   2.982e+03 3.754e+02 1.251e+01      1.660e+01 0.005566 0.5682
# %SIGMA@wn2*.pc3%   2.409e+01 2.931e+00 9.769e-02      1.255e-01 0.005211 0.6057
# %SIGMA@wn2*.pc4%   7.291e+00 8.502e-01 2.834e-02      3.415e-02 0.004683 0.6887
#                        s
# t_set_heating      607.8
# infl_rate_m3ph_m2  390.3
# window_opening_ach 555.0
# %SIGMA@wn2*.pc.mu% 555.2
# %SIGMA@wn2*.pc1%   563.4
# %SIGMA@wn2*.pc2%   511.4
# %SIGMA@wn2*.pc3%   545.1
# %SIGMA@wn2*.pc4%   619.9
#
# 2. Quantiles for each variable:
#
#                         2.5%       25%       50%       75%     97.5%
# t_set_heating      5.364e-01 5.989e-01 6.320e-01 6.639e-01 7.235e-01
# infl_rate_m3ph_m2  5.856e-02 3.364e-01 5.528e-01 7.847e-01 9.698e-01
# window_opening_ach 1.410e-01 4.851e-01 6.956e-01 8.355e-01 9.816e-01
# %SIGMA@wn2*.pc.mu% 1.327e+05 1.570e+05 1.722e+05 1.874e+05 2.146e+05
# %SIGMA@wn2*.pc1%   1.776e+04 2.109e+04 2.279e+04 2.485e+04 2.874e+04
# %SIGMA@wn2*.pc2%   2.262e+03 2.721e+03 2.973e+03 3.231e+03 3.750e+03
# %SIGMA@wn2*.pc3%   1.879e+01 2.201e+01 2.396e+01 2.602e+01 3.038e+01
# %SIGMA@wn2*.pc4%   5.705e+00 6.709e+00 7.267e+00 7.855e+00 9.011e+00
# *** Simulation 15 / <until converged> (elapsed time: 0.0516 mins) ***
#
# Iterations = 150:5546
# Thinning interval = 4
# Number of chains = 1
# Sample size per chain = 1350
#
# 1. Empirical mean and standard deviation for each variable,
#    plus standard error of the mean:
#
#                         Mean        SD  Naive SE Time-series SE        t    eff
# t_set_heating      6.311e-01 4.719e-02 1.284e-03      1.620e-03 0.002568 0.6282
# infl_rate_m3ph_m2  5.533e-01 2.627e-01 7.150e-03      1.017e-02 0.018373 0.4946
# window_opening_ach 6.404e-01 2.372e-01 6.455e-03      8.299e-03 0.012959 0.6050
# %SIGMA@wn2*.pc.mu% 1.728e+05 2.111e+04 5.746e+02      6.963e+02 0.004031 0.6810
# %SIGMA@wn2*.pc1%   2.311e+04 2.852e+03 7.763e+01      9.226e+01 0.003992 0.7079
# %SIGMA@wn2*.pc2%   2.986e+03 3.685e+02 1.003e+01      1.289e+01 0.004318 0.6052
# %SIGMA@wn2*.pc3%   2.391e+01 2.948e+00 8.024e-02      9.609e-02 0.004020 0.6972
# %SIGMA@wn2*.pc4%   7.256e+00 8.469e-01 2.305e-02      2.813e-02 0.003877 0.6713
#                        s
# t_set_heating      848.1
# infl_rate_m3ph_m2  667.8
# window_opening_ach 816.8
# %SIGMA@wn2*.pc.mu% 919.3
# %SIGMA@wn2*.pc1%   955.7
# %SIGMA@wn2*.pc2%   817.1
# %SIGMA@wn2*.pc3%   941.2
# %SIGMA@wn2*.pc4%   906.3
#
# 2. Quantiles for each variable:
#
#                         2.5%       25%       50%       75%     97.5%
# t_set_heating      5.363e-01 5.983e-01 6.321e-01 6.640e-01 7.236e-01
# infl_rate_m3ph_m2  6.812e-02 3.451e-01 5.670e-01 7.780e-01 9.681e-01
# window_opening_ach 1.173e-01 4.778e-01 6.794e-01 8.284e-01 9.814e-01
# %SIGMA@wn2*.pc.mu% 1.347e+05 1.579e+05 1.726e+05 1.866e+05 2.133e+05
# %SIGMA@wn2*.pc1%   1.817e+04 2.114e+04 2.302e+04 2.495e+04 2.895e+04
# %SIGMA@wn2*.pc2%   2.268e+03 2.731e+03 2.978e+03 3.235e+03 3.716e+03
# %SIGMA@wn2*.pc3%   1.866e+01 2.185e+01 2.370e+01 2.575e+01 3.006e+01
# %SIGMA@wn2*.pc4%   5.694e+00 6.685e+00 7.206e+00 7.806e+00 8.984e+00
# *** Simulation 20 / <until converged> (elapsed time: 0.0655 mins) ***
#
# Iterations = 200:7396
# Thinning interval = 4
# Number of chains = 1
# Sample size per chain = 1800
#
# 1. Empirical mean and standard deviation for each variable,
#    plus standard error of the mean:
#
#                         Mean        SD  Naive SE Time-series SE        t    eff
# t_set_heating      6.314e-01 4.740e-02 1.117e-03      1.388e-03 0.002198 0.6484
# infl_rate_m3ph_m2  5.544e-01 2.636e-01 6.213e-03      8.868e-03 0.015997 0.4908
# window_opening_ach 6.318e-01 2.410e-01 5.681e-03      8.147e-03 0.012896 0.4861
# %SIGMA@wn2*.pc.mu% 1.736e+05 2.108e+04 4.968e+02      5.863e+02 0.003377 0.7178
# %SIGMA@wn2*.pc1%   2.310e+04 2.827e+03 6.664e+01      7.843e+01 0.003396 0.7219
# %SIGMA@wn2*.pc2%   2.990e+03 3.658e+02 8.623e+00      1.072e+01 0.003585 0.6470
# %SIGMA@wn2*.pc3%   2.393e+01 2.874e+00 6.775e-02      8.021e-02 0.003352 0.7133
# %SIGMA@wn2*.pc4%   7.262e+00 8.617e-01 2.031e-02      2.693e-02 0.003708 0.5689
#                         s
# t_set_heating      1167.1
# infl_rate_m3ph_m2   883.4
# window_opening_ach  875.0
# %SIGMA@wn2*.pc.mu% 1292.1
# %SIGMA@wn2*.pc1%   1299.4
# %SIGMA@wn2*.pc2%   1164.7
# %SIGMA@wn2*.pc3%   1284.0
# %SIGMA@wn2*.pc4%   1024.0
#
# 2. Quantiles for each variable:
#
#                         2.5%       25%       50%       75%     97.5%
# t_set_heating      5.364e-01 5.991e-01 6.317e-01 6.632e-01 7.250e-01
# infl_rate_m3ph_m2  6.697e-02 3.451e-01 5.688e-01 7.819e-01 9.708e-01
# window_opening_ach 1.163e-01 4.612e-01 6.650e-01 8.288e-01 9.814e-01
# %SIGMA@wn2*.pc.mu% 1.353e+05 1.588e+05 1.732e+05 1.879e+05 2.155e+05
# %SIGMA@wn2*.pc1%   1.800e+04 2.114e+04 2.297e+04 2.494e+04 2.891e+04
# %SIGMA@wn2*.pc2%   2.294e+03 2.733e+03 2.978e+03 3.236e+03 3.709e+03
# %SIGMA@wn2*.pc3%   1.859e+01 2.196e+01 2.379e+01 2.578e+01 2.980e+01
# %SIGMA@wn2*.pc4%   5.684e+00 6.671e+00 7.209e+00 7.813e+00 9.059e+00
# *** Simulation 25 / <until converged> (elapsed time: 0.0794 mins) ***
#
# Iterations = 250:9246
# Thinning interval = 4
# Number of chains = 1
# Sample size per chain = 2250
#
# 1. Empirical mean and standard deviation for each variable,
#    plus standard error of the mean:
#
#                         Mean        SD  Naive SE Time-series SE        t    eff
# t_set_heating      6.314e-01 4.780e-02 1.008e-03      1.243e-03 0.001969 0.6572
# infl_rate_m3ph_m2  5.561e-01 2.626e-01 5.537e-03      7.946e-03 0.014290 0.4855
# window_opening_ach 6.260e-01 2.412e-01 5.086e-03      7.382e-03 0.011792 0.4747
# %SIGMA@wn2*.pc.mu% 1.734e+05 2.076e+04 4.377e+02      5.121e+02 0.002954 0.7306
# %SIGMA@wn2*.pc1%   2.303e+04 2.860e+03 6.030e+01      7.304e+01 0.003172 0.6816
# %SIGMA@wn2*.pc2%   2.981e+03 3.679e+02 7.757e+00      9.488e+00 0.003183 0.6683
# %SIGMA@wn2*.pc3%   2.393e+01 2.826e+00 5.958e-02      6.898e-02 0.002882 0.7462
# %SIGMA@wn2*.pc4%   7.256e+00 8.690e-01 1.832e-02      2.171e-02 0.002992 0.7122
#                       s
# t_set_heating      1479
# infl_rate_m3ph_m2  1092
# window_opening_ach 1068
# %SIGMA@wn2*.pc.mu% 1644
# %SIGMA@wn2*.pc1%   1534
# %SIGMA@wn2*.pc2%   1504
# %SIGMA@wn2*.pc3%   1679
# %SIGMA@wn2*.pc4%   1602
#
# 2. Quantiles for each variable:
#
#                         2.5%       25%       50%       75%     97.5%
# t_set_heating      5.369e-01 5.982e-01 6.303e-01 6.637e-01 7.251e-01
# infl_rate_m3ph_m2  5.846e-02 3.451e-01 5.700e-01 7.835e-01 9.718e-01
# window_opening_ach 1.153e-01 4.568e-01 6.586e-01 8.216e-01 9.814e-01
# %SIGMA@wn2*.pc.mu% 1.351e+05 1.589e+05 1.730e+05 1.874e+05 2.134e+05
# %SIGMA@wn2*.pc1%   1.792e+04 2.106e+04 2.288e+04 2.493e+04 2.884e+04
# %SIGMA@wn2*.pc2%   2.301e+03 2.727e+03 2.966e+03 3.219e+03 3.733e+03
# %SIGMA@wn2*.pc3%   1.872e+01 2.197e+01 2.383e+01 2.576e+01 2.973e+01
# %SIGMA@wn2*.pc4%   5.659e+00 6.662e+00 7.216e+00 7.835e+00 9.009e+00
# *** Simulation 30 / <until converged> (elapsed time: 0.0935 mins) ***
#
# Iterations = 300:11096
# Thinning interval = 4
# Number of chains = 1
# Sample size per chain = 2700
#
# 1. Empirical mean and standard deviation for each variable,
#    plus standard error of the mean:
#
#                         Mean        SD  Naive SE Time-series SE        t    eff
# t_set_heating      6.318e-01 4.845e-02 9.323e-04      1.129e-03 0.001787 0.6822
# infl_rate_m3ph_m2  5.589e-01 2.644e-01 5.089e-03      7.399e-03 0.013238 0.4730
# window_opening_ach 6.227e-01 2.440e-01 4.696e-03      7.039e-03 0.011304 0.4451
# %SIGMA@wn2*.pc.mu% 1.732e+05 2.046e+04 3.938e+02      4.566e+02 0.002636 0.7438
# %SIGMA@wn2*.pc1%   2.302e+04 2.841e+03 5.468e+01      6.586e+01 0.002861 0.6894
# %SIGMA@wn2*.pc2%   2.976e+03 3.638e+02 7.001e+00      8.535e+00 0.002868 0.6730
# %SIGMA@wn2*.pc3%   2.400e+01 2.828e+00 5.443e-02      6.392e-02 0.002664 0.7249
# %SIGMA@wn2*.pc4%   7.243e+00 8.510e-01 1.638e-02      2.049e-02 0.002828 0.6392
#                       s
# t_set_heating      1842
# infl_rate_m3ph_m2  1277
# window_opening_ach 1202
# %SIGMA@wn2*.pc.mu% 2008
# %SIGMA@wn2*.pc1%   1861
# %SIGMA@wn2*.pc2%   1817
# %SIGMA@wn2*.pc3%   1957
# %SIGMA@wn2*.pc4%   1726
#
# 2. Quantiles for each variable:
#
#                         2.5%       25%       50%       75%     97.5%
# t_set_heating      5.361e-01 5.989e-01 6.303e-01 6.639e-01 7.300e-01
# infl_rate_m3ph_m2  4.902e-02 3.446e-01 5.767e-01 7.845e-01 9.760e-01
# window_opening_ach 9.974e-02 4.510e-01 6.532e-01 8.208e-01 9.814e-01
# %SIGMA@wn2*.pc.mu% 1.359e+05 1.589e+05 1.726e+05 1.869e+05 2.134e+05
# %SIGMA@wn2*.pc1%   1.798e+04 2.103e+04 2.290e+04 2.492e+04 2.881e+04
# %SIGMA@wn2*.pc2%   2.294e+03 2.725e+03 2.959e+03 3.214e+03 3.724e+03
# %SIGMA@wn2*.pc3%   1.883e+01 2.197e+01 2.389e+01 2.589e+01 2.973e+01
# %SIGMA@wn2*.pc4%   5.662e+00 6.659e+00 7.214e+00 7.808e+00 8.968e+00
# *** Simulation 35 / <until converged> (elapsed time: 0.108 mins) ***
#
# Iterations = 350:12946
# Thinning interval = 4
# Number of chains = 1
# Sample size per chain = 3150
#
# 1. Empirical mean and standard deviation for each variable,
#    plus standard error of the mean:
#
#                         Mean        SD  Naive SE Time-series SE        t    eff
# t_set_heating      6.314e-01 4.836e-02 8.616e-04      1.046e-03 0.001657 0.6785
# infl_rate_m3ph_m2  5.566e-01 2.645e-01 4.712e-03      6.881e-03 0.012361 0.4690
# window_opening_ach 6.267e-01 2.439e-01 4.346e-03      6.522e-03 0.010408 0.4439
# %SIGMA@wn2*.pc.mu% 1.732e+05 2.026e+04 3.609e+02      4.155e+02 0.002400 0.7546
# %SIGMA@wn2*.pc1%   2.308e+04 2.834e+03 5.049e+01      6.070e+01 0.002630 0.6918
# %SIGMA@wn2*.pc2%   2.971e+03 3.650e+02 6.503e+00      8.020e+00 0.002699 0.6575
# %SIGMA@wn2*.pc3%   2.402e+01 2.835e+00 5.050e-02      6.004e-02 0.002499 0.7077
# %SIGMA@wn2*.pc4%   7.248e+00 8.460e-01 1.507e-02      1.852e-02 0.002555 0.6623
#                       s
# t_set_heating      2137
# infl_rate_m3ph_m2  1477
# window_opening_ach 1398
# %SIGMA@wn2*.pc.mu% 2377
# %SIGMA@wn2*.pc1%   2179
# %SIGMA@wn2*.pc2%   2071
# %SIGMA@wn2*.pc3%   2229
# %SIGMA@wn2*.pc4%   2086
#
# 2. Quantiles for each variable:
#
#                         2.5%       25%       50%       75%     97.5%
# t_set_heating      5.357e-01 5.989e-01 6.303e-01 6.639e-01 7.290e-01
# infl_rate_m3ph_m2  5.495e-02 3.438e-01 5.708e-01 7.827e-01 9.755e-01
# window_opening_ach 9.769e-02 4.576e-01 6.572e-01 8.222e-01 9.823e-01
# %SIGMA@wn2*.pc.mu% 1.360e+05 1.589e+05 1.724e+05 1.870e+05 2.133e+05
# %SIGMA@wn2*.pc1%   1.797e+04 2.110e+04 2.300e+04 2.496e+04 2.878e+04
# %SIGMA@wn2*.pc2%   2.292e+03 2.719e+03 2.952e+03 3.213e+03 3.731e+03
# %SIGMA@wn2*.pc3%   1.883e+01 2.199e+01 2.391e+01 2.592e+01 2.968e+01
# %SIGMA@wn2*.pc4%   5.664e+00 6.669e+00 7.211e+00 7.808e+00 8.978e+00
# *** Simulation 40 / <until converged> (elapsed time: 0.122 mins) ***
#
# Iterations = 400:14796
# Thinning interval = 4
# Number of chains = 1
# Sample size per chain = 3600
#
# 1. Empirical mean and standard deviation for each variable,
#    plus standard error of the mean:
#
#                         Mean        SD  Naive SE Time-series SE        t    eff
# t_set_heating      6.314e-01 4.809e-02 8.016e-04      9.784e-04 0.001550 0.6711
# infl_rate_m3ph_m2  5.597e-01 2.655e-01 4.426e-03      6.417e-03 0.011466 0.4757
# window_opening_ach 6.257e-01 2.451e-01 4.085e-03      6.031e-03 0.009639 0.4587
# %SIGMA@wn2*.pc.mu% 1.732e+05 2.014e+04 3.357e+02      3.862e+02 0.002230 0.7553
# %SIGMA@wn2*.pc1%   2.308e+04 2.824e+03 4.707e+01      5.620e+01 0.002435 0.7016
# %SIGMA@wn2*.pc2%   2.968e+03 3.625e+02 6.042e+00      7.485e+00 0.002522 0.6518
# %SIGMA@wn2*.pc3%   2.401e+01 2.843e+00 4.738e-02      5.597e-02 0.002331 0.7167
# %SIGMA@wn2*.pc4%   7.256e+00 8.453e-01 1.409e-02      1.771e-02 0.002441 0.6327
#                       s
# t_set_heating      2416
# infl_rate_m3ph_m2  1712
# window_opening_ach 1651
# %SIGMA@wn2*.pc.mu% 2719
# %SIGMA@wn2*.pc1%   2526
# %SIGMA@wn2*.pc2%   2346
# %SIGMA@wn2*.pc3%   2580
# %SIGMA@wn2*.pc4%   2278
#
# 2. Quantiles for each variable:
#
#                         2.5%       25%       50%       75%     97.5%
# t_set_heating      5.368e-01 5.992e-01 6.301e-01 6.639e-01 7.288e-01
# infl_rate_m3ph_m2  5.829e-02 3.454e-01 5.747e-01 7.862e-01 9.761e-01
# window_opening_ach 9.089e-02 4.569e-01 6.552e-01 8.240e-01 9.827e-01
# %SIGMA@wn2*.pc.mu% 1.367e+05 1.589e+05 1.726e+05 1.873e+05 2.133e+05
# %SIGMA@wn2*.pc1%   1.797e+04 2.111e+04 2.298e+04 2.496e+04 2.881e+04
# %SIGMA@wn2*.pc2%   2.292e+03 2.716e+03 2.951e+03 3.206e+03 3.709e+03
# %SIGMA@wn2*.pc3%   1.883e+01 2.198e+01 2.389e+01 2.589e+01 2.973e+01
# %SIGMA@wn2*.pc4%   5.676e+00 6.677e+00 7.221e+00 7.830e+00 8.979e+00
# *** Simulation 45 / <until converged> (elapsed time: 0.136 mins) ***
#
# Iterations = 450:16646
# Thinning interval = 4
# Number of chains = 1
# Sample size per chain = 4050
#
# 1. Empirical mean and standard deviation for each variable,
#    plus standard error of the mean:
#
#                         Mean        SD  Naive SE Time-series SE        t    eff
# t_set_heating      6.315e-01 4.796e-02 7.537e-04      9.146e-04 0.001448 0.6790
# infl_rate_m3ph_m2  5.631e-01 2.631e-01 4.134e-03      5.925e-03 0.010523 0.4868
# window_opening_ach 6.249e-01 2.440e-01 3.834e-03      5.566e-03 0.008908 0.4744
# %SIGMA@wn2*.pc.mu% 1.731e+05 2.013e+04 3.164e+02      3.637e+02 0.002102 0.7565
# %SIGMA@wn2*.pc1%   2.308e+04 2.808e+03 4.412e+01      5.227e+01 0.002264 0.7123
# %SIGMA@wn2*.pc2%   2.970e+03 3.656e+02 5.745e+00      7.112e+00 0.002395 0.6526
# %SIGMA@wn2*.pc3%   2.399e+01 2.863e+00 4.498e-02      5.368e-02 0.002237 0.7023
# %SIGMA@wn2*.pc4%   7.255e+00 8.410e-01 1.321e-02      1.602e-02 0.002209 0.6801
#                       s
# t_set_heating      2750
# infl_rate_m3ph_m2  1972
# window_opening_ach 1922
# %SIGMA@wn2*.pc.mu% 3064
# %SIGMA@wn2*.pc1%   2885
# %SIGMA@wn2*.pc2%   2643
# %SIGMA@wn2*.pc3%   2844
# %SIGMA@wn2*.pc4%   2754
#
# 2. Quantiles for each variable:
#
#                         2.5%       25%       50%       75%     97.5%
# t_set_heating      5.377e-01 5.993e-01 6.303e-01 6.642e-01 7.287e-01
# infl_rate_m3ph_m2  6.026e-02 3.509e-01 5.787e-01 7.865e-01 9.754e-01
# window_opening_ach 9.123e-02 4.556e-01 6.542e-01 8.227e-01 9.820e-01
# %SIGMA@wn2*.pc.mu% 1.364e+05 1.589e+05 1.726e+05 1.869e+05 2.133e+05
# %SIGMA@wn2*.pc1%   1.799e+04 2.114e+04 2.297e+04 2.494e+04 2.875e+04
# %SIGMA@wn2*.pc2%   2.293e+03 2.716e+03 2.955e+03 3.205e+03 3.725e+03
# %SIGMA@wn2*.pc3%   1.877e+01 2.197e+01 2.385e+01 2.590e+01 2.973e+01
# %SIGMA@wn2*.pc4%   5.684e+00 6.677e+00 7.221e+00 7.808e+00 8.976e+00
# *** Simulation 50 / <until converged> (elapsed time: 0.15 mins) ***
#
# Iterations = 500:18496
# Thinning interval = 4
# Number of chains = 1
# Sample size per chain = 4500
#
# 1. Empirical mean and standard deviation for each variable,
#    plus standard error of the mean:
#
#                         Mean        SD  Naive SE Time-series SE        t    eff
# t_set_heating      6.322e-01 4.800e-02 7.155e-04      8.712e-04 0.001378 0.6746
# infl_rate_m3ph_m2  5.627e-01 2.623e-01 3.910e-03      5.795e-03 0.010300 0.4551
# window_opening_ach 6.236e-01 2.442e-01 3.641e-03      5.374e-03 0.008617 0.4590
# %SIGMA@wn2*.pc.mu% 1.732e+05 2.022e+04 3.014e+02      3.335e+02 0.001925 0.8170
# %SIGMA@wn2*.pc1%   2.311e+04 2.796e+03 4.168e+01      4.933e+01 0.002134 0.7141
# %SIGMA@wn2*.pc2%   2.970e+03 3.644e+02 5.432e+00      6.692e+00 0.002253 0.6588
# %SIGMA@wn2*.pc3%   2.400e+01 2.866e+00 4.273e-02      5.086e-02 0.002119 0.7056
# %SIGMA@wn2*.pc4%   7.260e+00 8.446e-01 1.259e-02      1.533e-02 0.002112 0.6744
#                       s
# t_set_heating      3036
# infl_rate_m3ph_m2  2048
# window_opening_ach 2065
# %SIGMA@wn2*.pc.mu% 3676
# %SIGMA@wn2*.pc1%   3214
# %SIGMA@wn2*.pc2%   2965
# %SIGMA@wn2*.pc3%   3175
# %SIGMA@wn2*.pc4%   3035
#
# 2. Quantiles for each variable:
#
#                         2.5%       25%       50%       75%     97.5%
# t_set_heating      5.395e-01 5.998e-01 6.310e-01 6.650e-01 7.289e-01
# infl_rate_m3ph_m2  6.310e-02 3.510e-01 5.790e-01 7.847e-01 9.761e-01
# window_opening_ach 8.973e-02 4.535e-01 6.531e-01 8.217e-01 9.823e-01
# %SIGMA@wn2*.pc.mu% 1.363e+05 1.589e+05 1.727e+05 1.872e+05 2.133e+05
# %SIGMA@wn2*.pc1%   1.802e+04 2.115e+04 2.301e+04 2.496e+04 2.876e+04
# %SIGMA@wn2*.pc2%   2.296e+03 2.714e+03 2.955e+03 3.208e+03 3.709e+03
# %SIGMA@wn2*.pc3%   1.876e+01 2.199e+01 2.386e+01 2.592e+01 2.976e+01
# %SIGMA@wn2*.pc4%   5.686e+00 6.677e+00 7.223e+00 7.816e+00 8.998e+00
# *** Simulation 55 / <until converged> (elapsed time: 0.164 mins) ***
#
# Iterations = 550:20346
# Thinning interval = 4
# Number of chains = 1
# Sample size per chain = 4950
#
# 1. Empirical mean and standard deviation for each variable,
#    plus standard error of the mean:
#
#                         Mean        SD  Naive SE Time-series SE        t    eff
# t_set_heating      6.323e-01 4.794e-02 6.813e-04      8.315e-04 0.001315 0.6714
# infl_rate_m3ph_m2  5.637e-01 2.640e-01 3.752e-03      5.783e-03 0.010260 0.4209
# window_opening_ach 6.213e-01 2.454e-01 3.487e-03      5.182e-03 0.008340 0.4530
# %SIGMA@wn2*.pc.mu% 1.734e+05 2.013e+04 2.862e+02      3.264e+02 0.001883 0.7689
# %SIGMA@wn2*.pc1%   2.310e+04 2.790e+03 3.966e+01      4.665e+01 0.002019 0.7228
# %SIGMA@wn2*.pc2%   2.967e+03 3.630e+02 5.160e+00      6.301e+00 0.002123 0.6706
# %SIGMA@wn2*.pc3%   2.399e+01 2.860e+00 4.065e-02      4.831e-02 0.002014 0.7081
# %SIGMA@wn2*.pc4%   7.269e+00 8.505e-01 1.209e-02      1.488e-02 0.002047 0.6604
#                       s
# t_set_heating      3323
# infl_rate_m3ph_m2  2083
# window_opening_ach 2242
# %SIGMA@wn2*.pc.mu% 3806
# %SIGMA@wn2*.pc1%   3578
# %SIGMA@wn2*.pc2%   3319
# %SIGMA@wn2*.pc3%   3505
# %SIGMA@wn2*.pc4%   3269
#
# 2. Quantiles for each variable:
#
#                         2.5%       25%       50%       75%     97.5%
# t_set_heating      5.395e-01 5.999e-01 6.313e-01 6.650e-01 7.290e-01
# infl_rate_m3ph_m2  6.446e-02 3.498e-01 5.795e-01 7.896e-01 9.792e-01
# window_opening_ach 8.840e-02 4.484e-01 6.522e-01 8.206e-01 9.817e-01
# %SIGMA@wn2*.pc.mu% 1.366e+05 1.590e+05 1.729e+05 1.873e+05 2.134e+05
# %SIGMA@wn2*.pc1%   1.805e+04 2.114e+04 2.301e+04 2.496e+04 2.874e+04
# %SIGMA@wn2*.pc2%   2.294e+03 2.716e+03 2.951e+03 3.205e+03 3.709e+03
# %SIGMA@wn2*.pc3%   1.873e+01 2.198e+01 2.386e+01 2.588e+01 2.975e+01
# %SIGMA@wn2*.pc4%   5.683e+00 6.689e+00 7.238e+00 7.833e+00 9.005e+00
# *** Simulation 60 / <until converged> (elapsed time: 0.178 mins) ***
#
# Iterations = 600:22196
# Thinning interval = 4
# Number of chains = 1
# Sample size per chain = 5400
#
# 1. Empirical mean and standard deviation for each variable,
#    plus standard error of the mean:
#
#                         Mean        SD  Naive SE Time-series SE        t    eff
# t_set_heating      6.318e-01 4.797e-02 6.527e-04      8.028e-04 0.001271 0.6611
# infl_rate_m3ph_m2  5.653e-01 2.649e-01 3.604e-03      5.571e-03 0.009854 0.4186
# window_opening_ach 6.199e-01 2.459e-01 3.346e-03      4.864e-03 0.007846 0.4732
# %SIGMA@wn2*.pc.mu% 1.733e+05 2.019e+04 2.748e+02      3.217e+02 0.001857 0.7297
# %SIGMA@wn2*.pc1%   2.311e+04 2.794e+03 3.802e+01      4.485e+01 0.001941 0.7186
# %SIGMA@wn2*.pc2%   2.965e+03 3.632e+02 4.943e+00      6.002e+00 0.002024 0.6783
# %SIGMA@wn2*.pc3%   2.399e+01 2.856e+00 3.886e-02      4.614e-02 0.001923 0.7096
# %SIGMA@wn2*.pc4%   7.273e+00 8.571e-01 1.166e-02      1.412e-02 0.001941 0.6828
#                       s
# t_set_heating      3570
# infl_rate_m3ph_m2  2260
# window_opening_ach 2555
# %SIGMA@wn2*.pc.mu% 3940
# %SIGMA@wn2*.pc1%   3880
# %SIGMA@wn2*.pc2%   3663
# %SIGMA@wn2*.pc3%   3832
# %SIGMA@wn2*.pc4%   3687
#
# 2. Quantiles for each variable:
#
#                         2.5%       25%       50%       75%     97.5%
# t_set_heating      5.395e-01 5.991e-01 6.307e-01 6.646e-01 7.289e-01
# infl_rate_m3ph_m2  6.052e-02 3.503e-01 5.823e-01 7.941e-01 9.796e-01
# window_opening_ach 8.759e-02 4.474e-01 6.495e-01 8.213e-01 9.827e-01
# %SIGMA@wn2*.pc.mu% 1.362e+05 1.590e+05 1.728e+05 1.870e+05 2.137e+05
# %SIGMA@wn2*.pc1%   1.805e+04 2.113e+04 2.302e+04 2.498e+04 2.875e+04
# %SIGMA@wn2*.pc2%   2.291e+03 2.714e+03 2.951e+03 3.206e+03 3.695e+03
# %SIGMA@wn2*.pc3%   1.876e+01 2.198e+01 2.389e+01 2.586e+01 2.976e+01
# %SIGMA@wn2*.pc4%   5.683e+00 6.684e+00 7.241e+00 7.844e+00 9.021e+00
# $CALIBRATION_RESULTS
#            PARAMETER   ESTIMATE       LOWER      UPPER
# 1      t_set_heating 21.7288724 21.24771581 22.3710119
# 2  infl_rate_m3ph_m2  4.5124785  3.39499491  4.7972873
# 3 window_opening_ach  0.1485479  0.03404208  0.1994079
#
# $CALIBRATED_MODEL_GOF
#              sim       cals
# data1 0.07967615 0.07771449
# Warning messages:
# 1: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 2: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 3: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 4: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# Warning messages:
# 1: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 2: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 3: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 4: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# processing file: /opt/homebrew/lib/R/4.3/site-library/calibro/calibro_report.Rnw
# 1/44
# 2/44 [setup]
# 3/44
# 4/44 [exeSumm]
# 5/44
# 6/44 [content]
# 7/44
# 8/44 [genVar]
# 9/44
# 10/44 [dsVar]
# 11/44 [dsText]
# 12/44
# 13/44 [ds1]
# 14/44 [ds2]
# 15/44 [ds3]
# 16/44 [ds4]
# 17/44 [ds5]
# 18/44 [ds6]
# 19/44 [ds7]
# 20/44 [ds8]
# 21/44 [ds9]
# 22/44 [ds10]
# 23/44
# 24/44 [saVar]
# 25/44 [saText]
# 26/44
# 27/44 [ret_tables]
# 28/44
# 29/44 [train]
# 30/44
# 31/44 [calVar]
# 32/44 [cal]
# 33/44 [thetaplot]
# 34/44 [ds1fit]
# 35/44 [ds2fit]
# 36/44 [ds3fit]
# 37/44 [ds4fit]
# 38/44 [ds5fit]
# 39/44 [ds6fit]
# 40/44 [ds7fit]
# 41/44 [ds8fit]
# 42/44 [ds9fit]
# 43/44 [ds10fit]
# 44/44
# output file: calibro_report.tex
# [1] "calibro_report.pdf"
# ✓ Calibro finished successfully.
#
# 🎉 Experiment complete. Results saved to: /Users/rui.bo/Desktop/BASE/1_phd/Y3/RC_br/_json/_run/JUN11__ETHlib_bldg_LoD_Y/calibro
# Warning: LaTeX Warning: `!h' float specifier changed to `!ht'.
# Warning: LaTeX Warning: `!h' float specifier changed to `!ht'.
# Warning messages:
# 1: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 2: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 3: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 4: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
