# %%
DATE = 'JUN11'
default_json  = '_json/default_params.json'
controller_mode = 'occupancy'
start = "2023-02-01 00:00"
end   = "2023-03-10 23:00"

# %%
from pathlib import Path
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json

RC_SIMULATOR = "ETHlib"
if RC_SIMULATOR not in sys.path:
    sys.path.insert(0, RC_SIMULATOR)

from _ import *
from _BR_ import *
from _zone_ import DebugZone as Zone
import supply_system
import emission_system
case = RCCase(
    year=2023,
    loc_json              = Path("_json/location_params.json"),
    geo_json              = Path("_json/geo_params.json"),
    default_json          = Path("_json/default_params.json"),
    epw_path              = Path("../src/_base/epw/ED-TMYx.2023.epw"),
    occupancy_profile_csv = Path("ETHlib/auxiliary/schedules_el_OFFICE.csv"),
    Zone=Zone,
    supply_system=supply_system,
    emission_system=emission_system,
)
case.occupancy_profile = (
    pd.read_csv(Path("_data/bldg_LoD.csv"), usecols=["D"])
      .rename(columns={"D": "People"})
      .iloc[:8760]
      .reset_index(drop=True)
)

# %%
DEFAULT_PARAMS = json.loads(Path(default_json).read_text())
RUN_DIR = Path(f"_json/_run/{DATE}")
uq_json_path = RUN_DIR / "OAT.json"

meter_path = "_data/Metering_ISO.csv"
meter_daily = load_meter_heating(
    meter_path,
    "Main Heating",
    case.geometry["FLOOR_AREA"],
    "D",
)
meter_hourly = load_meter_heating(
    meter_path,
    "Main Heating",
    case.geometry["FLOOR_AREA"],
    "h",
)
# Out:
# Metering Timestamp: 2023-01-01 00:00:00 ~ 2023-12-31 23:00:00
# Metering Timestamp: 2023-01-01 00:00:00 ~ 2023-12-31 23:00:00

# %% [markdown]
# # RUN

# %%
from _ import show_progress
from scipy.stats import qmc
def make_lhs_samples_from_uq_json(uq_json_path, N=100, save_csv=True):
    
    uq_json_path = Path(uq_json_path)

    with open(uq_json_path, "r", encoding="utf-8") as f:
        uq_config = json.load(f)

    N = N
    seed = uq_config["seed"]
    params = uq_config["parameters"]

    param_names = list(params.keys())
    n_dim = len(param_names)

    sampler = qmc.LatinHypercube(d=n_dim, seed=seed)
    lhs_unit = sampler.random(n=N)

    samples = pd.DataFrame(index=range(N), columns=param_names, dtype=float)

    for i, name in enumerate(param_names):
        lower = params[name]["lower"]
        upper = params[name]["upper"]

        samples[name] = lower + lhs_unit[:, i] * (upper - lower)

    samples.index = [f"sample_{i+1:03d}" for i in range(N)]

    if save_csv:
        output_path = uq_json_path.parent / f"LHS_samples.csv"
        samples.to_csv(output_path)
        print(f"Saved LHS samples to: {output_path}")

    return samples

def run_lhs_samples(
    lhs_samples,
    controller_mode="occupancy",
):
    results = {}
    euis = {}

    for sample_id, row in show_progress(
        lhs_samples.iterrows(),
        total=len(lhs_samples),
        desc="Running samples",
        unit="sample",
    ):
        sampled_params = row.to_dict()

        res, eui, _ = run_model_case(
            case=case,
            sampled_params=sampled_params,
            controller_mode=controller_mode,
        )

        results[sample_id] = res
        euis[sample_id] = eui

    eui_df = pd.DataFrame(euis).T

    return results, eui_df

# %%
lhs_samples= make_lhs_samples_from_uq_json(
uq_json_path=uq_json_path,
N=40
)

lhs_results_occ, lhs_eui_df_occ = run_lhs_samples(
lhs_samples  = lhs_samples,
controller_mode = controller_mode,
)
# Out:
# Saved LHS samples to: _json/_run/JUN11/LHS_samples.csv
# Running samples:   0%|          | 0/40 [00:00<?, ?sample/s]

# %%
def calc_metrics(sim, obs):
    df = pd.concat(
        [sim.rename("sim"), obs.rename("obs")],
        axis=1,
    ).dropna()

    error = df["obs"] - df["sim"]
    obs_mean = df["obs"].mean()

    cvrmse = np.sqrt(np.mean(error ** 2)) / obs_mean * 100
    nmbe = error.sum() / (len(df) * obs_mean) * 100

    return cvrmse, nmbe


def compare_lhs_to_meter(
    lhs_results,
    meter_series,
    variable="HeatingEnergy",
    freq_label="hourly",
):
    rows = []

    for sample_id, res in lhs_results.items():
        cvrmse, nmbe = calc_metrics(res[variable], meter_series)
        rows.append((sample_id, freq_label, cvrmse, nmbe))

    return pd.DataFrame(
        rows,
        columns=["sample_id", "freq", "cvrmse", "nmbe"],
    ).set_index("sample_id")

# %%
KPI = "HeatingEnergy"
temp_res = "D"

meter_series = meter_hourly.resample(temp_res).sum()

lhs_results_res = {
    sample_id: res[[KPI]].resample(temp_res).sum()
    for sample_id, res in lhs_results_occ.items()
}

lhs_metrics_res = compare_lhs_to_meter(
    lhs_results=lhs_results_res,
    meter_series=meter_series,
    variable=KPI,
    freq_label=temp_res,
)

# %% [markdown]
# # Training dataset for `calibro`
# * temp_res = "H"   # hourly
# * temp_res = "D"   # daily
# * temp_res = "W"   # weekly
# * temp_res = "ME"  # month-end

# %%
def save_bayesian_calibration_files(
    lhs_samples,
    lhs_results,
    meter_series,
    variable="HeatingEnergy",
    freq="D",
    start=None,
    end=None,
    output_dir=Path(f"json/UQ/{DATE}_lhs"),
):
    output_dir = Path(output_dir)
    output_dir.mkdir(parents=True, exist_ok=True)

    TT = lhs_samples.copy()

    def prepare_series(series):
        series = series.copy()

        if start is not None or end is not None:
            series = series.loc[start:end]

        if freq is not None:
            series = series.resample(freq).sum()

        return series

    Y = pd.DataFrame({
        sample_id: prepare_series(res[variable])
        for sample_id, res in lhs_results.items()
    })

    obs = prepare_series(meter_series)
    obs.name = "obs"

    common_index = obs.index.intersection(Y.index)

    obs = obs.loc[common_index]
    Y = Y.loc[common_index]

    # Drop index columns when saving to CSV
    TT.to_csv(output_dir / "TT.csv", index=False)
    Y.to_csv(output_dir / "Y.csv", index=False)
    obs.to_csv(output_dir / "obs.csv", index=False)

    print(f"Saved Bayesian calibration files to: {output_dir}")
    print(f"Period: {obs.index.min()} to {obs.index.max()}")
    print(f"TT shape:  {TT.shape}")
    print(f"Y shape:   {Y.shape}")
    print(f"obs shape: {obs.shape}")

    return TT, Y, obs

KPI = "HeatingEnergy"
temp_res = "D"

output_dir = RUN_DIR / "BC"

TT, Y, obs = save_bayesian_calibration_files(
    lhs_samples=lhs_samples,
    lhs_results=lhs_results_occ,
    meter_series=meter_hourly,
    variable=KPI,
    freq=temp_res,
    start=start,
    end=end,
    output_dir=output_dir,
)
# Out:
# Saved Bayesian calibration files to: _json/_run/JUN11/BC
# Period: 2023-02-01 00:00:00 to 2023-03-10 00:00:00
# TT shape:  (40, 4)
# Y shape:   (38, 40)
# obs shape: (38,)

# %% [markdown]
# # Execution of `Calibro`

# %%
import papermill as pm

NOTEBOOK_IN = "1_CALIBRO.ipynb"

pm.execute_notebook(
    NOTEBOOK_IN,
    f"{DATE}.ipynb",
    parameters={
        "DATE": DATE,
        "START_DATE": start,
        "END_DATE": end,
    },
)
# Out:
# Passed unknown parameter: DATE
# Passed unknown parameter: START_DATE
# Passed unknown parameter: END_DATE
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/4 [00:00<?, ?cell/s]
# Loading required package: R6
# Loading required package: coda
# Loading required package: parallel
# Loading required package: MASS
# Loading required package: modeest
# ### NELDER-MEAD DOWNHILL SIMPLEX ALGORITHM ###
#
#  Version: amoeba
#  Start time: 2026-06-14 21:52:01.235202
#  Number of simulations: 5
#
#
# *** Simulation 1 / 5 (elapsed time: 0.00117 mins) ***
#
#  best y: 263.589762958277
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc.mu = 0.1073
# 	 %RHO@window_opening_ach%@sePar01.pc.mu = 0.2024
# 	 %ALPHA1@sePar01.pc.mu = 0.9999
# 	 %SIGMA1@wn1.pc.mu = 0.9999
# 	 %SIGMA1@wn2.pc.mu = 7.7e+07
#
# *** Simulation 2 / 5 (elapsed time: 0.002 mins) ***
#
#  best y: 271.798843716433
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc.mu = 0.3665
# 	 %RHO@window_opening_ach%@sePar01.pc.mu = 0.4736
# 	 %ALPHA1@sePar01.pc.mu = 0.9999
# 	 %SIGMA1@wn1.pc.mu = 0.9999
# 	 %SIGMA1@wn2.pc.mu = 86270000
#
# *** Simulation 3 / 5 (elapsed time: 0.00224 mins) ***
#
#  best y: 271.798843716433
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc.mu = 0.3665
# 	 %RHO@window_opening_ach%@sePar01.pc.mu = 0.4736
# 	 %ALPHA1@sePar01.pc.mu = 0.9999
# 	 %SIGMA1@wn1.pc.mu = 0.9999
# 	 %SIGMA1@wn2.pc.mu = 86270000
#
# *** Simulation 4 / 5 (elapsed time: 0.00255 mins) ***
#
#  best y: 271.890942112667
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc.mu = 0.3869
# 	 %RHO@window_opening_ach%@sePar01.pc.mu = 0.448
# 	 %ALPHA1@sePar01.pc.mu = 0.9999
# 	 %SIGMA1@wn1.pc.mu = 0.9999
# 	 %SIGMA1@wn2.pc.mu = 86840000
#
# *** Simulation 5 / 5 (elapsed time: 0.0028 mins) ***
#
#  best y: 271.890942112667
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc.mu = 0.3869
# 	 %RHO@window_opening_ach%@sePar01.pc.mu = 0.448
# 	 %ALPHA1@sePar01.pc.mu = 0.9999
# 	 %SIGMA1@wn1.pc.mu = 0.9999
# 	 %SIGMA1@wn2.pc.mu = 86840000
#
# *** Simulation 6 / 5 (elapsed time: 0.00306 mins) ***
#
#  best y: 271.890942112667
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc.mu = 0.3869
# 	 %RHO@window_opening_ach%@sePar01.pc.mu = 0.448
# 	 %ALPHA1@sePar01.pc.mu = 0.9999
# 	 %SIGMA1@wn1.pc.mu = 0.9999
# 	 %SIGMA1@wn2.pc.mu = 86840000
#
# ### NELDER-MEAD DOWNHILL SIMPLEX ALGORITHM ###
#
#  Version: amoeba
#  Start time: 2026-06-14 21:52:01.467884
#  Number of simulations: 5
#
#
# *** Simulation 1 / 5 (elapsed time: 0.000501 mins) ***
#
#  best y: 243.803803354918
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc1 = 0.3833
# 	 %ALPHA1@sePar01.pc1 = 0.9999
# 	 %SIGMA1@wn1.pc1 = 0.9999
# 	 %SIGMA1@wn2.pc1 = 10610000
#
# *** Simulation 2 / 5 (elapsed time: 0.000712 mins) ***
#
#  best y: 243.803803354918
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc1 = 0.3833
# 	 %ALPHA1@sePar01.pc1 = 0.9999
# 	 %SIGMA1@wn1.pc1 = 0.9999
# 	 %SIGMA1@wn2.pc1 = 10610000
#
# *** Simulation 3 / 5 (elapsed time: 0.000971 mins) ***
#
#  best y: 266.530338486965
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc1 = 0.1133
# 	 %ALPHA1@sePar01.pc1 = 0.9999
# 	 %SIGMA1@wn1.pc1 = 0.9999
# 	 %SIGMA1@wn2.pc1 = 13680000
#
# *** Simulation 4 / 5 (elapsed time: 0.00122 mins) ***
#
#  best y: 266.530338486965
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc1 = 0.1133
# 	 %ALPHA1@sePar01.pc1 = 0.9999
# 	 %SIGMA1@wn1.pc1 = 0.9999
# 	 %SIGMA1@wn2.pc1 = 13680000
#
# *** Simulation 5 / 5 (elapsed time: 0.00145 mins) ***
#
#  best y: 266.530338486965
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc1 = 0.1133
# 	 %ALPHA1@sePar01.pc1 = 0.9999
# 	 %SIGMA1@wn1.pc1 = 0.9999
# 	 %SIGMA1@wn2.pc1 = 13680000
#
# *** Simulation 6 / 5 (elapsed time: 0.00167 mins) ***
#
#  best y: 266.530338486965
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc1 = 0.1133
# 	 %ALPHA1@sePar01.pc1 = 0.9999
# 	 %SIGMA1@wn1.pc1 = 0.9999
# 	 %SIGMA1@wn2.pc1 = 13680000
#
# ### NELDER-MEAD DOWNHILL SIMPLEX ALGORITHM ###
#
#  Version: amoeba
#  Start time: 2026-06-14 21:52:01.606979
#  Number of simulations: 5
#
#
# *** Simulation 1 / 5 (elapsed time: 0.000371 mins) ***
#
#  best y: 88.9468423935513
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc2 = 1
# 	 %ALPHA1@sePar01.pc2 = 1
# 	 %SIGMA1@wn1.pc2 = 0.9879
# 	 %SIGMA1@wn2.pc2 = 745700
#
# *** Simulation 2 / 5 (elapsed time: 0.000624 mins) ***
#
#  best y: 88.9468423935513
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc2 = 1
# 	 %ALPHA1@sePar01.pc2 = 1
# 	 %SIGMA1@wn1.pc2 = 0.9879
# 	 %SIGMA1@wn2.pc2 = 745700
#
# *** Simulation 3 / 5 (elapsed time: 0.00091 mins) ***
#
#  best y: 161.044133927572
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc2 = 0.108
# 	 %ALPHA1@sePar01.pc2 = 0.9984
# 	 %SIGMA1@wn1.pc2 = 0.9996
# 	 %SIGMA1@wn2.pc2 = 749100
#
# *** Simulation 4 / 5 (elapsed time: 0.00125 mins) ***
#
#  best y: 161.044133927572
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc2 = 0.108
# 	 %ALPHA1@sePar01.pc2 = 0.9984
# 	 %SIGMA1@wn1.pc2 = 0.9996
# 	 %SIGMA1@wn2.pc2 = 749100
#
# *** Simulation 5 / 5 (elapsed time: 0.00157 mins) ***
#
#  best y: 161.044133927572
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc2 = 0.108
# 	 %ALPHA1@sePar01.pc2 = 0.9984
# 	 %SIGMA1@wn1.pc2 = 0.9996
# 	 %SIGMA1@wn2.pc2 = 749100
#
# *** Simulation 6 / 5 (elapsed time: 0.00189 mins) ***
#
#  best y: 161.044712802711
#  best z:
# 	 %RHO@t_set_heating%@sePar01.pc2 = 0.1109
# 	 %ALPHA1@sePar01.pc2 = 0.9984
# 	 %SIGMA1@wn1.pc2 = 0.9996
# 	 %SIGMA1@wn2.pc2 = 746800
#
# ### NELDER-MEAD DOWNHILL SIMPLEX ALGORITHM ###
#
#  Version: amoeba
#  Start time: 2026-06-14 21:52:01.759937
#  Number of simulations: 5
#
#
# *** Simulation 1 / 5 (elapsed time: 0.000617 mins) ***
#
#  best y: 103.824631884418
#  best z:
# 	 %RHO@window_opening_ach%@sePar01.pc3 = 0.1429
# 	 %ALPHA1@sePar01.pc3 = 0.9983
# 	 %SIGMA1@wn1.pc3 = 0.9925
# 	 %SIGMA1@wn2.pc3 = 2757
#
# *** Simulation 2 / 5 (elapsed time: 0.000888 mins) ***
#
#  best y: 103.824631884418
#  best z:
# 	 %RHO@window_opening_ach%@sePar01.pc3 = 0.1429
# 	 %ALPHA1@sePar01.pc3 = 0.9983
# 	 %SIGMA1@wn1.pc3 = 0.9925
# 	 %SIGMA1@wn2.pc3 = 2757
#
# *** Simulation 3 / 5 (elapsed time: 0.00116 mins) ***
#
#  best y: 103.82746617689
#  best z:
# 	 %RHO@window_opening_ach%@sePar01.pc3 = 0.1559
# 	 %ALPHA1@sePar01.pc3 = 0.9984
# 	 %SIGMA1@wn1.pc3 = 0.9925
# 	 %SIGMA1@wn2.pc3 = 2763
#
# ### ADAPTIVE METROPOLIS WITHIN GIBBS ALGORITHM ###
#
#  Start time: 2026-06-14 21:52:02.557457
#  Number of chains: 1
#  Number of simulations: <until converged>
#
# *** Simulation 5 / <until converged> (elapsed time: 0.0101 mins) ***
#
# Iterations = 50:1846
# Thinning interval = 4
# Number of chains = 1
# Sample size per chain = 450
#
# 1. Empirical mean and standard deviation for each variable,
#    plus standard error of the mean:
#
#                         Mean        SD  Naive SE Time-series SE        t    eff
# t_set_heating      9.551e-01 5.266e-02 2.483e-03      4.313e-03 0.004515 0.3314
# window_opening_ach 4.138e-01 2.396e-01 1.129e-02      1.601e-02 0.038681 0.4980
# %SIGMA@wn2*.pc.mu% 1.160e+05 1.802e+04 8.496e+02      1.657e+03 0.014283 0.2627
# %SIGMA@wn2*.pc1%   1.144e+04 1.962e+03 9.248e+01      1.174e+02 0.010255 0.6210
# %SIGMA@wn2*.pc2%   8.616e+02 1.472e+02 6.939e+00      1.239e+01 0.014376 0.3138
# %SIGMA@wn2*.pc3%   3.645e+00 4.944e-01 2.331e-02      3.030e-02 0.008312 0.5918
#                        s
# t_set_heating      149.1
# window_opening_ach 224.1
# %SIGMA@wn2*.pc.mu% 118.2
# %SIGMA@wn2*.pc1%   279.4
# %SIGMA@wn2*.pc2%   141.2
# %SIGMA@wn2*.pc3%   266.3
#
# 2. Quantiles for each variable:
#
#                         2.5%       25%       50%       75%     97.5%
# t_set_heating
# %SIGMA@wn2*.pc2%   8.454e+02 1.327e+02 1.886e+00      2.627e+00 0.003108 0.5153
# %SIGMA@wn2*.pc3%   3.666e+00 5.298e-01 7.530e-03      8.988e-03 0.002452 0.7020
#                         s
# t_set_heating       898.9
# window_opening_ach 3254.8
# %SIGMA@wn2*.pc.mu% 3549.7
# %SIGMA@wn2*.pc1%   2951.8
# %SIGMA@wn2*.pc2%   2550.5
# %SIGMA@wn2*.pc3%   3474.8
#
# 2. Quantiles for each variable:
#
#                         2.5%       25%       50%       75%     97.5%
# t_set_heating      7.576e-01 9.285e-01 9.719e-01 9.898e-01 9.991e-01
# window_opening_ach 2.681e-02 2.246e-01 4.153e-01 5.848e-01 9.256e-01
# %SIGMA@wn2*.pc.mu% 8.496e+04 1.039e+05 1.152e+05 1.275e+05 1.521e+05
# %SIGMA@wn2*.pc1%   7.950e+03 1.010e+04 1.138e+04 1.286e+04 1.601e+04
# %SIGMA@wn2*.pc2%   5.936e+02 7.563e+02 8.392e+02 9.306e+02 1.119e+03
# %SIGMA@wn2*.pc3%   2.724e+00 3.298e+00 3.624e+00 4.006e+00 4.813e+00
#
# *** Simulation 60 / <until converged> (elapsed time: 0.0618 mins) ***
#
# Iterations = 600:22196
# Thinning interval = 4
# Number of chains = 1
# Sample size per chain = 5400
#
# 1. Empirical mean and standard deviation for each variable,
#    plus standard error of the mean:
#
#                         Mean        SD  Naive SE Time-series SE        t    eff
# t_set_heating      9.464e-01 6.540e-02 8.899e-04      2.067e-03 0.002184 0.1855
# window_opening_ach 4.223e-01 2.414e-01 3.284e-03      4.052e-03 0.009596 0.6569
# %SIGMA@wn2*.pc.mu% 1.162e+05 1.712e+04 2.329e+02      2.744e+02 0.002361 0.7206
# %SIGMA@wn2*.pc1%   1.153e+04 2.040e+03 2.775e+01      3.582e+01 0.003108 0.6003
# %SIGMA@wn2*.pc2%   8.474e+02 1.324e+02 1.801e+00      2.529e+00 0.002985 0.5071
# %SIGMA@wn2*.pc3%   3.663e+00 5.280e-01 7.185e-03      8.486e-03 0.002317 0.7170
#                       s
# t_set_heating      1001
# window_opening_ach 3547
# %SIGMA@wn2*.pc.mu% 3891
# %SIGMA@wn2*.pc1%   3241
# %SIGMA@wn2*.pc2%   2738
# %SIGMA@wn2*.pc3%   3872
#
# 2. Quantiles for each variable:
#
#                         2.5%       25%       50%       75%     97.5%
# t_set_heating      7.580e-01 9.292e-01 9.721e-01 9.899e-01 9.991e-01
# window_opening_ach 2.695e-02 2.249e-01 4.197e-01 5.905e-01 9.252e-01
# %SIGMA@wn2*.pc.mu% 8.498e+04 1.038e+05 1.153e+05 1.276e+05 1.521e+05
# %SIGMA@wn2*.pc1%   7.969e+03 1.012e+04 1.138e+04 1.286e+04 1.597e+04
# %SIGMA@wn2*.pc2%   5.971e+02 7.572e+02 8.414e+02 9.326e+02 1.119e+03
# %SIGMA@wn2*.pc3%   2.716e+00 3.293e+00 3.624e+00 4.003e+00 4.800e+00
#
# $CALIBRATION_RESULTS
#            PARAMETER   ESTIMATE       LOWER      UPPER
# 1      t_set_heating 23.0741992 22.26459105 23.0891283
# 2 window_opening_ach  0.1187563  0.02811256  0.1940576
#
# $CALIBRATED_MODEL_GOF
#              sim       cals
# data1 0.08148599 0.08324607
# Warning messages:
# 1: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 2: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 3: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 4: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 5: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 6: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 7: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 8: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# Warning messages:
# 1: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 2: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 3: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 4: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 5: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 6: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 7: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 8: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
#
#
# processing file: /opt/homebrew/lib/R/4.3/site-library/calibro/calibro_report.Rnw
# 1/44
# 2/44 [setup]
# 3/44
# 4/44 [exeSumm]
# 5/44
# 6/44 [content]
# 7/44
# 8/44 [genVar]
# 9/44
# 10/44 [dsVar]
# 11/44 [dsText]
# 12/44
# 13/44 [ds1]
# 14/44 [ds2]
# 15/44 [ds3]
# 16/44 [ds4]
# 17/44 [ds5]
# 18/44 [ds6]
# 19/44 [ds7]
# 20/44 [ds8]
# 21/44 [ds9]
# 22/44 [ds10]
# 23/44
# 24/44 [saVar]
# 25/44 [saText]
# 26/44
# 27/44 [ret_tables]
# 28/44
# 29/44 [train]
# 30/44
# 31/44 [calVar]
# 32/44 [cal]
# 33/44 [thetaplot]
# 34/44 [ds1fit]
# 35/44 [ds2fit]
# 36/44 [ds3fit]
# 37/44 [ds4fit]
# 38/44 [ds5fit]
# 39/44 [ds6fit]
# 40/44 [ds7fit]
# 41/44 [ds8fit]
# 42/44 [ds9fit]
# 43/44 [ds10fit]
# 44/44
# output file: calibro_report.tex
# [1] "calibro_report.pdf"
# Warning: LaTeX Warning: `!h' float specifier changed to `!ht'.
# Warning: LaTeX Warning: `!h' float specifier changed to `!ht'.
# Warning messages:
# 1: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 2: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 3: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 4: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 5: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 6: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 7: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# 8: encountered a tie, and the difference between minimal and
#                    maximal value is > length('x') * 'tie.limit'
# the distribution could be multimodal
# {'cells': [{'id': 'ee942dd9',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2026-06-14T20:51:45.761979',
#      'end_time': '2026-06-14T20:51:45.778798',
#      'duration': 0.016819,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2026-06-14T20:51:45.768198Z',
#      'iopub.execute_input': '2026-06-14T20:51:45.768710Z',
#      'shell.execute_reply': '2026-06-14T20:51:45.776443Z',
#      'iopub.status.idle': '2026-06-14T20:51:45.777005Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nDATE = "JUN11"\nSTART_DATE = "2023-02-01 00:00"\nEND_DATE = "2023-03-10 23:00"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'execution_count': 2,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2026-06-14T20:51:45.781989',
#      'end_time': '2026-06-14T20:51:45.789370',
#      'duration': 0.007381,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2026-06-14T20:51:45.784459Z',
#      'iopub.execute_input': '2026-06-14T20:51:45.784772Z',
#      'iopub.status.idle': '2026-06-14T20:51:45.788318Z',
#      'shell.execute_reply': '2026-06-14T20:51:45.787947Z'}},
#    'outputs': [],
#    'source': 'from pathlib import Path\nimport subprocess\ndata_dir = Path(f"_json/_run/{DATE}/BC").resolve()\noutput_dir = Path(f"_json/_run/{DATE}/calibro").resolve()\noutput_dir.mkdir(parents=True, exist_ok=True)\ncode_dir = Path(f"_json/_run/{DATE}/_code")\ncode_dir.mkdir(parents=True, exist_ok=True)\nCALIBRO_NAME = "simplest"\nRSCRIPT_BIN = "Rscript"',
#    'id': 'b75b5d8f'},
#   {'cell_type': 'code',
#    'execution_count': 3,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2026-06-14T20:51:45.790536',
#      'end_time': '2026-06-14T20:52:08.720125',
#      'duration': 22.929589,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2026-06-14T20:51:45.792104Z',
#      'iopub.execute_input': '2026-06-14T20:51:45.792281Z',
#      'iopub.status.idle': '2026-06-14T20:52:08.719425Z',
#      'shell.execute_reply': '2026-06-14T20:52:08.719075Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': '[INFO] R script generated: _json/_run/JUN11/_code/run_calibro.R\n\n[INFO] Running Calibro Rscript...\n'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': 'Loading required package: R6\nLoading required package: coda\nLoading required package: parallel\nLoading required package: MASS\nLoading required package: modeest\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\n### NELDER-MEAD DOWNHILL SIMPLEX ALGORITHM ###\n\n Version: amoeba\n Start time: 2026-06-14 21:52:01.235202 \n Number of simulations: 5 \n\n\n*** Simulation 1 / 5 (elapsed time: 0.00117 mins) ***\n\n best y: 263.589762958277\n best z:\n\t %RHO@t_set_heating%@sePar01.pc.mu = 0.1073 \n\t %RHO@window_opening_ach%@sePar01.pc.mu = 0.2024 \n\t %ALPHA1@sePar01.pc.mu = 0.9999 \n\t %SIGMA1@wn1.pc.mu = 0.9999 \n\t %SIGMA1@wn2.pc.mu = 7.7e+07 \n\n*** Simulation 2 / 5 (elapsed time: 0.002 mins) ***\n\n best y: 271.798843716433\n best z:\n\t %RHO@t_set_heating%@sePar01.pc.mu = 0.3665 \n\t %RHO@window_opening_ach%@sePar01.pc.mu = 0.4736 \n\t %ALPHA1@sePar01.pc.mu = 0.9999 \n\t %SIGMA1@wn1.pc.mu = 0.9999 \n\t %SIGMA1@wn2.pc.mu = 86270000 \n\n*** Simulation 3 / 5 (elapsed time: 0.00224 mins) ***\n\n best y: 271.798843716433\n best z:\n\t %RHO@t_set_heating%@sePar01.pc.mu = 0.3665 \n\t %RHO@window_opening_ach%@sePar01.pc.mu = 0.4736 \n\t %ALPHA1@sePar01.pc.mu = 0.9999 \n\t %SIGMA1@wn1.pc.mu = 0.9999 \n\t %SIGMA1@wn2.pc.mu = 86270000 \n\n*** Simulation 4 / 5 (elapsed time: 0.00255 mins) ***\n\n best y: 271.890942112667\n best z:\n\t %RHO@t_set_heating%@sePar01.pc.mu = 0.3869 \n\t %RHO@window_opening_ach%@sePar01.pc.mu = 0.448 \n\t %ALPHA1@sePar01.pc.mu = 0.9999 \n\t %SIGMA1@wn1.pc.mu = 0.9999 \n\t %SIGMA1@wn2.pc.mu = 86840000 \n\n*** Simulation 5 / 5 (elapsed time: 0.0028 mins) ***\n\n best y: 271.890942112667\n best z:\n\t %RHO@t_set_heating%@sePar01.pc.mu = 0.3869 \n\t %RHO@window_opening_ach%@sePar01.pc.mu = 0.448 \n\t %ALPHA1@sePar01.pc.mu = 0.9999 \n\t %SIGMA1@wn1.pc.mu = 0.9999 \n\t %SIGMA1@wn2.pc.mu = 86840000 \n\n*** Simulation 6 / 5 (elapsed time: 0.00306 mins) ***\n\n best y: 271.890942112667\n best z:\n\t %RHO@t_set_heating%@sePar01.pc.mu = 0.3869 \n\t %RHO@window_opening_ach%@sePar01.pc.mu = 0.448 \n\t %ALPHA1@sePar01.pc.mu = 0.9999 \n\t %SIGMA1@wn1.pc.mu = 0.9999 \n\t %SIGMA1@wn2.pc.mu = 86840000 \n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\n### NELDER-MEAD DOWNHILL SIMPLEX ALGORITHM ###\n\n Version: amoeba\n Start time: 2026-06-14 21:52:01.467884 \n Number of simulations: 5 \n\n\n*** Simulation 1 / 5 (elapsed time: 0.000501 mins) ***\n\n best y: 243.803803354918\n best z:\n\t %RHO@t_set_heating%@sePar01.pc1 = 0.3833 \n\t %ALPHA1@sePar01.pc1 = 0.9999 \n\t %SIGMA1@wn1.pc1 = 0.9999 \n\t %SIGMA1@wn2.pc1 = 10610000 \n\n*** Simulation 2 / 5 (elapsed time: 0.000712 mins) ***\n\n best y: 243.803803354918\n best z:\n\t %RHO@t_set_heating%@sePar01.pc1 = 0.3833 \n\t %ALPHA1@sePar01.pc1 = 0.9999 \n\t %SIGMA1@wn1.pc1 = 0.9999 \n\t %SIGMA1@wn2.pc1 = 10610000 \n\n*** Simulation 3 / 5 (elapsed time: 0.000971 mins) ***\n\n best y: 266.530338486965\n best z:\n\t %RHO@t_set_heating%@sePar01.pc1 = 0.1133 \n\t %ALPHA1@sePar01.pc1 = 0.9999 \n\t %SIGMA1@wn1.pc1 = 0.9999 \n\t %SIGMA1@wn2.pc1 = 13680000 \n\n*** Simulation 4 / 5 (elapsed time: 0.00122 mins) ***\n\n best y: 266.530338486965\n best z:\n\t %RHO@t_set_heating%@sePar01.pc1 = 0.1133 \n\t %ALPHA1@sePar01.pc1 = 0.9999 \n\t %SIGMA1@wn1.pc1 = 0.9999 \n\t %SIGMA1@wn2.pc1 = 13680000 \n\n*** Simulation 5 / 5 (elapsed time: 0.00145 mins) ***\n\n best y: 266.530338486965\n best z:\n\t %RHO@t_set_heating%@sePar01.pc1 = 0.1133 \n\t %ALPHA1@sePar01.pc1 = 0.9999 \n\t %SIGMA1@wn1.pc1 = 0.9999 \n\t %SIGMA1@wn2.pc1 = 13680000 \n\n*** Simulation 6 / 5 (elapsed time: 0.00167 mins) ***\n\n best y: 266.530338486965\n best z:\n\t %RHO@t_set_heating%@sePar01.pc1 = 0.1133 \n\t %ALPHA1@sePar01.pc1 = 0.9999 \n\t %SIGMA1@wn1.pc1 = 0.9999 \n\t %SIGMA1@wn2.pc1 = 13680000 \n\n### NELDER-MEAD DOWNHILL SIMPLEX ALGORITHM ###\n\n Version: amoeba\n Start time: 2026-06-14 21:52:01.606979 \n Number of simulations: 5 \n\n\n*** Simulation 1 / 5 (elapsed time: 0.000371 mins) ***\n\n best y: 88.9468423935513\n best z:\n\t %RHO@t_set_heating%@sePar01.pc2 = 1 \n\t %ALPHA1@sePar01.pc2 = 1 \n\t %SIGMA1@wn1.pc2 = 0.9879 \n\t %SIGMA1@wn2.pc2 = 745700 \n\n*** Simulation 2 / 5 (elapsed time: 0.000624 mins) ***\n\n best y: 88.9468423935513\n best z:\n\t %RHO@t_set_heating%@sePar01.pc2 = 1 \n\t %ALPHA1@sePar01.pc2 = 1 \n\t %SIGMA1@wn1.pc2 = 0.9879 \n\t %SIGMA1@wn2.pc2 = 745700 \n\n*** Simulation 3 / 5 (elapsed time: 0.00091 mins) ***\n\n best y: 161.044133927572\n best z:\n\t %RHO@t_set_heating%@sePar01.pc2 = 0.108 \n\t %ALPHA1@sePar01.pc2 = 0.9984 \n\t %SIGMA1@wn1.pc2 = 0.9996 \n\t %SIGMA1@wn2.pc2 = 749100 \n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\n*** Simulation 4 / 5 (elapsed time: 0.00125 mins) ***\n\n best y: 161.044133927572\n best z:\n\t %RHO@t_set_heating%@sePar01.pc2 = 0.108 \n\t %ALPHA1@sePar01.pc2 = 0.9984 \n\t %SIGMA1@wn1.pc2 = 0.9996 \n\t %SIGMA1@wn2.pc2 = 749100 \n\n*** Simulation 5 / 5 (elapsed time: 0.00157 mins) ***\n\n best y: 161.044133927572\n best z:\n\t %RHO@t_set_heating%@sePar01.pc2 = 0.108 \n\t %ALPHA1@sePar01.pc2 = 0.9984 \n\t %SIGMA1@wn1.pc2 = 0.9996 \n\t %SIGMA1@wn2.pc2 = 749100 \n\n*** Simulation 6 / 5 (elapsed time: 0.00189 mins) ***\n\n best y: 161.044712802711\n best z:\n\t %RHO@t_set_heating%@sePar01.pc2 = 0.1109 \n\t %ALPHA1@sePar01.pc2 = 0.9984 \n\t %SIGMA1@wn1.pc2 = 0.9996 \n\t %SIGMA1@wn2.pc2 = 746800 \n\n### NELDER-MEAD DOWNHILL SIMPLEX ALGORITHM ###\n\n Version: amoeba\n Start time: 2026-06-14 21:52:01.759937 \n Number of simulations: 5 \n\n\n*** Simulation 1 / 5 (elapsed time: 0.000617 mins) ***\n\n best y: 103.824631884418\n best z:\n\t %RHO@window_opening_ach%@sePar01.pc3 = 0.1429 \n\t %ALPHA1@sePar01.pc3 = 0.9983 \n\t %SIGMA1@wn1.pc3 = 0.9925 \n\t %SIGMA1@wn2.pc3 = 2757 \n\n*** Simulation 2 / 5 (elapsed time: 0.000888 mins) ***\n\n best y: 103.824631884418\n best z:\n\t %RHO@window_opening_ach%@sePar01.pc3 = 0.1429 \n\t %ALPHA1@sePar01.pc3 = 0.9983 \n\t %SIGMA1@wn1.pc3 = 0.9925 \n\t %SIGMA1@wn2.pc3 = 2757 \n\n*** Simulation 3 / 5 (elapsed time: 0.00116 mins) ***\n\n best y: 103.82746617689\n best z:\n\t %RHO@window_opening_ach%@sePar01.pc3 = 0.1559 \n\t %ALPHA1@sePar01.pc3 = 0.9984 \n\t %SIGMA1@wn1.pc3 = 0.9925 \n\t %SIGMA1@wn2.pc3 = 2763 \n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\n### ADAPTIVE METROPOLIS WITHIN GIBBS ALGORITHM ###\n\n Start time: 2026-06-14 21:52:02.557457 \n Number of chains: 1 \n Number of simulations: <until converged> \n\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '*** Simulation 5 / <until converged> (elapsed time: 0.0101 mins) ***\n\nIterations = 50:1846\nThinning interval = 4 \nNumber of chains = 1 \nSample size per chain = 450 \n\n1. Empirical mean and standard deviation for each variable,\n   plus standard error of the mean:\n\n                        Mean        SD  Naive SE Time-series SE        t    eff\nt_set_heating      9.551e-01 5.266e-02 2.483e-03      4.313e-03 0.004515 0.3314\nwindow_opening_ach 4.138e-01 2.396e-01 1.129e-02      1.601e-02 0.038681 0.4980\n%SIGMA@wn2*.pc.mu% 1.160e+05 1.802e+04 8.496e+02      1.657e+03 0.014283 0.2627\n%SIGMA@wn2*.pc1%   1.144e+04 1.962e+03 9.248e+01      1.174e+02 0.010255 0.6210\n%SIGMA@wn2*.pc2%   8.616e+02 1.472e+02 6.939e+00      1.239e+01 0.014376 0.3138\n%SIGMA@wn2*.pc3%   3.645e+00 4.944e-01 2.331e-02      3.030e-02 0.008312 0.5918\n                       s\nt_set_heating      149.1\nwindow_opening_ach 224.1\n%SIGMA@wn2*.pc.mu% 118.2\n%SIGMA@wn2*.pc1%   279.4\n%SIGMA@wn2*.pc2%   141.2\n%SIGMA@wn2*.pc3%   266.3\n\n2. Quantiles for each variable:\n\n                        2.5%       25%       50%       75%     97.5%\nt_set_heating      8.048e-01 9.403e-01 9.740e-01 9.925e-01 9.995e-01\nwindow_opening_ach 2.291e-02 2.221e-01 4.023e-01 5.692e-01 9.312e-01\n%SIGMA@wn2*.pc.mu% 8.163e+04 1.028e+05 1.161e+05 1.278e+05 1.499e+05\n%SIGMA@wn2*.pc1%   8.085e+03 9.997e+03 1.142e+04 1.264e+04 1.561e+04\n%SIGMA@wn2*.pc2%   6.182e+02 7.472e+02 8.482e+02 9.650e+02 1.164e+03\n%SIGMA@wn2*.pc3%   2.715e+00 3.287e+00 3.617e+00 3.979e+00 4.560e+00\n\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '*** Simulation 10 / <until converged> (elapsed time: 0.0147 mins) ***\n\nIterations = 100:3696\nThinning interval = 4 \nNumber of chains = 1 \nSample size per chain = 900 \n\n1. Empirical mean and standard deviation for each variable,\n   plus standard error of the mean:\n\n                        Mean        SD  Naive SE Time-series SE        t    eff\nt_set_heating      9.486e-01 6.360e-02 2.120e-03      4.214e-03 0.004442 0.2531\nwindow_opening_ach 4.218e-01 2.396e-01 7.988e-03      1.006e-02 0.023857 0.6300\n%SIGMA@wn2*.pc.mu% 1.164e+05 1.755e+04 5.849e+02      7.570e+02 0.006502 0.5970\n%SIGMA@wn2*.pc1%   1.146e+04 2.026e+03 6.752e+01      8.021e+01 0.006997 0.7086\n%SIGMA@wn2*.pc2%   8.403e+02 1.387e+02 4.622e+00      6.908e+00 0.008220 0.4477\n%SIGMA@wn2*.pc3%   3.630e+00 5.052e-01 1.684e-02      2.154e-02 0.005935 0.6112\n                       s\nt_set_heating      227.8\nwindow_opening_ach 567.0\n%SIGMA@wn2*.pc.mu% 537.3\n%SIGMA@wn2*.pc1%   637.7\n%SIGMA@wn2*.pc2%   402.9\n%SIGMA@wn2*.pc3%   550.1\n\n2. Quantiles for each variable:\n\n                        2.5%       25%       50%       75%     97.5%\nt_set_heating      7.668e-01 9.341e-01 9.735e-01 9.889e-01 9.993e-01\nwindow_opening_ach 2.497e-02 2.295e-01 4.264e-01 5.799e-01 9.305e-01\n%SIGMA@wn2*.pc.mu% 8.290e+04 1.047e+05 1.160e+05 1.277e+05 1.518e+05\n%SIGMA@wn2*.pc1%   7.880e+03 1.005e+04 1.138e+04 1.285e+04 1.561e+04\n%SIGMA@wn2*.pc2%   6.081e+02 7.447e+02 8.273e+02 9.246e+02 1.140e+03\n%SIGMA@wn2*.pc3%   2.702e+00 3.278e+00 3.579e+00 3.979e+00 4.635e+00\n\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '*** Simulation 15 / <until converged> (elapsed time: 0.0193 mins) ***\n\nIterations = 150:5546\nThinning interval = 4 \nNumber of chains = 1 \nSample size per chain = 1350 \n\n1. Empirical mean and standard deviation for each variable,\n   plus standard error of the mean:\n\n                        Mean        SD  Naive SE Time-series SE        t    eff\nt_set_heating      9.480e-01 6.155e-02 1.675e-03      3.396e-03 0.003582 0.2433\nwindow_opening_ach 4.206e-01 2.402e-01 6.537e-03      8.268e-03 0.019659 0.6251\n%SIGMA@wn2*.pc.mu% 1.162e+05 1.738e+04 4.731e+02      5.560e+02 0.004783 0.7240\n%SIGMA@wn2*.pc1%   1.148e+04 2.007e+03 5.463e+01      6.646e+01 0.005787 0.6756\n%SIGMA@wn2*.pc2%   8.414e+02 1.351e+02 3.677e+00      4.967e+00 0.005903 0.5480\n%SIGMA@wn2*.pc3%   3.638e+00 5.003e-01 1.362e-02      1.579e-02 0.004342 0.7433\n                        s\nt_set_heating       328.5\nwindow_opening_ach  843.8\n%SIGMA@wn2*.pc.mu%  977.5\n%SIGMA@wn2*.pc1%    912.1\n%SIGMA@wn2*.pc2%    739.8\n%SIGMA@wn2*.pc3%   1003.5\n\n2. Quantiles for each variable:\n\n                        2.5%       25%       50%       75%     97.5%\nt_set_heating      7.786e-01 9.317e-01 9.716e-01 9.889e-01 9.987e-01\nwindow_opening_ach 2.448e-02 2.228e-01 4.193e-01 5.823e-01 9.289e-01\n%SIGMA@wn2*.pc.mu% 8.464e+04 1.046e+05 1.148e+05 1.276e+05 1.526e+05\n%SIGMA@wn2*.pc1%   7.846e+03 1.009e+04 1.141e+04 1.278e+04 1.567e+04\n%SIGMA@wn2*.pc2%   6.074e+02 7.486e+02 8.299e+02 9.228e+02 1.137e+03\n%SIGMA@wn2*.pc3%   2.707e+00 3.285e+00 3.604e+00 3.980e+00 4.654e+00\n\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '*** Simulation 20 / <until converged> (elapsed time: 0.0238 mins) ***\n\nIterations = 200:7396\nThinning interval = 4 \nNumber of chains = 1 \nSample size per chain = 1800 \n\n1. Empirical mean and standard deviation for each variable,\n   plus standard error of the mean:\n\n                        Mean        SD  Naive SE Time-series SE        t    eff\nt_set_heating      9.478e-01 6.289e-02 1.482e-03      3.043e-03 0.003211 0.2373\nwindow_opening_ach 4.173e-01 2.435e-01 5.738e-03      7.268e-03 0.017415 0.6234\n%SIGMA@wn2*.pc.mu% 1.163e+05 1.710e+04 4.030e+02      4.661e+02 0.004006 0.7477\n%SIGMA@wn2*.pc1%   1.148e+04 2.047e+03 4.825e+01      5.971e+01 0.005199 0.6529\n%SIGMA@wn2*.pc2%   8.441e+02 1.331e+02 3.138e+00      4.098e+00 0.004855 0.5865\n%SIGMA@wn2*.pc3%   3.634e+00 5.022e-01 1.184e-02      1.362e-02 0.003749 0.7550\n                        s\nt_set_heating       427.1\nwindow_opening_ach 1122.1\n%SIGMA@wn2*.pc.mu% 1345.9\n%SIGMA@wn2*.pc1%   1175.2\n%SIGMA@wn2*.pc2%   1055.7\n%SIGMA@wn2*.pc3%   1359.0\n\n2. Quantiles for each variable:\n\n                        2.5%       25%       50%       75%     97.5%\nt_set_heating      7.715e-01 9.313e-01 9.727e-01 9.891e-01 9.990e-01\nwindow_opening_ach 2.325e-02 2.176e-01 4.083e-01 5.831e-01 9.277e-01\n%SIGMA@wn2*.pc.mu% 8.498e+04 1.047e+05 1.149e+05 1.275e+05 1.519e+05\n%SIGMA@wn2*.pc1%   7.837e+03 1.005e+04 1.137e+04 1.282e+04 1.577e+04\n%SIGMA@wn2*.pc2%   6.105e+02 7.537e+02 8.339e+02 9.268e+02 1.133e+03\n%SIGMA@wn2*.pc3%   2.704e+00 3.289e+00 3.600e+00 3.961e+00 4.717e+00\n\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '*** Simulation 25 / <until converged> (elapsed time: 0.0284 mins) ***\n\nIterations = 250:9246\nThinning interval = 4 \nNumber of chains = 1 \nSample size per chain = 2250 \n\n1. Empirical mean and standard deviation for each variable,\n   plus standard error of the mean:\n\n                        Mean        SD  Naive SE Time-series SE        t    eff\nt_set_heating      9.478e-01 6.448e-02 1.359e-03      2.989e-03 0.003154 0.2069\nwindow_opening_ach 4.177e-01 2.405e-01 5.071e-03      6.358e-03 0.015220 0.6362\n%SIGMA@wn2*.pc.mu% 1.166e+05 1.719e+04 3.624e+02      4.259e+02 0.003653 0.7239\n%SIGMA@wn2*.pc1%   1.149e+04 2.062e+03 4.347e+01      5.347e+01 0.004652 0.6609\n%SIGMA@wn2*.pc2%   8.459e+02 1.330e+02 2.804e+00      3.715e+00 0.004392 0.5694\n%SIGMA@wn2*.pc3%   3.655e+00 5.213e-01 1.099e-02      1.292e-02 0.003536 0.7230\n                        s\nt_set_heating       465.4\nwindow_opening_ach 1431.4\n%SIGMA@wn2*.pc.mu% 1628.9\n%SIGMA@wn2*.pc1%   1487.0\n%SIGMA@wn2*.pc2%   1281.1\n%SIGMA@wn2*.pc3%   1626.8\n\n2. Quantiles for each variable:\n\n                        2.5%       25%       50%       75%     97.5%\nt_set_heating      7.697e-01 9.311e-01 9.729e-01 9.899e-01 9.990e-01\nwindow_opening_ach 2.331e-02 2.201e-01 4.182e-01 5.823e-01 9.093e-01\n%SIGMA@wn2*.pc.mu% 8.546e+04 1.048e+05 1.153e+05 1.276e+05 1.524e+05\n%SIGMA@wn2*.pc1%   7.887e+03 1.005e+04 1.138e+04 1.284e+04 1.604e+04\n%SIGMA@wn2*.pc2%   6.077e+02 7.563e+02 8.382e+02 9.288e+02 1.132e+03\n%SIGMA@wn2*.pc3%   2.710e+00 3.294e+00 3.609e+00 3.991e+00 4.752e+00\n\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
# ...
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '*** Simulation 45 / <until converged> (elapsed time: 0.0479 mins) ***\n\nIterations = 450:16646\nThinning interval = 4 \nNumber of chains = 1 \nSample size per chain = 4050 \n\n1. Empirical mean and standard deviation for each variable,\n   plus standard error of the mean:\n\n                        Mean        SD  Naive SE Time-series SE        t    eff\nt_set_heating      9.467e-01 6.530e-02 1.026e-03      2.333e-03 0.002464 0.1935\nwindow_opening_ach 4.191e-01 2.401e-01 3.773e-03      4.661e-03 0.011123 0.6550\n%SIGMA@wn2*.pc.mu% 1.164e+05 1.713e+04 2.692e+02      3.146e+02 0.002704 0.7321\n%SIGMA@wn2*.pc1%   1.152e+04 2.056e+03 3.231e+01      4.078e+01 0.003541 0.6278\n%SIGMA@wn2*.pc2%   8.450e+02 1.326e+02 2.083e+00      2.945e+00 0.003485 0.5004\n%SIGMA@wn2*.pc3%   3.668e+00 5.318e-01 8.357e-03      1.002e-02 0.002731 0.6960\n                        s\nt_set_heating       783.5\nwindow_opening_ach 2652.8\n%SIGMA@wn2*.pc.mu% 2965.2\n%SIGMA@wn2*.pc1%   2542.6\n%SIGMA@wn2*.pc2%   2026.7\n%SIGMA@wn2*.pc3%   2818.7\n\n2. Quantiles for each variable:\n\n                        2.5%       25%       50%       75%     97.5%\nt_set_heating      7.610e-01 9.285e-01 9.722e-01 9.901e-01 9.991e-01\nwindow_opening_ach 2.525e-02 2.215e-01 4.176e-01 5.837e-01 9.139e-01\n%SIGMA@wn2*.pc.mu% 8.539e+04 1.043e+05 1.153e+05 1.276e+05 1.524e+05\n%SIGMA@wn2*.pc1%   7.992e+03 1.008e+04 1.135e+04 1.288e+04 1.604e+04\n%SIGMA@wn2*.pc2%   5.938e+02 7.559e+02 8.382e+02 9.301e+02 1.118e+03\n%SIGMA@wn2*.pc3%   2.717e+00 3.300e+00 3.623e+00 4.013e+00 4.811e+00\n\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '*** Simulation 50 / <until converged> (elapsed time: 0.0525 mins) ***\n\nIterations = 500:18496\nThinning interval = 4 \nNumber of chains = 1 \nSample size per chain = 4500 \n\n1. Empirical mean and standard deviation for each variable,\n   plus standard error of the mean:\n\n                        Mean        SD  Naive SE Time-series SE        t    eff\nt_set_heating      9.469e-01 6.487e-02 9.670e-04      2.180e-03 0.002303 0.1967\nwindow_opening_ach 4.187e-01 2.406e-01 3.587e-03      4.409e-03 0.010531 0.6619\n%SIGMA@wn2*.pc.mu% 1.163e+05 1.711e+04 2.550e+02      2.984e+02 0.002566 0.7305\n%SIGMA@wn2*.pc1%   1.151e+04 2.046e+03 3.051e+01      3.804e+01 0.003304 0.6430\n%SIGMA@wn2*.pc2%   8.459e+02 1.321e+02 1.969e+00      2.732e+00 0.003230 0.5197\n%SIGMA@wn2*.pc3%   3.666e+00 5.311e-01 7.917e-03      9.578e-03 0.002613 0.6832\n                        s\nt_set_heating       885.2\nwindow_opening_ach 2978.7\n%SIGMA@wn2*.pc.mu% 3287.1\n%SIGMA@wn2*.pc1%   2893.7\n%SIGMA@wn2*.pc2%   2338.5\n%SIGMA@wn2*.pc3%   3074.3\n\n2. Quantiles for each variable:\n\n                        2.5%       25%       50%       75%     97.5%\nt_set_heating      7.611e-01 9.292e-01 9.722e-01 9.902e-01 9.991e-01\nwindow_opening_ach 2.661e-02 2.215e-01 4.147e-01 5.848e-01 9.177e-01\n%SIGMA@wn2*.pc.mu% 8.517e+04 1.042e+05 1.153e+05 1.276e+05 1.518e+05\n%SIGMA@wn2*.pc1%   7.949e+03 1.009e+04 1.137e+04 1.286e+04 1.602e+04\n%SIGMA@wn2*.pc2%   5.952e+02 7.569e+02 8.391e+02 9.308e+02 1.119e+03\n%SIGMA@wn2*.pc3%   2.718e+00 3.299e+00 3.622e+00 4.010e+00 4.804e+00\n\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '*** Simulation 55 / <until converged> (elapsed time: 0.0571 mins) ***\n\nIterations = 550:20346\nThinning interval = 4 \nNumber of chains = 1 \nSample size per chain = 4950 \n\n1. Empirical mean and standard deviation for each variable,\n   plus standard error of the mean:\n\n                        Mean        SD  Naive SE Time-series SE        t    eff\nt_set_heating      9.462e-01 6.556e-02 9.319e-04      2.187e-03 0.002311 0.1816\nwindow_opening_ach 4.202e-01 2.409e-01 3.424e-03      4.223e-03 0.010051 0.6575\n%SIGMA@wn2*.pc.mu% 1.161e+05 1.708e+04 2.428e+02      2.867e+02 0.002469 0.7171\n%SIGMA@wn2*.pc1%   1.152e+04 2.053e+03 2.918e+01      3.779e+01 0.003280 0.5963\n%SIGMA@wn2*.pc2%   8.454e+02 1.327e+02 1.886e+00      2.627e+00 0.003108 0.5153\n%SIGMA@wn2*.pc3%   3.666e+00 5.298e-01 7.530e-03      8.988e-03 0.002452 0.7020\n                        s\nt_set_heating       898.9\nwindow_opening_ach 3254.8\n%SIGMA@wn2*.pc.mu% 3549.7\n%SIGMA@wn2*.pc1%   2951.8\n%SIGMA@wn2*.pc2%   2550.5\n%SIGMA@wn2*.pc3%   3474.8\n\n2. Quantiles for each variable:\n\n                        2.5%       25%       50%       75%     97.5%\nt_set_heating      7.576e-01 9.285e-01 9.719e-01 9.898e-01 9.991e-01\nwindow_opening_ach 2.681e-02 2.246e-01 4.153e-01 5.848e-01 9.256e-01\n%SIGMA@wn2*.pc.mu% 8.496e+04 1.039e+05 1.152e+05 1.275e+05 1.521e+05\n%SIGMA@wn2*.pc1%   7.950e+03 1.010e+04 1.138e+04 1.286e+04 1.601e+04\n%SIGMA@wn2*.pc2%   5.936e+02 7.563e+02 8.392e+02 9.306e+02 1.119e+03\n%SIGMA@wn2*.pc3%   2.724e+00 3.298e+00 3.624e+00 4.006e+00 4.813e+00\n\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '*** Simulation 60 / <until converged> (elapsed time: 0.0618 mins) ***\n\nIterations = 600:22196\nThinning interval = 4 \nNumber of chains = 1 \nSample size per chain = 5400 \n\n1. Empirical mean and standard deviation for each variable,\n   plus standard error of the mean:\n\n                        Mean        SD  Naive SE Time-series SE        t    eff\nt_set_heating      9.464e-01 6.540e-02 8.899e-04      2.067e-03 0.002184 0.1855\nwindow_opening_ach 4.223e-01 2.414e-01 3.284e-03      4.052e-03 0.009596 0.6569\n%SIGMA@wn2*.pc.mu% 1.162e+05 1.712e+04 2.329e+02      2.744e+02 0.002361 0.7206\n%SIGMA@wn2*.pc1%   1.153e+04 2.040e+03 2.775e+01      3.582e+01 0.003108 0.6003\n%SIGMA@wn2*.pc2%   8.474e+02 1.324e+02 1.801e+00      2.529e+00 0.002985 0.5071\n%SIGMA@wn2*.pc3%   3.663e+00 5.280e-01 7.185e-03      8.486e-03 0.002317 0.7170\n                      s\nt_set_heating      1001\nwindow_opening_ach 3547\n%SIGMA@wn2*.pc.mu% 3891\n%SIGMA@wn2*.pc1%   3241\n%SIGMA@wn2*.pc2%   2738\n%SIGMA@wn2*.pc3%   3872\n\n2. Quantiles for each variable:\n\n                        2.5%       25%       50%       75%     97.5%\nt_set_heating      7.580e-01 9.292e-01 9.721e-01 9.899e-01 9.991e-01\nwindow_opening_ach 2.695e-02 2.249e-01 4.197e-01 5.905e-01 9.252e-01\n%SIGMA@wn2*.pc.mu% 8.498e+04 1.038e+05 1.153e+05 1.276e+05 1.521e+05\n%SIGMA@wn2*.pc1%   7.969e+03 1.012e+04 1.138e+04 1.286e+04 1.597e+04\n%SIGMA@wn2*.pc2%   5.971e+02 7.572e+02 8.414e+02 9.326e+02 1.119e+03\n%SIGMA@wn2*.pc3%   2.716e+00 3.293e+00 3.624e+00 4.003e+00 4.800e+00\n\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '$CALIBRATION_RESULTS\n           PARAMETER   ESTIMATE       LOWER      UPPER\n1      t_set_heating 23.0741992 22.26459105 23.0891283\n2 window_opening_ach  0.1187563  0.02811256  0.1940576\n\n$CALIBRATED_MODEL_GOF\n             sim       cals\ndata1 0.08148599 0.08324607\n\n'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': "Warning messages:\n1: encountered a tie, and the difference between minimal and \n                   maximal value is > length('x') * 'tie.limit'\nthe distribution could be multimodal \n2: encountered a tie, and the difference between minimal and \n                   maximal value is > length('x') * 'tie.limit'\nthe distribution could be multimodal \n3: encountered a tie, and the difference between minimal and \n                   maximal value is > length('x') * 'tie.limit'\nthe distribution could be multimodal \n4: encountered a tie, and the difference between minimal and \n                   maximal value is > length('x') * 'tie.limit'\nthe distribution could be multimodal \n5: encountered a tie, and the difference between minimal and \n                   maximal value is > length('x') * 'tie.limit'\nthe distribution could be multimodal \n6: encountered a tie, and the difference between minimal and \n                   maximal value is > length('x') * 'tie.limit'\nthe distribution could be multimodal \n7: encountered a tie, and the difference between minimal and \n                   maximal value is > length('x') * 'tie.limit'\nthe distribution could be multimodal \n8: encountered a tie, and the difference between minimal and \n                   maximal value is > length('x') * 'tie.limit'\nthe distribution could be multimodal \nWarning messages:\n1: encountered a tie, and the difference between minimal and \n                   maximal value is > length('x') * 'tie.limit'\nthe distribution could be multimodal \n2: encountered a tie, and the difference between minimal and \n                   maximal value is > length('x') * 'tie.limit'\nthe distribution could be multimodal \n3: encountered a tie, and the difference between minimal and \n                   maximal value is > length('x') * 'tie.limit'\nthe distribution could be multimodal \n4: encountered a tie, and the difference between minimal and \n                   maximal value is > length('x') * 'tie.limit'\nthe distribution could be multimodal \n5: encountered a tie, and the difference between minimal and \n                   maximal value is > length('x') * 'tie.limit'\nthe distribution could be multimodal \n6: encountered a tie, and the difference between minimal and \n                   maximal value is > length('x') * 'tie.limit'\nthe distribution could be multimodal \n7: encountered a tie, and the difference between minimal and \n                   maximal value is > length('x') * 'tie.limit'\nthe distribution could be multimodal \n8: encountered a tie, and the difference between minimal and \n                   maximal value is > length('x') * 'tie.limit'\nthe distribution could be multimodal \n"},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\n\nprocessing file: /opt/homebrew/lib/R/4.3/site-library/calibro/calibro_report.Rnw\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '1/44             \n2/44 [setup]     \n3/44             \n4/44 [exeSumm]   \n5/44             \n6/44 [content]   \n7/44             \n8/44 [genVar]    \n9/44             \n10/44 [dsVar]     \n11/44 [dsText]    \n12/44             \n13/44 [ds1]       \n14/44 [ds2]       \n15/44 [ds3]       \n16/44 [ds4]       \n17/44 [ds5]       \n18/44 [ds6]       \n19/44 [ds7]       \n20/44 [ds8]       \n21/44 [ds9]       \n22/44 [ds10]      \n23/44             \n24/44 [saVar]     \n25/44 [saText]    \n26/44             \n27/44 [ret_tables]\n28/44             \n29/44 [train]     \n30/44             \n31/44 [calVar]    \n32/44 [cal]       \n33/44 [thetaplot] \n34/44 [ds1fit]    \n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '35/44 [ds2fit]    \n36/44 [ds3fit]    \n37/44 [ds4fit]    \n38/44 [ds5fit]    \n39/44 [ds6fit]    \n40/44 [ds7fit]    \n41/44 [ds8fit]    \n42/44 [ds9fit]    \n43/44 [ds10fit]   \n44/44             \n'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': 'output file: calibro_report.tex\n\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '[1] "calibro_report.pdf"\n✓ Calibro finished successfully.\n\n🎉 Experiment complete. Results saved to: /Users/rui.bo/Desktop/BASE/1_phd/Y3/RC_br/_json/_run/JUN11/calibro\n'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': "Warning: LaTeX Warning: `!h' float specifier changed to `!ht'.\nWarning: LaTeX Warning: `!h' float specifier changed to `!ht'.\nWarning messages:\n1: encountered a tie, and the difference between minimal and \n                   maximal value is > length('x') * 'tie.limit'\nthe distribution could be multimodal \n2: encountered a tie, and the difference between minimal and \n                   maximal value is > length('x') * 'tie.limit'\nthe distribution could be multimodal \n3: encountered a tie, and the difference between minimal and \n                   maximal value is > length('x') * 'tie.limit'\nthe distribution could be multimodal \n4: encountered a tie, and the difference between minimal and \n                   maximal value is > length('x') * 'tie.limit'\nthe distribution could be multimodal \n5: encountered a tie, and the difference between minimal and \n                   maximal value is > length('x') * 'tie.limit'\nthe distribution could be multimodal \n6: encountered a tie, and the difference between minimal and \n                   maximal value is > length('x') * 'tie.limit'\nthe distribution could be multimodal \n7: encountered a tie, and the difference between minimal and \n                   maximal value is > length('x') * 'tie.limit'\nthe distribution could be multimodal \n8: encountered a tie, and the difference between minimal and \n                   maximal value is > length('x') * 'tie.limit'\nthe distribution could be multimodal \n"}],
#    'source': 'r_code = f"""\nsetwd("{output_dir}")\n\nlibrary(calibro)\n\nCE <- calEnv$new(name = \'{CALIBRO_NAME}\')\n\nCE$add.ds(\n    name = \'data1\',\n    Y.star = \'{data_dir}/obs.csv\',\n    TT     = \'{data_dir}/TT.csv\',\n    Y      = \'{data_dir}/Y.csv\'\n)\n\nCE$rd = \'pca\'\nCE$sa = \'sobolSmthSpl\'\nCE$ret = list(mthd = \'ng.screening\')\nCE$mdls = \'gpr.ng.sePar01_whitePar01\'\nCE$train = list(type = \'training\', alg = \'amoeba\')\nCE$cals = \'cal.gpr.ng\'\nCE$cal.mcmc = list(alg = \'amg\')\n\nCE$cal.res()\n\nM <- CE$cal.mcmc\nZ <- M$Z\n# z_map <- as.data.frame(t(M$bestz))\n\nif (inherits(Z, "mcmc.list")) {{\nZ <- do.call(rbind, lapply(Z, as.matrix))\n}} else {{\nZ <- as.matrix(Z)\n}}\n\n\nwrite.csv(Z, "posterior_draws_Z.csv", row.names = FALSE)\n# write.csv(z_map, "z_map.csv", row.names = FALSE)\ntheta <- CE$cal.res(mode = "theta")\nwrite.csv(theta, "theta_physical_summary.csv", row.names = FALSE)\n\nCE$genReport(\ntype = "pdf",\nout = c("dss", "cal")\n)\n"""\nr_script_path = code_dir / "run_calibro.R"\n\nr_code = r_code\n\nwith open(r_script_path, "w") as f:\n    f.write(r_code)\n\nprint("[INFO] R script generated:", r_script_path)\n\n\n# ================================================================\n# 6. Run Rscript\n# ================================================================\nprint("\\n[INFO] Running Calibro Rscript...")\ncmd = [RSCRIPT_BIN, str(r_script_path)]\nresult = subprocess.run(cmd)\nif result.returncode == 0:\n    print("✓ Calibro finished successfully.")\nelse:\n    print("❌ Calibro failed.")\n\n\nprint(f"\\n🎉 Experiment complete. Results saved to: {output_dir}")',
#    'id': '5e045933'},
#   {'cell_type': 'code',
#    'execution_count': None,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2026-06-14T20:52:08.721809',
#      'end_time': '2026-06-14T20:52:08.723193',
#      'duration': 0.001384,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': '',
#    'id': '157e6667'}],
#  'metadata': {'kernelspec': {'display_name': 'eplus_env',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.10.4',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'orig_nbformat_minor': 2,
#   'papermill': {'default_parameters': {},
#    'parameters': {'DATE': 'JUN11',
#     'START_DATE': '2023-02-01 00:00',
#     'END_DATE': '2023-03-10 23:00'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '1_CALIBRO.ipynb',
#    'output_path': 'JUN11.ipynb',
#    'start_time': '2026-06-14T20:51:45.042132',
#    'end_time': '2026-06-14T20:52:08.840618',
#    'duration': 23.798486,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %%
import papermill as pm

NOTEBOOK_IN = "1_PLOT_map.ipynb"

pm.execute_notebook(
    NOTEBOOK_IN,
    f"{DATE}.ipynb",
    parameters={
        "DATE": DATE,
        "START_DATE": start,
        "END_DATE": end,
    },
)
# Out:
# Passed unknown parameter: DATE
# Passed unknown parameter: START_DATE
# Passed unknown parameter: END_DATE
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/1 [00:00<?, ?cell/s]
# {'cells': [{'id': 'a3a1d0e2',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2026-06-14T20:52:09.584677',
#      'end_time': '2026-06-14T20:52:09.601816',
#      'duration': 0.017139,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2026-06-14T20:52:09.589667Z',
#      'iopub.execute_input': '2026-06-14T20:52:09.590220Z',
#      'iopub.status.idle': '2026-06-14T20:52:09.599923Z',
#      'shell.execute_reply': '2026-06-14T20:52:09.599054Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nDATE = "JUN11"\nSTART_DATE = "2023-02-01 00:00"\nEND_DATE = "2023-03-10 23:00"\n',
#    'outputs': []}],
#  'metadata': {'kernelspec': {'display_name': 'eplus_env',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.10.4',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'orig_nbformat_minor': 2,
#   'papermill': {'default_parameters': {},
#    'parameters': {'DATE': 'JUN11',
#     'START_DATE': '2023-02-01 00:00',
#     'END_DATE': '2023-03-10 23:00'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '1_PLOT_map.ipynb',
#    'output_path': 'JUN11.ipynb',
#    'start_time': '2026-06-14T20:52:08.885063',
#    'end_time': '2026-06-14T20:52:09.723484',
#    'duration': 0.838421,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %% [markdown]
# # APPENDIX: Code STYLE

# %% [markdown]
# Use a configuration-driven functional pandas style.
#
# Package preference:
# - Use pathlib.Path for paths.
# - Use pandas for tabular data, time-indexed data, resampling, alignment, and CSV output.
# - Use numpy only for numerical formulas.
# - Avoid classes unless state must be preserved across many methods.
# - Avoid creating many intermediate global objects when a function can apply the transformation internally.
#
# Function style:
# - Keep functions small and task-specific.
# - Pass domain choices as arguments: KPI, frequency, period, output directory.
# - Let functions accept base-resolution data, then slice, resample, align, and save internally.
# - Avoid hard-coded daily/hourly/heating names inside the function body.
# - Avoid default arguments that depend on changing global variables where possible.
#
# DataFrame construction style:
# - For fixed summary rows, collect tuples and create one DataFrame with explicit columns.
# - For simulation matrices, create a dictionary of aligned Series and pass it once to pd.DataFrame.
# - Do not append rows directly to a DataFrame inside a loop.
# - Always align simulated and observed data explicitly before metrics or export.
#
# Calling style:
# - Define configuration variables once at the call site.
# - Use keyword arguments for main workflow functions.
# - Do not pre-create daily-specific objects unless they are reused elsewhere.

# %% [markdown]
# # Posterior SIM

# %%
posterior_TT = f'_json/_run/{DATE}/calibro/posterior_rand10_from_topfrac.csv'
# If posterior_TT is a string (file path)
posterior_TT = pd.read_csv(posterior_TT)

# %%
def run_posterior_ecm_samples(
    posterior_TT,
    extra_params=None,
    controller_mode="original",
):
    results = {}
    euis = {}

    if extra_params is None:
        extra_params = {}

    for sample_id, row in show_progress(
        posterior_TT.iterrows(),
        total=len(posterior_TT),
        desc="Running posterior samples",
        unit="sample",
    ):
        sampled_params = row.to_dict()
        sampled_params.update(extra_params)

        res, eui, _ = run_model_case(
            case=case,
            sampled_params=sampled_params,
            controller_mode=controller_mode,
        )

        results[sample_id] = res
        euis[sample_id] = eui

    eui_df = pd.DataFrame(euis).T

    return results, eui_df

baseline_results, baseline_eui = run_posterior_ecm_samples(
    posterior_TT=posterior_TT,
    extra_params=None,
    controller_mode=controller_mode,
)
# Out:
# Running posterior samples:   0%|          | 0/10 [00:00<?, ?sample/s]

# %%
def make_ecm_specs(case):
    default_infl = case.default_params["infl_rate_m3ph_m2"]

    return {
        "Baseline": {},

        "ECM-1_setpoint_19C": {
            "t_set_heating": 19.0,
        },

        "ECM-2_reschedule_8_8_8": {
            "heating_schedule_mode": "8_8_8",
        },

        "ECM-3_setpoint_19C_default_infiltration": {
            "t_set_heating": 19.0,
            "infl_rate_m3ph_m2": default_infl,
        },

        "ECM-4_reschedule_8_8_8_default_infiltration": {
            "heating_schedule_mode": "8_8_8",
            "infl_rate_m3ph_m2": default_infl,
        },
    }

def run_ecm_suite(
    posterior_TT,
    ecm_specs,
    controller_mode="original",
):
    all_results = {}
    all_euis = {}

    for ecm_name, extra_params in ecm_specs.items():
        results, eui_df = run_posterior_ecm_samples(
            posterior_TT=posterior_TT,
            extra_params=extra_params,
            controller_mode=controller_mode,
        )

        all_results[ecm_name] = results
        all_euis[ecm_name] = eui_df

    return all_results, all_euis

# %%
ecm_specs = make_ecm_specs(case)

all_results, all_euis = run_ecm_suite(
    posterior_TT=posterior_TT,
    ecm_specs=ecm_specs,
)
# Out:
# Running posterior samples:   0%|          | 0/10 [00:00<?, ?sample/s]
# Running posterior samples:   0%|          | 0/10 [00:00<?, ?sample/s]
# Running posterior samples:   0%|          | 0/10 [00:00<?, ?sample/s]
# Running posterior samples:   0%|          | 0/10 [00:00<?, ?sample/s]
# Running posterior samples:   0%|          | 0/10 [00:00<?, ?sample/s]

# %%
def compute_ecm_savings(
    all_euis,
    baseline_name="Baseline",
    energy_col="HeatingEnergy",
):
    baseline = all_euis[baseline_name][energy_col]
    rows = []

    for ecm_name, eui_df in all_euis.items():
        if ecm_name == baseline_name:
            continue

        df = pd.concat(
            [
                baseline.rename("baseline"),
                eui_df[energy_col].rename("ecm_energy"),
            ],
            axis=1,
            join="inner",
        )

        saving_abs = df["baseline"] - df["ecm_energy"]

        rows.append(
            pd.DataFrame(
                {
                    "ecm": ecm_name,
                    "sample_id": df.index,
                    "saving_abs": saving_abs,
                    "saving_rel": saving_abs / df["baseline"] * 100.0,
                }
            )
        )

    return pd.concat(rows, ignore_index=True)

# %%
def plot_ecm_savings_pair(
    savings_df,
    kpi_label="Heating energy",
    abs_unit="kWh m$^{-2}$",
    figsize=(12, 8),
    rot=30,
):
    plot_specs = {
        "saving_abs": (
            f"Absolute {kpi_label.lower()} saving ({abs_unit})",
            f"Absolute {kpi_label.lower()} savings across posterior samples",
        ),
        "saving_rel": (
            f"Relative {kpi_label.lower()} saving (%)",
            f"Relative {kpi_label.lower()} savings across posterior samples",
        ),
    }

    for value_col, (y_label, title) in plot_specs.items():
        fig, ax = plt.subplots(figsize=figsize)

        savings_df.boxplot(
            column=value_col,
            by="ecm",
            ax=ax,
            rot=rot,
        )

        ax.axhline(0, linestyle="--", linewidth=1)
        ax.set_ylabel(y_label)
        ax.set_xlabel("")
        ax.set_title(title)
        ax.grid(True, axis="y", alpha=0.3)

        plt.suptitle("")
        plt.tight_layout()
        plt.show()

# %%
heating_savings = compute_ecm_savings(
    all_euis=all_euis,
    baseline_name="Baseline",
    energy_col="HeatingEnergy",
)

plot_ecm_savings_pair(
    savings_df=heating_savings,
    kpi_label="Heating energy",
)
